# %% [markdown]
# ### Create anndata object from re-mapped E-MTAB-8901 samples
# - **Developed by:** Anna Maguza
# - **Affilation:** Faculty of Medicine, Würzburg University
# - **Creation date:** 23th of October 2024
# - **Last modified date:** 23th of October 2024

# %% [markdown]
# ### Import packages

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sci
import anndata as ad
from scipy import io,sparse
import os

# %% [markdown]
# + We want to save the spliced/unspliced counts in our anndata object

# %%
def starsolo_velocity_anndata(input_dir):
    """
    input directory should contain barcodes.tsv, features.tsv with 3 mtx from spliced, ambigious, unspliced
    """
    obs = pd.read_csv(os.path.join(input_dir,'barcodes.tsv'), header = None, index_col = 0)
    # Remove index column name to make it compliant with the anndata format
    obs.index.name = None

    var = pd.read_csv(os.path.join(input_dir,"features.tsv"), sep='\t',names = ('gene_ids', 'feature_types'), index_col = 1)
    var.index.name = None

    spliced=sci.sparse.csr_matrix(sci.io.mmread(os.path.join(input_dir,"spliced.mtx")).T)
    ambiguous=sci.sparse.csr_matrix(sci.io.mmread(os.path.join(input_dir,"ambiguous.mtx")).T)
    unspliced=sci.sparse.csr_matrix(sci.io.mmread(os.path.join(input_dir,"unspliced.mtx")).T)
    adata=ad.AnnData(X=spliced,obs=obs,var=var,layers={'spliced':spliced,"ambiguous":ambiguous,"unspliced":unspliced})
    adata.var_names_make_unique()
    return adata

# %% [markdown]
# + Upload sample description dataframe

# %%
samples = pd.read_csv("/mnt/LaCIE/annaM/gut_project/raw_fastq_files/Elmentaite_2021/metadata/E-MTAB-8901.sdrf.txt", sep = "\t")

# %%
samples['sample_name'] = samples['Comment[read2 file]'].str.split('_').str[0]

# %% [markdown]
# + Base path for remapped samples

# %%
base_path = '/mnt/LaCIE/annaM/gut_project/raw_data/Elmentaite_2021/remapped_fetal_data_E-MTAB-8901_starsolo'

# %%
ann_data_list = []
failed_samples = []

for sample_name in samples['sample_name']:
    try:
        # Try loading the AnnData object from the UMI10_output path
        sample_path = f"{base_path}/{sample_name}/UMI10_output/Velocyto/raw"
        sample_name_adata = starsolo_velocity_anndata(sample_path)

        # Create the cell_id column
        sample_name_adata.obs['sample_name'] = sample_name

        ann_data_list.append(sample_name_adata)
    except FileNotFoundError:
        try:
            # If not found in UMI10_output, try loading from the UMI12_output path
            sample_path = f"{base_path}/{sample_name}/UMI12_output/Velocyto/raw"
            sample_name_adata = starsolo_velocity_anndata(sample_path)

            # Create the cell_id column
            sample_name_adata.obs['sample_name'] = sample_name

            ann_data_list.append(sample_name_adata)
        except FileNotFoundError:
            # If sample is not found in either path, add it to the failed_samples list
            failed_samples.append(sample_name)
            print(f"Sample {sample_name} not found in both UMI10 and UMI12 paths, skipping.")

# Merge all AnnData objects into one, if there are any
if ann_data_list:
    combined_adata = ann_data_list[0].concatenate(ann_data_list[1:], join='outer')
else:
    combined_adata = None
    print("No valid AnnData objects found to merge.")

# List samples that were not processed
if failed_samples:
    print("The following samples were not processed:")
    for sample in failed_samples:
        print(sample)
# Out:
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# Sample 4918STDY7718974 not found in both UMI10 and UMI12 paths, skipping.
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# Sample 4918STDY7718972 not found in both UMI10 and UMI12 paths, skipping.
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# Sample 4918STDY7718973 not found in both UMI10 and UMI12 paths, skipping.
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# Sample 4918STDY7718977 not found in both UMI10 and UMI12 paths, skipping.
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# Sample 4918STDY7718975 not found in both UMI10 and UMI12 paths, skipping.
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# Sample 4918STDY7718976 not found in both UMI10 and UMI12 paths, skipping.
# Sample 4918STDY7901096 not found in both UMI10 and UMI12 paths, skipping.
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# Sample 4918STDY7273964 not found in both UMI10 and UMI12 paths, skipping.
# Sample 4918STDY7273965 not found in both UMI10 and UMI12 paths, skipping.
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/utils.py:220: UserWarning: Suffix used (-[0-9]+) to deduplicate index values may make index values difficult to interpret. There values with a similar suffixes in the index. Consider using a different delimiter by passing `join={delimiter}`Example key collisions generated by the make_index_unique algorithm: ['SNORD116-1', 'SNORD116-2', 'SNORD116-3', 'SNORD116-4', 'SNORD116-5']
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1763: FutureWarning: The AnnData.concatenate method is deprecated in favour of the anndata.concat function. Please use anndata.concat instead.
#
# See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   warnings.warn(
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/merge.py:1015: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   concat_indices = concat_indices.str.cat(label_col.map(str), sep=index_unique)
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/merge.py:217: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(dtype):
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/merge.py:1015: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   concat_indices = concat_indices.str.cat(label_col.map(str), sep=index_unique)
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/merge.py:217: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(dtype):
# The following samples were not processed:
# 4918STDY7718974
# 4918STDY7718972
# 4918STDY7718973
# 4918STDY7718977
# 4918STDY7718975
# 4918STDY7718976
# 4918STDY7901096
# 4918STDY7273964
# 4918STDY7273965

# %%
combined_adata.obs['barcode'] = combined_adata.obs.index.copy()

# %%
combined_adata.obs = combined_adata.obs.merge(samples, on='sample_name', how='left', suffixes=('', '_y'))

combined_adata.obs = combined_adata.obs.loc[:, ~combined_adata.obs.columns.str.endswith('_y')]

# %%
combined_adata.obs.index = combined_adata.obs['barcode']

# %%
combined_adata.obs
# Out:
#                          sample_name batch              barcode  \
# barcode
# AAACCTGAGAAACCAT-0   4918STDY8366756     0   AAACCTGAGAAACCAT-0
# AAACCTGAGAAACCGC-0   4918STDY8366756     0   AAACCTGAGAAACCGC-0
# AAACCTGAGAAACCTA-0   4918STDY8366756     0   AAACCTGAGAAACCTA-0
# AAACCTGAGAAACGAG-0   4918STDY8366756     0   AAACCTGAGAAACGAG-0
# AAACCTGAGAAACGCC-0   4918STDY8366756     0   AAACCTGAGAAACGCC-0
# ...                              ...   ...                  ...
# TTTGTCATCTTTACAC-45  4918STDY7389431    45  TTTGTCATCTTTACAC-45
# TTTGTCATCTTTACGT-45  4918STDY7389431    45  TTTGTCATCTTTACGT-45
# TTTGTCATCTTTAGGG-45  4918STDY7389431    45  TTTGTCATCTTTAGGG-45
# TTTGTCATCTTTAGTC-45  4918STDY7389431    45  TTTGTCATCTTTAGTC-45
# TTTGTCATCTTTCCTC-45  4918STDY7389431    45  TTTGTCATCTTTCCTC-45
#
#                              Source Name Comment[ENA_SAMPLE]  \
# barcode
# AAACCTGAGAAACCAT-0   2206_p2_WNT3A_cells          ERS4414920
# AAACCTGAGAAACCGC-0   2206_p2_WNT3A_cells          ERS4414920
# AAACCTGAGAAACCTA-0   2206_p2_WNT3A_cells          ERS4414920
# AAACCTGAGAAACGAG-0   2206_p2_WNT3A_cells          ERS4414920
# AAACCTGAGAAACGCC-0   2206_p2_WNT3A_cells          ERS4414920
# ...                                  ...                 ...
# TTTGTCATCTTTACAC-45         T44_IL_cells          ERS4414974
# TTTGTCATCTTTACGT-45         T44_IL_cells          ERS4414974
# TTTGTCATCTTTAGGG-45         T44_IL_cells          ERS4414974
# TTTGTCATCTTTAGTC-45         T44_IL_cells          ERS4414974
# TTTGTCATCTTTCCTC-45         T44_IL_cells          ERS4414974
#
#                     Comment[BioSD_SAMPLE] Characteristics[organism]  \
# barcode
# AAACCTGAGAAACCAT-0           SAMEA6655451              Homo sapiens
# AAACCTGAGAAACCGC-0           SAMEA6655451              Homo sapiens
# AAACCTGAGAAACCTA-0           SAMEA6655451              Homo sapiens
# AAACCTGAGAAACGAG-0           SAMEA6655451              Homo sapiens
# AAACCTGAGAAACGCC-0           SAMEA6655451              Homo sapiens
# ...                                   ...                       ...
# TTTGTCATCTTTACAC-45          SAMEA6655505              Homo sapiens
# TTTGTCATCTTTACGT-45          SAMEA6655505              Homo sapiens
# TTTGTCATCTTTAGGG-45          SAMEA6655505              Homo sapiens
# TTTGTCATCTTTAGTC-45          SAMEA6655505              Homo sapiens
# TTTGTCATCTTTCCTC-45          SAMEA6655505              Homo sapiens
#
#                     Characteristics[developmental stage] Characteristics[age]  \
# barcode
# AAACCTGAGAAACCAT-0                 embryonic human stage
# AAACCTGAGAAACCGC-0                 embryonic human stage
# AAACCTGAGAAACCTA-0                 embryonic human stage
# AAACCTGAGAAACGAG-0                 embryonic human stage
# AAACCTGAGAAACGCC-0                 embryonic human stage
# ...                                                  ...                  ...
# TTTGTCATCTTTACAC-45                          child stage                   10
# TTTGTCATCTTTACGT-45                          child stage                   10
# TTTGTCATCTTTAGGG-45                          child stage                   10
# TTTGTCATCTTTAGTC-45                          child stage                   10
# TTTGTCATCTTTCCTC-45                          child stage                   10
#
#                     Unit[time unit]  ...  \
# barcode                              ...
# AAACCTGAGAAACCAT-0                   ...
# AAACCTGAGAAACCGC-0                   ...
# AAACCTGAGAAACCTA-0                   ...
# AAACCTGAGAAACGAG-0                   ...
# AAACCTGAGAAACGCC-0                   ...
# ...                             ...  ...
# TTTGTCATCTTTACAC-45            year  ...
# TTTGTCATCTTTACGT-45            year  ...
# TTTGTCATCTTTAGGG-45            year  ...
# TTTGTCATCTTTAGTC-45            year  ...
# TTTGTCATCTTTCCTC-45            year  ...
#
#                                                     Comment[FASTQ_URI]  \
# barcode
# AAACCTGAGAAACCAT-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACCGC-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACCTA-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACGAG-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACGCC-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# ...                                                                ...
# TTTGTCATCTTTACAC-45  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTACGT-45  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTAGGG-45  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTAGTC-45  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTCCTC-45  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
#
#                                          Comment[read2 file]  \
# barcode
# AAACCTGAGAAACCAT-0   4918STDY8366756_S1_L001_R2_001.fastq.gz
# AAACCTGAGAAACCGC-0   4918STDY8366756_S1_L001_R2_001.fastq.gz
# AAACCTGAGAAACCTA-0   4918STDY8366756_S1_L001_R2_001.fastq.gz
# AAACCTGAGAAACGAG-0   4918STDY8366756_S1_L001_R2_001.fastq.gz
# AAACCTGAGAAACGCC-0   4918STDY8366756_S1_L001_R2_001.fastq.gz
# ...                                                      ...
# TTTGTCATCTTTACAC-45  4918STDY7389431_S1_L001_R2_001.fastq.gz
# TTTGTCATCTTTACGT-45  4918STDY7389431_S1_L001_R2_001.fastq.gz
# TTTGTCATCTTTAGGG-45  4918STDY7389431_S1_L001_R2_001.fastq.gz
# TTTGTCATCTTTAGTC-45  4918STDY7389431_S1_L001_R2_001.fastq.gz
# TTTGTCATCTTTCCTC-45  4918STDY7389431_S1_L001_R2_001.fastq.gz
#
#                                                   Comment[FASTQ_URI].1  \
# barcode
# AAACCTGAGAAACCAT-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACCGC-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACCTA-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACGAG-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACGCC-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# ...                                                                ...
# TTTGTCATCTTTACAC-45  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTACGT-45  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTAGGG-45  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTAGTC-45  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTCCTC-45  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
#
#                                         Comment[index1 file]  \
# barcode
# AAACCTGAGAAACCAT-0   4918STDY8366756_S1_L001_I1_001.fastq.gz
# AAACCTGAGAAACCGC-0   4918STDY8366756_S1_L001_I1_001.fastq.gz
# AAACCTGAGAAACCTA-0   4918STDY8366756_S1_L001_I1_001.fastq.gz
# AAACCTGAGAAACGAG-0   4918STDY8366756_S1_L001_I1_001.fastq.gz
# AAACCTGAGAAACGCC-0   4918STDY8366756_S1_L001_I1_001.fastq.gz
# ...                                                      ...
# TTTGTCATCTTTACAC-45  4918STDY7389431_S1_L001_I1_001.fastq.gz
# TTTGTCATCTTTACGT-45  4918STDY7389431_S1_L001_I1_001.fastq.gz
# TTTGTCATCTTTAGGG-45  4918STDY7389431_S1_L001_I1_001.fastq.gz
# TTTGTCATCTTTAGTC-45  4918STDY7389431_S1_L001_I1_001.fastq.gz
# TTTGTCATCTTTCCTC-45  4918STDY7389431_S1_L001_I1_001.fastq.gz
#
#                                                   Comment[FASTQ_URI].2  \
# barcode
# AAACCTGAGAAACCAT-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACCGC-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACCTA-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACGAG-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# AAACCTGAGAAACGCC-0   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# ...                                                                ...
# TTTGTCATCTTTACAC-45  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTACGT-45  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTAGGG-45  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTAGTC-45  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# TTTGTCATCTTTCCTC-45  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
#
#                     Factor Value[disease] Factor Value[developmental stage]  \
# barcode
# AAACCTGAGAAACCAT-0                 normal             embryonic human stage
# AAACCTGAGAAACCGC-0                 normal             embryonic human stage
# AAACCTGAGAAACCTA-0                 normal             embryonic human stage
# AAACCTGAGAAACGAG-0                 normal             embryonic human stage
# AAACCTGAGAAACGCC-0                 normal             embryonic human stage
# ...                                   ...                               ...
# TTTGTCATCTTTACAC-45                normal                       child stage
# TTTGTCATCTTTACGT-45                normal                       child stage
# TTTGTCATCTTTAGGG-45                normal                       child stage
# TTTGTCATCTTTAGTC-45                normal                       child stage
# TTTGTCATCTTTCCTC-45                normal                       child stage
#
#                     Factor Value[organism part] Factor Value[immunophenotype]  \
# barcode
# AAACCTGAGAAACCAT-0                        ileum                   total cells
# AAACCTGAGAAACCGC-0                        ileum                   total cells
# AAACCTGAGAAACCTA-0                        ileum                   total cells
# AAACCTGAGAAACGAG-0                        ileum                   total cells
# AAACCTGAGAAACGCC-0                        ileum                   total cells
# ...                                         ...                           ...
# TTTGTCATCTTTACAC-45              terminal ileum                   total cells
# TTTGTCATCTTTACGT-45              terminal ileum                   total cells
# TTTGTCATCTTTAGGG-45              terminal ileum                   total cells
# TTTGTCATCTTTAGTC-45              terminal ileum                   total cells
# TTTGTCATCTTTCCTC-45              terminal ileum                   total cells
#
#                            Factor Value[growth condition]
# barcode
# AAACCTGAGAAACCAT-0   organoid grown in conditioned medium
# AAACCTGAGAAACCGC-0   organoid grown in conditioned medium
# AAACCTGAGAAACCTA-0   organoid grown in conditioned medium
# AAACCTGAGAAACGAG-0   organoid grown in conditioned medium
# AAACCTGAGAAACGCC-0   organoid grown in conditioned medium
# ...                                                   ...
# TTTGTCATCTTTACAC-45                        primary tissue
# TTTGTCATCTTTACGT-45                        primary tissue
# TTTGTCATCTTTAGGG-45                        primary tissue
# TTTGTCATCTTTAGTC-45                        primary tissue
# TTTGTCATCTTTCCTC-45                        primary tissue
#
# [33914880 rows x 77 columns]

# %%
combined_adata.write_h5ad('/mnt/LaCIE/annaM/gut_project/raw_data/Elmentaite_2021/remapped_fetal_data_E-MTAB-8901_starsolo/E-MTAB-8901_raw_velocity_anndata.h5ad')

# %%
sample_names_to_keep = [
    '4918STDY7718974', '4918STDY7718972', '4918STDY7718973', 
    '4918STDY7718977', '4918STDY7718975', '4918STDY7718976', 
    '4918STDY7901096', '4918STDY7273964', '4918STDY7273965'
]

filtered_samples = samples[samples['sample_name'].isin(sample_names_to_keep)]
filtered_samples
# Out:
#              Source Name Comment[ENA_SAMPLE] Comment[BioSD_SAMPLE]  \
# 7   BRC2134_CO_neg_cells          ERS4414927          SAMEA6655458
# 10  BRC2134_DU_neg_cells          ERS4414930          SAMEA6655461
# 12  BRC2134_IL_neg_cells          ERS4414932          SAMEA6655463
# 19  BRC2134_CO_pos_cells          ERS4414939          SAMEA6655470
# 26  BRC2134_DU_pos_cells          ERS4414946          SAMEA6655477
# 33  BRC2134_IL_pos_cells          ERS4414953          SAMEA6655484
# 34         T176_IL_cells          ERS4414954          SAMEA6655485
# 39         T017_IL_cells          ERS4414959          SAMEA6655490
# 40         T019_IL_cells          ERS4414960          SAMEA6655491
#
#    Characteristics[organism]      Characteristics[developmental stage]  \
# 7               Homo sapiens  10th week post-fertilization human stage
# 10              Homo sapiens  10th week post-fertilization human stage
# 12              Homo sapiens  10th week post-fertilization human stage
# 19              Homo sapiens  10th week post-fertilization human stage
# 26              Homo sapiens  10th week post-fertilization human stage
# 33              Homo sapiens  10th week post-fertilization human stage
# 34              Homo sapiens                               child stage
# 39              Homo sapiens                          adolescent stage
# 40              Homo sapiens                               child stage
#
#    Characteristics[age] Unit[time unit] Term Source REF Term Accession Number  \
# 7
# 10
# 12
# 19
# 26
# 33
# 34                   11            year             EFO            UO_0000036
# 39                   13            year             EFO            UO_0000036
# 40                   12            year             EFO            UO_0000036
#
#    Characteristics[gestational age]  ...  \
# 7                                12  ...
# 10                               12  ...
# 12                               12  ...
# 19                               12  ...
# 26                               12  ...
# 33                               12  ...
# 34                                   ...
# 39                                   ...
# 40                                   ...
#
#                         Comment[read2 file]  \
# 7   4918STDY7718974_S1_L001_R2_001.fastq.gz
# 10  4918STDY7718972_S1_L001_R2_001.fastq.gz
# 12  4918STDY7718973_S1_L001_R2_001.fastq.gz
# 19  4918STDY7718977_S1_L001_R2_001.fastq.gz
# 26  4918STDY7718975_S1_L001_R2_001.fastq.gz
# 33  4918STDY7718976_S1_L001_R2_001.fastq.gz
# 34  4918STDY7901096_S1_L001_R2_001.fastq.gz
# 39  4918STDY7273964_S1_L001_R2_001.fastq.gz
# 40  4918STDY7273965_S1_L001_R2_001.fastq.gz
#
#                                  Comment[FASTQ_URI].1  \
# 7   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 10  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 12  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 19  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 26  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 33  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 34  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 39  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
# 40  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...
#
#                        Comment[index1 file]  \
# 7   4918STDY7718974_S1_L001_I1_001.fastq.gz
# 10  4918STDY7718972_S1_L001_I1_001.fastq.gz
# 12  4918STDY7718973_S1_L001_I1_001.fastq.gz
# 19  4918STDY7718977_S1_L001_I1_001.fastq.gz
# 26  4918STDY7718975_S1_L001_I1_001.fastq.gz
# 33  4918STDY7718976_S1_L001_I1_001.fastq.gz
# 34  4918STDY7901096_S1_L001_I1_001.fastq.gz
# 39  4918STDY7273964_S1_L001_I1_001.fastq.gz
# 40  4918STDY7273965_S1_L001_I1_001.fastq.gz
#
#                                  Comment[FASTQ_URI].2 Factor Value[disease]  \
# 7   ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...                normal
# 10  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...                normal
# 12  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...                normal
# 19  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...                normal
# 26  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...                normal
# 33  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...                normal
# 34  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...         Crohn disease
# 39  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...         Crohn disease
# 40  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...         Crohn disease
#
#            Factor Value[developmental stage] Factor Value[organism part]  \
# 7   10th week post-fertilization human stage                       colon
# 10  10th week post-fertilization human stage                    duodenum
# 12  10th week post-fertilization human stage                       ileum
# 19  10th week post-fertilization human stage                       colon
# 26  10th week post-fertilization human stage                    duodenum
# 33  10th week post-fertilization human stage                       ileum
# 34                               child stage              terminal ileum
# 39                          adolescent stage              terminal ileum
# 40                               child stage              terminal ileum
#
#    Factor Value[immunophenotype] Factor Value[growth condition]  \
# 7                 EPCAM negative                 primary tissue
# 10                EPCAM negative                 primary tissue
# 12                EPCAM negative                 primary tissue
# 19                EPCAM positive                 primary tissue
# 26                EPCAM positive                 primary tissue
# 33                EPCAM positive                 primary tissue
# 34                   total cells                 primary tissue
# 39                   total cells                 primary tissue
# 40                   total cells                 primary tissue
#
#         sample_name
# 7   4918STDY7718974
# 10  4918STDY7718972
# 12  4918STDY7718973
# 19  4918STDY7718977
# 26  4918STDY7718975
# 33  4918STDY7718976
# 34  4918STDY7901096
# 39  4918STDY7273964
# 40  4918STDY7273965
#
# [9 rows x 75 columns]

# %%
filtered_samples.to_csv("/mnt/LaCIE/annaM/gut_project/raw_fastq_files/Elmentaite_2021/metadata/E-MTAB-8901_filtered.sdrf.txt", sep = "\t")
