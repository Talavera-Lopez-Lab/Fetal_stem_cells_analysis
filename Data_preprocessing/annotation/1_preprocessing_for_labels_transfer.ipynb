# %% [markdown]
# # Preprocessing of the remapped datasets for the labels transfer
#
# **Developed by:** Anna Maguza\
# **Affiliation:** Faculty of Medicine, Würzburg University\
# **Creation date:** 17th December 2024\
# **Last modified date:** 17th December 2024
#
# #### **Datasets**
#
# In this notebiook we will prepare the following datasets for the annotation process:
#
# - **E-MTAB-8901** (Elementaite et al., 2021) - Fetal developing gut
# - **E-MTAB-9536** (Elementaite et al., 2021) - Fetal developing gut
# - **E-MTAB-9543** (Elementaite et al., 2021) - Adult gut
# - **E-MTAB-9489** (Holloway et al., 2021) - Fetal developing gut
# - **E-MTAB-9720** (Holloway et al., 2021) - Fetal enteroids
#
# Here we will conduct such preprocessing:
#
# 1. **Cell Annotation Transfer**
#
#    - Cells present in both the Gut Cell Atlas (Elementaite, 2021) and the following Elementaite datasets (E-MTAB-8901, E-MTAB-9536, and E-MTAB-9543) are assigned cell type labels consistent with the Gut Cell Atlas annotations.
#    - Cells from the Holloway datasets (E-MTAB-9489 and E-MTAB-9720) and unannotated cells from the Elementaite datasets are initially labeled as 'Unknown'.
#
# 2. **Datasets merge**
#
# 3. **Visualization of uncorrected PCA and UMAP plots to identify main covariates**

# %% [markdown]
# ## Import packages

# %%
import anndata
import numpy as np
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt
import json
from datetime import datetime

# %% [markdown]
# ## Setup working environment

# %%
sc.settings.verbosity = 3
sc.settings.set_figure_params(dpi = 180, color_map = 'magma_r', dpi_save = 300, vector_friendly = True, format = 'svg')

# %%
def X_is_raw(adata):
    return np.array_equal(adata.X.sum(axis=0).astype(int), adata.X.sum(axis=0))

# %% [markdown]
# ## Upload data

# %% [markdown]
# + Gut cell atlas (annotated) (Elementaite et al., 2021)

# %%
GCA = sc.read_h5ad("/mnt/LaCIE/annaM/gut_project/raw_data/Elmentaite_2021/Full_obj_raw_counts_nosoupx_v2.h5ad")
GCA
# Out:
# AnnData object with n_obs × n_vars = 428469 × 33538
#     obs: 'Sample name', 'Diagnosis', 'Age', 'sample name', 'Region code', 'Fraction', 'Gender', 'Region', '10X', 'batch', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_scores', 'predicted_doublets', 'category', 'Age_group', 'Integrated_05'
#     var: 'gene_ids', 'feature_types'

# %%
X_is_raw(GCA)
# Out:
# True

# %% [markdown]
# * E-MTAB-8901 (Elementaite et al., 2021)

# %%
E8901 = sc.read_h5ad('Elementaite_2021/gut_hs_Elementaite2021_E-MTAB-8901_metadata_with_embedding_AM_18122024_124621_raw.h5ad')
E8901
# Out:
# AnnData object with n_obs × n_vars = 131623 × 70711
#     obs: 'barcode', 'Source Name', 'ENA_SAMPLE', 'BioSD_SAMPLE', 'organism', 'developmental_stage', 'age', 'time_unit', 'gestational_age', 'disease', 'donor_id', 'organism_part', 'cell_type', 'immunophenotype', 'growth_condition', 'passage', 'Material Type', 'Protocol REF', 'sample_id', 'LIBRARY_LAYOUT', 'cdna_read_size', 'cell_barcode_size', 'end_bias', 'library_construction', 'sample_barcode_size', 'umi_barcode_offset', 'umi_barcode_size', 'Performer', 'Assay Name', 'ENA_EXPERIMENT', 'ENA_RUN', 'n_genes', 'doublet_scores', 'predicted_doublets', 'n_counts', 'log1p_n_counts', 'log1p_n_genes', 'percent_mito', 'n_counts_mito', 'percent_ribo', 'n_counts_ribo', 'percent_hb', 'n_counts_hb', 'percent_top50', 'cell_passed_qc', 'qc_cluster', 'cluster_passed_qc', 'consensus_fraction', 'consensus_passed_qc', 'total_counts', 'n_genes_by_counts', 'percent_chrY', 'XIST-counts', 'XIST-percentage', 'sex', 'S_score', 'G2M_score', 'Cell_cycle_phase', 'Study_name', 'ArrayExpress_ID', 'library_preparation_protocol', 'batch', 'full_age', 'age_group', 'metadata_cluster'
#     var: 'gene_ids', 'feature_types', 'mito', 'ribo', 'hb', 'n_counts', 'n_cells'
#     uns: 'Source Name_colors', 'cell_passed_qc_colors', 'cluster_passed_qc_colors', 'processing_history', 'scautoqc_ranges'
#     obsm: 'X_umap_qc'
#     layers: 'ambiguous', 'spliced', 'unspliced'

# %%
X_is_raw(E8901)
# Out:
# True

# %% [markdown]
# * E-MTAB-9536 (Elementaite et al., 2021)

# %%
E9536 = sc.read_h5ad('Elementaite_2021/gut_hs_Elementaite2021_E-MTAB-9536_metadata_with_embedding_AM_18122024_124621_raw.h5ad')
E9536
# Out:
# AnnData object with n_obs × n_vars = 31494 × 70711
#     obs: 'sample_id', 'barcode', 'Source Name', 'ENA_SAMPLE', 'BioSD_SAMPLE', 'organism', 'age', 'time_unit', 'developmental_stage', 'donor_id', 'disease', 'organism_part', 'sampling_site', 'Material Type', 'Protocol REF', 'Performer', 'LIBRARY_LAYOUT', 'cdna_read_size', 'cell_barcode_size', 'end_bias', 'library_construction', 'sample_barcode_size', 'umi_barcode_offset', 'umi_barcode_size', 'Assay Name', 'ENA_EXPERIMENT', 'ENA_RUN', 'n_genes', 'doublet_scores', 'predicted_doublets', 'n_counts', 'log1p_n_counts', 'log1p_n_genes', 'percent_mito', 'n_counts_mito', 'percent_ribo', 'n_counts_ribo', 'percent_hb', 'n_counts_hb', 'percent_top50', 'cell_passed_qc', 'qc_cluster', 'cluster_passed_qc', 'consensus_fraction', 'consensus_passed_qc', 'total_counts', 'n_genes_by_counts', 'percent_chrY', 'XIST-counts', 'XIST-percentage', 'sex', 'S_score', 'G2M_score', 'Cell_cycle_phase', 'Study_name', 'ArrayExpress_ID', 'library_preparation_protocol', 'batch', 'full_age', 'growth_condition', 'age_group', 'immunophenotype', 'metadata_cluster'
#     var: 'gene_ids', 'feature_types', 'mito', 'ribo', 'hb', 'n_counts', 'n_cells'
#     uns: 'Source Name_colors', 'cell_passed_qc_colors', 'cluster_passed_qc_colors', 'consensus_passed_qc_colors', 'processing_history', 'qc_cluster_colors', 'scautoqc_ranges'
#     obsm: 'X_umap_qc'
#     layers: 'ambiguous', 'spliced', 'unspliced'

# %%
X_is_raw(E9536)
# Out:
# True

# %% [markdown]
# * E-MTAB-9543 (Elementaite et al., 2021)

# %%
E9543 = sc.read_h5ad('Elementaite_2021/gut_hs_Elementaite2021_E-MTAB-9543_metadata_with_embedding_AM_18122024_124621_raw.h5ad')
E9543
# Out:
# AnnData object with n_obs × n_vars = 62586 × 70711
#     obs: 'sample_id', 'barcode', 'Source Name', 'ENA_SAMPLE', 'BioSD_SAMPLE', 'organism', 'age', 'time_unit', 'developmental_stage', 'donor_id', 'cell_type', 'organism_part', 'Material Type', 'Protocol REF', 'Performer', 'LIBRARY_LAYOUT', 'cdna_read_size', 'cell_barcode_size', 'end_bias', 'library_construction', 'sample_barcode_size', 'umi_barcode_offset', 'umi_barcode_size', 'Assay Name', 'ENA_EXPERIMENT', 'ENA_RUN', 'n_genes', 'doublet_scores', 'predicted_doublets', 'n_counts', 'log1p_n_counts', 'log1p_n_genes', 'percent_mito', 'n_counts_mito', 'percent_ribo', 'n_counts_ribo', 'percent_hb', 'n_counts_hb', 'percent_top50', 'total_counts', 'n_genes_by_counts', 'cell_passed_qc', 'percent_chrY', 'XIST-counts', 'XIST-percentage', 'sex', 'S_score', 'G2M_score', 'Cell_cycle_phase', 'Study_name', 'ArrayExpress_ID', 'library_preparation_protocol', 'batch', 'full_age', 'disease', 'growth_condition', 'age_group', 'immunophenotype', 'metadata_cluster'
#     var: 'gene_ids', 'feature_types', 'mito', 'ribo', 'hb', 'n_counts', 'n_cells'
#     uns: 'Source Name_colors', 'processing_history', 'scautoqc_ranges'
#     layers: 'ambiguous', 'spliced', 'unspliced'

# %%
X_is_raw(E9543)
# Out:
# True

# %% [markdown]
# * E-MTAB-9489 (Holloway et al., 2021)

# %%
E9489 = sc.read_h5ad('Holloway_2021/gut_hs_Holloway2021_E-MTAB-9489_metadata_with_embedding_AM_18122024_124621_raw.h5ad')
E9489
# Out:
# AnnData object with n_obs × n_vars = 223842 × 70711
#     obs: 'barcode', 'Source Name', 'ENA_SAMPLE', 'BioSD_SAMPLE', 'organism', 'developmental_stage', 'age', 'time_unit', 'disease', 'donor_id', 'organism_part', 'immunophenotype', 'Material Type', 'Protocol REF', 'sample_id', 'LIBRARY_LAYOUT', 'cdna_read_size', 'cell_barcode_size', 'end_bias', 'library_construction', 'sample_barcode_size', 'umi_barcode_offset', 'umi_barcode_size', 'Performer', 'Assay Name', 'ENA_EXPERIMENT', 'ENA_RUN', 'n_genes', 'doublet_scores', 'predicted_doublets', 'n_counts', 'log1p_n_counts', 'log1p_n_genes', 'percent_mito', 'n_counts_mito', 'percent_ribo', 'n_counts_ribo', 'percent_hb', 'n_counts_hb', 'percent_top50', 'cell_passed_qc', 'qc_cluster', 'cluster_passed_qc', 'consensus_fraction', 'consensus_passed_qc', 'total_counts', 'n_genes_by_counts', 'percent_chrY', 'XIST-counts', 'XIST-percentage', 'sex', 'S_score', 'G2M_score', 'Cell_cycle_phase', 'Study_name', 'ArrayExpress_ID', 'library_preparation_protocol', 'full_age', 'growth_condition', 'age_group', 'metadata_cluster'
#     var: 'gene_ids', 'feature_types', 'mito', 'ribo', 'hb', 'n_counts', 'n_cells'
#     uns: 'Source Name_colors', 'cell_passed_qc_colors', 'cluster_passed_qc_colors', 'consensus_passed_qc_colors', 'processing_history', 'qc_cluster_colors', 'scautoqc_ranges'
#     obsm: 'X_umap_qc'
#     layers: 'ambiguous', 'spliced', 'unspliced'

# %%
X_is_raw(E9489)
# Out:
# True

# %% [markdown]
# * E-MTAB-9720 (Holloway et al., 2021)

# %%
E9720 = sc.read_h5ad('Holloway_2021/gut_hs_Holloway2021_E-MTAB-9720_metadata_with_embedding_AM_18122024_124621_raw.h5ad')
E9720
# Out:
# AnnData object with n_obs × n_vars = 10558 × 70711
#     obs: 'barcode', 'Source Name', 'ENA_SAMPLE', 'BioSD_SAMPLE', 'organism', 'disease', 'organism_part', 'cell_type', 'growth_condition', 'developmental_stage', 'Material Type', 'Protocol REF', 'sample_id', 'LIBRARY_LAYOUT', 'cdna_read_size', 'cell_barcode_size', 'end_bias', 'library_construction', 'sample_barcode_size', 'umi_barcode_offset', 'umi_barcode_size', 'Performer', 'Assay Name', 'ENA_EXPERIMENT', 'ENA_RUN', 'time', 'time_unit', 'n_genes', 'doublet_scores', 'predicted_doublets', 'n_counts', 'log1p_n_counts', 'log1p_n_genes', 'percent_mito', 'n_counts_mito', 'percent_ribo', 'n_counts_ribo', 'percent_hb', 'n_counts_hb', 'percent_top50', 'cell_passed_qc', 'qc_cluster', 'cluster_passed_qc', 'consensus_fraction', 'consensus_passed_qc', 'total_counts', 'n_genes_by_counts', 'percent_chrY', 'XIST-counts', 'XIST-percentage', 'sex', 'S_score', 'G2M_score', 'Cell_cycle_phase', 'Study_name', 'ArrayExpress_ID', 'library_preparation_protocol', 'full_age', 'age_group', 'immunophenotype', 'metadata_cluster'
#     var: 'gene_ids', 'feature_types', 'mito', 'ribo', 'hb', 'n_counts', 'n_cells'
#     uns: 'Source Name_colors', 'processing_history', 'scautoqc_ranges'
#     obsm: 'X_umap_qc'
#     layers: 'ambiguous', 'spliced', 'unspliced'

# %%
X_is_raw(E9720)
# Out:
# True

# %% [markdown]
# ## Prepare obs

# %% [markdown]
# + Make barcodes as in the GCA dataset

# %%
E8901.obs.rename(columns={E8901.obs.columns[0]: 'cell_id'}, inplace=True)
E9489.obs.rename(columns={E9489.obs.columns[0]: 'cell_id'}, inplace=True)
E9536.obs.rename(columns={E9536.obs.columns[1]: 'cell_id'}, inplace=True)
E9543.obs.rename(columns={E9543.obs.columns[1]: 'cell_id'}, inplace=True)
E9720.obs.rename(columns={E9720.obs.columns[0]: 'cell_id'}, inplace=True)

# %%
anndata_objects = [E8901, E9489, E9536, E9543, E9720]

# %%
for adata in anndata_objects:
    adata.obs['cell_id'] = adata.obs['cell_id'].str.split('-').str[0]

# %%
anndata_objects = [E8901, E9536, E9543]

# %%
for adata in anndata_objects:
    adata.obs['batch'] = adata.obs['batch'].astype(str)
    adata.obs['cell_id'] = adata.obs['cell_id'] + '-1-' + adata.obs['batch']
    adata.obs['barcode'] = adata.obs.index.copy()
    adata.obs['barcode'] = adata.obs['barcode'].str.split('-').str[0]
    adata.obs.index = adata.obs['cell_id']

# %%
common_indexes = E8901.obs.index.intersection(GCA.obs.index)
print(f"Number of common indexes: {len(common_indexes)}")
common_indexes = E9536.obs.index.intersection(GCA.obs.index)
print(f"Number of common indexes: {len(common_indexes)}")
common_indexes = E9543.obs.index.intersection(GCA.obs.index)
print(f"Number of common indexes: {len(common_indexes)}")
# Out:
# Number of common indexes: 83766
# Number of common indexes: 24994
# Number of common indexes: 13967

# %%
anndata_objects = [E9489, E9720]

for adata in anndata_objects:
    adata.obs['Source Name'] = adata.obs['Source Name'].astype(str)
    adata.obs['cell_id'] = adata.obs['cell_id'] + '-1-' + adata.obs['Source Name']
    adata.obs['barcode'] = adata.obs.index.copy()
    adata.obs['barcode'] = adata.obs['barcode'].str.split('-').str[0]
    adata.obs.index = adata.obs['cell_id']

# %% [markdown]
# + Merge cell types and cell states from GCA to Elementaite objects, cells that are not present in GCA have annotation 'Unknown'

# %%
anndata_objects = [E8901, E9536, E9543]

# %%
for adata in anndata_objects:
    adata.obs['category'] = 'Unknown'
    adata.obs['Integrated_05'] = 'Unknown'
    
    common_indexes = adata.obs.index.intersection(GCA.obs.index)
    
    adata.obs.loc[common_indexes, 'category'] = GCA.obs.loc[common_indexes, 'category']
    adata.obs.loc[common_indexes, 'Integrated_05'] = GCA.obs.loc[common_indexes, 'Integrated_05']

# %%
anndata_objects = [E9489, E9720]

for adata in anndata_objects:
    adata.obs['category'] = 'Unknown'
    adata.obs['Integrated_05'] = 'Unknown'

# %%
del GCA # to reduce memory usage

# %% [markdown]
# ## Merge datasets

# %%
anndata_objects = {'E-MTAB-9720': E9720, 'E-MTAB-E8901': E8901, 'E-MTAB-E9489': E9489, 'E-MTAB-E9543': E9543, 'E-MTAB-E9536': E9536}

# %%
combined_processing_history = []

for key, adata in anndata_objects.items():
    if 'processing_history' in adata.uns:
        for entry in adata.uns['processing_history']:
            combined_processing_history.append(f'[{key}] {entry}')

# %%
merged_data = anndata.concat(
    list(anndata_objects.values()), 
    join='outer', 
    label=None, 
    keys=list(anndata_objects.keys()), 
    index_unique=None, 
    uns_merge='unique',
)
# Out:
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
merged_data.uns['processing_history'] = np.array(combined_processing_history)
print(merged_data.uns['processing_history'])
# Out:
# ['[E-MTAB-9720] {"step": "create raw anndata after mapping, no filtering", "timestamp": "06112024_121025"}'
#  '[E-MTAB-9720] {"timestamp": "27112024_160858", "step": "added qc metrics (generated with sctk), doublets info, filtered cells with less than 100 genes"}'
#  '[E-MTAB-9720] {"timestamp": "09122024_103213", "step": "filtered cells based on consensus qc generated with sctk (default parameters), added sex covariates and cell cycle phase"}'
#  '[E-MTAB-9720] {"timestamp": "17122024_164056", "step": "Metadata harmonized for integration with other datasets"}'
#  '[E-MTAB-9720] {"timestamp": "18122024_124621", "step": "Add metadata clusters using sentence-transformers"}'
#  '[E-MTAB-E8901] {"step": "added qc metrics (generated with sctk), doublets info, filtered cells with less than 100 genes", "timestamp": "25112024_121501"}'
#  '[E-MTAB-E8901] {"timestamp": "02122024_143702", "step": "filtered cells based on consensus qc generated with sctk (default parameters), added sex covariates and cell cycle phase"}'
#  '[E-MTAB-E8901] {"timestamp": "17122024_164056", "step": "Metadata harmonized for integration with other datasets"}'
#  '[E-MTAB-E8901] {"timestamp": "18122024_124621", "step": "Add metadata clusters using sentence-transformers"}'
#  '[E-MTAB-E9489] {"step": "added qc metrics (generated with sctk), doublets info, filtered cells with less than 100 genes", "timestamp": "27112024_122219"}'
#  '[E-MTAB-E9489] {"timestamp": "09122024_100120", "step": "filtered cells based on consensus qc generated with sctk (default parameters), added sex covariates and cell cycle phase"}'
#  '[E-MTAB-E9489] {"timestamp": "17122024_164056", "step": "Metadata harmonized for integration with other datasets"}'
#  '[E-MTAB-E9489] {"timestamp": "18122024_124621", "step": "Add metadata clusters using sentence-transformers"}'
#  '[E-MTAB-E9543] {"step": "create raw anndata after mapping, no filtering", "timestamp": "05112024_113505"}'
#  '[E-MTAB-E9543] {"timestamp": "09122024_154541", "step": "doublets info; filtered cells with less than 100 genes; filtered cells: pct_mito <50, n_genes>50, n_counts>500, percent_hb<2, total_counts<9000, n_genes_by_counts<5000; added sex covariates and cell cycle phase"}'
#  '[E-MTAB-E9543] {"timestamp": "17122024_164056", "step": "Metadata harmonized for integration with other datasets"}'
#  '[E-MTAB-E9543] {"timestamp": "18122024_124621", "step": "Add metadata clusters using sentence-transformers"}'
#  '[E-MTAB-E9536] {"step": "create raw anndata after mapping, no filtering", "timestamp": "31102024_105424"}'
#  '[E-MTAB-E9536] {"timestamp": "13112024_101436", "step": "added qc metrics (generated with sctk), doublets info, filtered cells with less than 100 genes"}'
#  '[E-MTAB-E9536] {"timestamp": "13112024_104420", "step": "filtered cells based on consensus qc generated with sctk (default parameters), added sex covariates and cell cycle phase"}'
#  '[E-MTAB-E9536] {"timestamp": "17122024_164056", "step": "Metadata harmonized for integration with other datasets"}'
#  '[E-MTAB-E9536] {"timestamp": "18122024_124621", "step": "Add metadata clusters using sentence-transformers"}']

# %% [markdown]
# + Filter out genes that do not expressed

# %%
sc.pp.filter_genes(merged_data, min_counts=1)
merged_data
# Out:
# filtered out 27007 genes that are detected in less than 1 counts
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 460103 × 43704
#     obs: 'cell_id', 'Source Name', 'ENA_SAMPLE', 'BioSD_SAMPLE', 'organism', 'disease', 'organism_part', 'cell_type', 'growth_condition', 'developmental_stage', 'Material Type', 'Protocol REF', 'sample_id', 'LIBRARY_LAYOUT', 'cdna_read_size', 'cell_barcode_size', 'end_bias', 'library_construction', 'sample_barcode_size', 'umi_barcode_offset', 'umi_barcode_size', 'Performer', 'Assay Name', 'ENA_EXPERIMENT', 'ENA_RUN', 'time', 'time_unit', 'n_genes', 'doublet_scores', 'predicted_doublets', 'n_counts', 'log1p_n_counts', 'log1p_n_genes', 'percent_mito', 'n_counts_mito', 'percent_ribo', 'n_counts_ribo', 'percent_hb', 'n_counts_hb', 'percent_top50', 'cell_passed_qc', 'qc_cluster', 'cluster_passed_qc', 'consensus_fraction', 'consensus_passed_qc', 'total_counts', 'n_genes_by_counts', 'percent_chrY', 'XIST-counts', 'XIST-percentage', 'sex', 'S_score', 'G2M_score', 'Cell_cycle_phase', 'Study_name', 'ArrayExpress_ID', 'library_preparation_protocol', 'full_age', 'age_group', 'immunophenotype', 'metadata_cluster', 'barcode', 'category', 'Integrated_05', 'age', 'gestational_age', 'donor_id', 'passage', 'batch', 'sampling_site'
#     var: 'n_counts'
#     uns: 'cell_passed_qc_colors', 'cluster_passed_qc_colors', 'consensus_passed_qc_colors', 'processing_history'
#     obsm: 'X_umap_qc'
#     layers: 'ambiguous', 'spliced', 'unspliced'

# %%
del anndata_objects # to reduce memory usage

# %% [markdown]
# ## Visualize uncorrected datasets

# %%
adata_log = merged_data.copy()
sc.pp.normalize_total(adata_log, target_sum=1e6, exclude_highly_expressed=True)
sc.pp.log1p(adata_log)
# Out:
# normalizing counts per cell. The following highly-expressed genes are not considered during normalization factor computation:
# ['PLA2G2A', 'C1QB', 'GUCA2B', 'GUCA2A', 'YBX1', 'JUN', 'CLCA1', 'CLCA4', 'ATP1A1-AS1', 'REG4', 'S100A9', 'S100A12', 'S100A8', 'S100A6', 'RPS27', 'ITLN1', 'ITLN2', 'APOA2', 'PIGR', 'C1orf35', 'ACTG2', 'REG1A', 'REG3A', 'TMSB10', 'GNLY', 'FABP1', 'IGKV4-1', 'IGKV2D-29', 'IGKV2D-24', 'IGKV6D-21', 'IGKV3D-20', 'IGKV1D-16', 'IGKV1D-13', 'IGKV3D-11', 'GCG', 'CRYBA2', 'CCL20', 'GHRL', 'CCK', 'RBP2', 'MFSD1', 'SST', 'APOD', 'IGFBP7', 'FDCSP', 'ENSG00000286848', 'JCHAIN', 'GC', 'ALB', 'AFP', 'CXCL8', 'CXCL10', 'CXCL13', 'SPP1', 'MMRN1', 'RPL34', 'CCDC152', 'GZMA', 'ATG10', 'CXCL14', 'SPINK1', 'CD74', 'GPX3', 'FABP6', 'SOX4', 'ENSG00000271581', 'MLN', 'ENSG00000287089', 'CLPS', 'LINC01013', 'ACTB', 'AGR2', 'CD36', 'COL1A2', 'TAC1', 'ADAMDEC1', 'CLU', 'ENSG00000272256', 'RPL30-AS1', 'RPS6', 'SPINK4', 'CCL19', 'CCL21', 'TPM2', 'ENSG00000203396', 'TXN', 'GSN', 'RPL12', 'LCN2', 'LCN15', 'VIM-AS1', 'PSAP', 'C10orf55', 'ADIRF-AS1', 'SHLD2', 'ACTA2', 'PRADX', 'INS', 'BEST1', 'FTH1', 'TALAM1', 'ENSG00000285513', 'APOA4', 'APOC3', 'APOA1', 'APOA1-AS', 'TAGLN', 'GAPDH', 'ENSG00000269968', 'ENSG00000272173', 'CD69', 'MGP', 'MRPS35-DT', 'TROAP-AS1', 'RPS26', 'LYZ', 'ENSG00000257764', 'PHLDA1-AS1', 'NTS', 'BTG1-DT', 'UQCC6', 'TPT1', 'ENSG00000273149', 'RNASE1', 'FOS', 'HSP90AA1', 'CKB', 'IGHA2', 'IGHV2-70', 'THBS1', 'PHGR1', 'SNX22', 'RPLP1', 'ENSG00000279694', 'HBA2', 'ENSG00000290038', 'ENSG00000290010', 'TPSAB1', 'ZG16', 'MT2A', 'MT1G', 'MT1H', 'RPL13', 'ENO3', 'ENSG00000265401', 'CCL2', 'CCL11', 'GAST', 'PYY', 'GIP', 'COL1A1', 'H3-3B', 'TTR', 'JSRP1', 'ENSG00000267598', 'ENSG00000280194', 'YIF1B', 'ZFP36', 'CLC', 'RPS19', 'FTL', 'TFF3', 'TFF2', 'TFF1', 'PRAMENP', 'IGLV4-69', 'IGLV8-61', 'IGLV4-60', 'IGLV6-57', 'IGLV10-54', 'IGLV1-51', 'IGLV1-47', 'IGLV7-46', 'IGLV3-25', 'IGLV2-23', 'IGLV3-21', 'IGLV3-19', 'IGLV2-18', 'IGLV2-14', 'IGLV2-11', 'IGLV3-10', 'IGLV3-9', 'IGLV2-8', 'IGLV3-1', 'IGLL5', 'IGLC2', 'IGLC3', 'IGLC7', 'LGALS1', 'TMSB4X', 'TIMP1', 'PCSK1N', 'MT-RNR1', 'MT-RNR2', 'MT-ND1', 'MT-ND2', 'MT-CO1', 'MT-CO2', 'MT-ATP6', 'MT-CO3', 'MT-ND3', 'MT-ND4L', 'MT-ND4', 'MT-ND5', 'MT-ND6', 'MT-CYB', 'MUC2-1', 'ENSG00000288190', 'IGHA2-1', 'IGHE-1', 'IGHV3-33-1', 'ENSG00000278082', 'ENSG00000282150', 'IGHV1-69D-1', 'ENSG00000281759', 'HLA-DPA1-2', 'ENSG00000235952', 'ENSG00000231067', 'ENSG00000277856', 'ENSG00000275063']
#     finished (0:00:01)

# %%
sc.pp.pca(adata_log)
# Out:
# computing PCA
#     with n_comps=50
#     finished (0:02:15)

# %%
adata_log
# Out:
# AnnData object with n_obs × n_vars = 460103 × 43704
#     obs: 'cell_id', 'Source Name', 'ENA_SAMPLE', 'BioSD_SAMPLE', 'organism', 'disease', 'organism_part', 'cell_type', 'growth_condition', 'developmental_stage', 'Material Type', 'Protocol REF', 'sample_id', 'LIBRARY_LAYOUT', 'cdna_read_size', 'cell_barcode_size', 'end_bias', 'library_construction', 'sample_barcode_size', 'umi_barcode_offset', 'umi_barcode_size', 'Performer', 'Assay Name', 'ENA_EXPERIMENT', 'ENA_RUN', 'time', 'time_unit', 'n_genes', 'doublet_scores', 'predicted_doublets', 'n_counts', 'log1p_n_counts', 'log1p_n_genes', 'percent_mito', 'n_counts_mito', 'percent_ribo', 'n_counts_ribo', 'percent_hb', 'n_counts_hb', 'percent_top50', 'cell_passed_qc', 'qc_cluster', 'cluster_passed_qc', 'consensus_fraction', 'consensus_passed_qc', 'total_counts', 'n_genes_by_counts', 'percent_chrY', 'XIST-counts', 'XIST-percentage', 'sex', 'S_score', 'G2M_score', 'Cell_cycle_phase', 'Study_name', 'ArrayExpress_ID', 'library_preparation_protocol', 'full_age', 'age_group', 'immunophenotype', 'metadata_cluster', 'barcode', 'category', 'Integrated_05', 'age', 'gestational_age', 'donor_id', 'passage', 'batch', 'sampling_site'
#     var: 'n_counts'
#     uns: 'cell_passed_qc_colors', 'cluster_passed_qc_colors', 'consensus_passed_qc_colors', 'processing_history', 'log1p', 'pca'
#     obsm: 'X_umap_qc', 'X_pca'
#     varm: 'PCs'
#     layers: 'ambiguous', 'spliced', 'unspliced'

# %%
adata_log.obs['metadata_cluster'] = adata_log.obs['metadata_cluster'].astype(str)

# %%
with plt.rc_context():
    sc.set_figure_params(dpi=300, figsize=(15, 15))
    sc.set_figure_params(figsize=(10,10))
    sc.pl.pca(adata_log,color=["Study_name", "ArrayExpress_ID", 'disease', 'organism_part', 'developmental_stage', 'library_preparation_protocol', 'age_group', 'immunophenotype', 'category', 'sex', 'Cell_cycle_phase', 'metadata_cluster', 'growth_condition'], ncols=4, frameon=False, show=False)
    plt.savefig(f"integration_of_remapped_data/plots/all_datasets_uncorrected_PCA_categorical_values_unfiltered.png", bbox_inches="tight")
    plt.show()
    plt.close()

# %%
with plt.rc_context():
    sc.set_figure_params(dpi=300, figsize=(15, 15))
    sc.set_figure_params(figsize=(10,10))
    sc.pl.pca(adata_log,color=['n_genes', 'predicted_doublets', 'n_counts', 'percent_mito', 'percent_ribo', 'percent_hb', 'total_counts', 'n_genes_by_counts'], color_map = 'magma_r', ncols=4, frameon=False, show=False)
    plt.savefig(f"integration_of_remapped_data/plots/all_datasets_uncorrected_PCA_continious_values_unfiltered.png", bbox_inches="tight")
    plt.show()
    plt.close()

# %% [markdown]
# + Visualize uncorrected UMAP

# %%
sc.pp.neighbors(adata_log, n_neighbors=15, n_pcs=50)
sc.tl.umap(adata_log)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:42)
# computing UMAP
# 2024-12-18 13:03:58.695453: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-18 13:03:59.368858: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:455: UserWarning: Exited at iteration 192 with accuracies
# [5.04371452e-05 3.15956450e-05 3.12211876e-05 5.47200660e-04]
# not reaching the requested tolerance 3.3736228942871094e-05.
# Use iteration 184 instead with accuracy
# 0.0001426182305003315.
#
#   _, diffusion_map = lobpcg(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:455: UserWarning: Exited postprocessing with accuracies
# [3.15219200e-05 4.02758892e-05 3.20136072e-05 4.66661506e-04]
# not reaching the requested tolerance 3.3736228942871094e-05.
#   _, diffusion_map = lobpcg(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/umap/spectral.py:550: UserWarning: Spectral initialisation failed! The eigenvector solver
# failed. This is likely due to too small an eigengap. Consider
# adding some noise or jitter to your data.
#
# Falling back to random initialisation!
#   warn(
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm)
#     'umap', UMAP parameters (adata.uns) (0:11:54)

# %%
with plt.rc_context():
    sc.set_figure_params(dpi=300, figsize=(15, 15))
    sc.set_figure_params(figsize=(10,10))
    sc.pl.umap(adata_log,color=["Study_name", "ArrayExpress_ID", 'disease', 'organism_part', 'developmental_stage', 'library_preparation_protocol', 'age_group', 'immunophenotype', 'category', 'sex', 'Cell_cycle_phase', 'metadata_cluster', 'growth_condition'], ncols=4, frameon=False, show=False)
    plt.savefig(f"integration_of_remapped_data/plots/all_datasets_uncorrected_umap_categorical_values_unfiltered.png", bbox_inches="tight")
    plt.show()
    plt.close()

# %%
with plt.rc_context():
    sc.set_figure_params(dpi=300, figsize=(15, 15))
    sc.set_figure_params(figsize=(10,10))
    sc.pl.umap(adata_log,color=['n_genes', 'predicted_doublets', 'n_counts', 'percent_mito', 'percent_ribo', 'percent_hb', 'total_counts', 'n_genes_by_counts'], color_map = 'magma_r', ncols=4, frameon=False, show=False)
    plt.savefig(f"integration_of_remapped_data/plots/all_datasets_uncorrected_umap_continious_values_unfiltetred.png", bbox_inches="tight")
    plt.show()
    plt.close()

# %% [markdown]
# + We see that we have some low quality cells in the E-MTAB-9543 dataset, we will filter them out

# %%
adata_log = adata_log[~((adata_log.obs['ArrayExpress_ID'] == 'E-MTAB-9543') & (adata_log.obs['percent_mito'] > 25))]

adata_log.shape[0]
# Out:
# 435026

# %%
with plt.rc_context():
    sc.set_figure_params(dpi=300, figsize=(15, 15))
    sc.set_figure_params(figsize=(10,10))
    sc.pl.umap(adata_log,color=["Study_name", "ArrayExpress_ID", 'disease', 'organism_part', 'developmental_stage', 'library_preparation_protocol', 'age_group', 'immunophenotype', 'category', 'sex', 'Cell_cycle_phase', 'metadata_cluster', 'growth_condition'], ncols=4, frameon=False, show=False)
    plt.savefig(f"integration_of_remapped_data/plots/all_datasets_uncorrected_umap_categorical_values_filtered.png", bbox_inches="tight")
    plt.show()
    plt.close()

# %%
with plt.rc_context():
    sc.set_figure_params(dpi=300, figsize=(15, 15))
    sc.set_figure_params(figsize=(10,10))
    sc.pl.umap(adata_log,color=['n_genes', 'predicted_doublets', 'n_counts', 'percent_mito', 'percent_ribo', 'percent_hb', 'total_counts', 'n_genes_by_counts'], color_map = 'magma_r', ncols=4, frameon=False, show=False)
    plt.savefig(f"integration_of_remapped_data/plots/all_datasets_uncorrected_umap_continious_values_filtered.png", bbox_inches="tight")
    plt.show()
    plt.close()

# %%
with plt.rc_context():
    sc.set_figure_params(dpi=300, figsize=(15, 15))
    sc.set_figure_params(figsize=(10,10))
    sc.pl.pca(adata_log,color=["Study_name", "ArrayExpress_ID", 'disease', 'organism_part', 'developmental_stage', 'library_preparation_protocol', 'age_group', 'immunophenotype', 'category', 'sex', 'Cell_cycle_phase', 'metadata_cluster', 'growth_condition',], ncols=4, frameon=False, show=False)
    plt.savefig(f"integration_of_remapped_data/plots/all_datasets_uncorrected_PCA_categorical_values_filtered.png", bbox_inches="tight")
    plt.show()
    plt.close()

# %%
with plt.rc_context():
    sc.set_figure_params(dpi=300, figsize=(15, 15))
    sc.set_figure_params(figsize=(10,10))
    sc.pl.pca(adata_log,color=['n_genes', 'predicted_doublets', 'n_counts', 'percent_mito', 'percent_ribo', 'percent_hb', 'total_counts', 'n_genes_by_counts'], color_map = 'magma_r', ncols=4, frameon=False, show=False)
    plt.savefig(f"integration_of_remapped_data/plots/all_datasets_uncorrected_PCA_continious_values_filtered.png", bbox_inches="tight")
    plt.show()
    plt.close()

# %% [markdown]
# + Repeat the filtering on the raw dataset

# %%
merged_data = merged_data[~((merged_data.obs['ArrayExpress_ID'] == 'E-MTAB-9543') & (merged_data.obs['percent_mito'] > 25))]

merged_data.shape[0]
# Out:
# 435026

# %% [markdown]
# + Copy uncorrected PCA and UMAP to raw dataset

# %%
merged_data.obsm['X_pca'] = adata_log.obsm['X_pca'].copy()
merged_data.obsm['umap_uncorrected'] = adata_log.obsm['X_umap'].copy()
# Out:
# /tmp/ipykernel_3403777/1638592842.py:1: ImplicitModificationWarning: Setting element `.obsm['X_pca']` of view, initializing view as actual.
#   merged_data.obsm['X_pca'] = adata_log.obsm['X_pca'].copy()
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
del adata_log # to reduce memory usage

# %% [markdown]
# + Also, lets filter out cells with conditions we do not need

# %%
merged_data = merged_data[merged_data.obs['disease'] != "Crohn's disease"]
merged_data.shape[0]
# Out:
# 407340

# %%
merged_data = merged_data[merged_data.obs['organism_part'] != "mesenteric lymph node"]
merged_data.shape[0]
# Out:
# 402343

# %%
merged_data.obs['metadata_cluster'] = merged_data.obs['metadata_cluster'].astype(str)
# Out:
# /tmp/ipykernel_3403777/3171495823.py:1: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   merged_data.obs['metadata_cluster'] = merged_data.obs['metadata_cluster'].astype(str)
# /home/amaguza/.local/share/hatch/env/virtual/single-cell-project/HC5eoTg7/single_cell_project/lib/python3.10/site-packages/anndata/_core/anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %% [markdown]
# ## Save prepared dataset

# %%
timestamp = datetime.now().strftime('%d%m%Y_%H%M%S')
current_history = merged_data.uns['processing_history'].tolist()

new_entry = json.dumps({
    'timestamp': timestamp,
    'step': 'Merged all datasets, filtered cells from E-MTAB-9543 with percent_mito] > 25; added uncorrected umap and pca; filtered out Crohn\'s disease and mesenteric lymph node',
})
current_history.append(new_entry)

merged_data.uns['processing_history'] = current_history

# %%
merged_data.obs['age'] = merged_data.obs['age'].astype(str)
merged_data.obs['donor_id'] = merged_data.obs['donor_id'].astype(str)

# %%
project = 'gut'
species = 'hs'
name = 'AM'
counts = 'raw'
atribute = 'merged_datasets'

merged_data.write_h5ad(f"integration_of_remapped_data/{project}_{species}_{atribute}_{name}_{timestamp}_{counts}.h5ad")
