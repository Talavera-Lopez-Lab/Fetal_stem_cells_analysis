# %% [markdown]
# #### Labels transfer from fetal stem cells single-cell RNA sequencing cells to stem cells found in Xenium add-on data
# - **Developed by:** Anna Maguza
# - **Place:** Wuerzburg Institute for System Immunology
# - **Date:** 21st March 2024

# %% [markdown]
# ##### Import packages

# %%
import scvi
import torch
import anndata
import warnings
import numpy as np
import scanpy as sc
import pandas as pd
import plotnine as p
from pywaffle import Waffle
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Setup working environment

# %%
sc.settings.verbosity = 3
sc.logging.print_versions()
sc.settings.set_figure_params(dpi = 180, color_map = 'magma_r', dpi_save = 300, vector_friendly = True, format = 'svg')
# Out:
# -----
# anndata     0.10.3
# scanpy      1.9.6
# -----
# PIL                         10.1.0
# absl                        NA
# aiohttp                     3.8.6
# aiosignal                   1.3.1
# annotated_types             0.6.0
# anyio                       NA
# arrow                       1.3.0
# asttokens                   NA
# async_timeout               4.0.3
# attr                        23.1.0
# attrs                       23.1.0
# babel                       2.13.1
# backoff                     2.2.1
# brotli                      1.1.0
# bs4                         4.12.2
# certifi                     2023.07.22
# cffi                        1.16.0
# charset_normalizer          3.3.2
# chex                        0.1.7
# click                       8.1.7
# colorama                    0.4.6
# comm                        0.1.4
# contextlib2                 NA
# croniter                    NA
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.8.0
# decorator                   5.1.1
# deepdiff                    6.6.1
# defusedxml                  0.7.1
# docrep                      0.3.2
# etils                       1.5.2
# exceptiongroup              1.1.3
# executing                   2.0.1
# fastapi                     0.104.1
# fastjsonschema              NA
# flax                        0.7.5
# fqdn                        NA
# frozenlist                  1.4.0
# fsspec                      2023.10.0
# get_annotations             NA
# h5py                        3.10.0
# idna                        3.4
# igraph                      0.11.3
# importlib_resources         NA
# ipykernel                   6.26.0
# isoduration                 NA
# jax                         0.4.20
# jaxlib                      0.4.20
# jedi                        0.19.1
# jinja2                      3.1.2
# joblib                      1.3.2
# json5                       NA
# jsonpointer                 2.4
# jsonschema                  4.19.2
# jsonschema_specifications   NA
# jupyter_events              0.8.0
# jupyter_server              2.9.1
# jupyterlab_server           2.25.0
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# lightning                   2.0.9.post0
# lightning_cloud             0.5.50
# lightning_utilities         0.9.0
# llvmlite                    0.40.1
# markupsafe                  2.1.3
# matplotlib                  3.8.1
# mizani                      0.11.0
# ml_collections              NA
# ml_dtypes                   0.3.1
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.0.7
# mudata                      0.2.3
# multidict                   6.0.4
# multipart                   0.0.6
# multipledispatch            0.6.0
# natsort                     8.4.0
# nbformat                    5.9.2
# numba                       0.57.1
# numpy                       1.24.4
# numpyro                     0.13.2
# opt_einsum                  v3.3.0
# optax                       0.1.7
# ordered_set                 4.1.0
# overrides                   NA
# packaging                   23.2
# pandas                      1.5.3
# parso                       0.8.3
# pexpect                     4.8.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                3.11.0
# plotnine                    0.13.2
# prometheus_client           NA
# prompt_toolkit              3.0.39
# psutil                      5.9.5
# ptyprocess                  0.7.0
# pure_eval                   0.2.2
# pydantic                    2.1.1
# pydantic_core               2.4.0
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pydot                       2.0.0
# pygments                    2.16.1
# pyparsing                   3.1.1
# pyro                        1.8.6
# pythonjsonlogger            NA
# pytz                        2023.3.post1
# pywaffle                    NA
# referencing                 NA
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rich                        NA
# rpds                        NA
# scipy                       1.11.3
# scvi                        1.1.2
# send2trash                  NA
# session_info                1.0.0
# setuptools                  68.2.2
# six                         1.16.0
# sklearn                     1.3.2
# sniffio                     1.3.0
# socks                       1.7.1
# soupsieve                   2.5
# sparse                      0.14.0
# stack_data                  0.6.2
# starlette                   0.27.0
# sympy                       1.12
# texttable                   1.7.0
# threadpoolctl               3.2.0
# tomli                       2.0.1
# toolz                       0.12.0
# torch                       2.1.0+cu121
# torchgen                    NA
# torchmetrics                1.2.0
# tornado                     6.3.3
# tqdm                        4.66.1
# traitlets                   5.13.0
# tree                        0.1.8
# typing_extensions           NA
# uri_template                NA
# urllib3                     2.0.7
# uvicorn                     0.24.0.post1
# vscode                      NA
# wcwidth                     0.2.9
# webcolors                   1.13
# websocket                   1.6.4
# websockets                  12.0
# wrapt                       1.16.0
# yaml                        6.0.1
# yarl                        1.9.2
# zipp                        NA
# zmq                         25.1.1
# zoneinfo                    NA
# -----
# IPython             8.17.2
# jupyter_client      8.5.0
# jupyter_core        5.5.0
# jupyterlab          4.0.8
# notebook            7.0.6
# -----
# Python 3.9.18 | packaged by conda-forge | (main, Aug 30 2023, 03:49:32) [GCC 12.3.0]
# Linux-6.6.14-100.fc38.x86_64-x86_64-with-glibc2.37
# -----
# Session information updated at 2024-03-21 12:49

# %%
warnings.simplefilter(action = 'ignore')
scvi.settings.seed = 1712
# %config InlineBackend.print_figure_kwargs = {'facecolor' : "w"}
# %config InlineBackend.figure_format = 'retina'
torch.set_float32_matmul_precision('medium')
# Out:
# Global seed set to 1712

# %%
arches_params = dict(
    use_layer_norm = "both",
    use_batch_norm = "none",
    encode_covariates = True,
    dropout_rate = 0.2,
    n_layers = 3,
)

# %%
def X_is_raw(adata):
    return np.array_equal(adata.X.sum(axis=0).astype(int), adata.X.sum(axis=0))

# %% [markdown]
# ### Read in data

# %%
adata_xenium = sc.read_h5ad('/mnt/LaCIE/annaM/gut_project/Processed_data/Gut_data/10X_Xenium_data/epithelial_scRNA_and_Xenium_add_on_scANVI.h5ad')

# %%
X_is_raw(adata_xenium)
# Out:
# True

# %%
adata_xenium = adata_xenium[adata_xenium.obs['Study_name'] == '10X_Xenium_gut_data', :]

# %%
adata_fetal_sc = sc.read_h5ad('/mnt/LaCIE/annaM/gut_project/Processed_data/Gut_data/Fetal_stem_cells/Fetal_healthy_stem_cells_leiden.h5ad')

# %%
X_is_raw(adata_fetal_sc)
# Out:
# True

# %% [markdown]
# + Check common genes between 2 datasets

# %%
common_genes = adata_xenium.var_names.intersection(adata_fetal_sc.var_names)
print(len(common_genes))
# Out:
# 377

# %% [markdown]
# + Save raw counts

# %%
adata_fetal_sc.raw = adata_fetal_sc

# %%
adata_xenium.raw = adata_xenium

# %% [markdown]
# + Prepare obs

# %%
adata_xenium.obs
# Out:
#            Sample_ID   Cell Type           Study_name        Donor_ID  \
# aafdcfgh-1       NaN  Epithelial  10X_Xenium_gut_data  Xenium_donor_1
# aafdjmak-1       NaN  Epithelial  10X_Xenium_gut_data  Xenium_donor_1
# aafeagch-1       NaN  Epithelial  10X_Xenium_gut_data  Xenium_donor_1
# aafedihe-1       NaN  Epithelial  10X_Xenium_gut_data  Xenium_donor_1
# aafeghlf-1       NaN  Epithelial  10X_Xenium_gut_data  Xenium_donor_1
# ...              ...         ...                  ...             ...
# oijpleco-1       NaN  Epithelial  10X_Xenium_gut_data  Xenium_donor_1
# oikabfkp-1       NaN  Epithelial  10X_Xenium_gut_data  Xenium_donor_1
# oikalpjm-1       NaN  Epithelial  10X_Xenium_gut_data  Xenium_donor_1
# oikamhom-1       NaN  Epithelial  10X_Xenium_gut_data  Xenium_donor_1
# oikaoaef-1       NaN  Epithelial  10X_Xenium_gut_data  Xenium_donor_1
#
#            Diagnosis  Age Region code Fraction  Sex  \
# aafdcfgh-1       NaN  NaN         NaN      NaN  NaN
# aafdjmak-1       NaN  NaN         NaN      NaN  NaN
# aafeagch-1       NaN  NaN         NaN      NaN  NaN
# aafedihe-1       NaN  NaN         NaN      NaN  NaN
# aafeghlf-1       NaN  NaN         NaN      NaN  NaN
# ...              ...  ...         ...      ...  ...
# oijpleco-1       NaN  NaN         NaN      NaN  NaN
# oikabfkp-1       NaN  NaN         NaN      NaN  NaN
# oikalpjm-1       NaN  NaN         NaN      NaN  NaN
# oikamhom-1       NaN  NaN         NaN      NaN  NaN
# oikaoaef-1       NaN  NaN         NaN      NaN  NaN
#
#            Library_Preparation_Protocol  ... total_counts total_counts_mito  \
# aafdcfgh-1                       Xenium  ...          NaN               NaN
# aafdjmak-1                       Xenium  ...          NaN               NaN
# aafeagch-1                       Xenium  ...          NaN               NaN
# aafedihe-1                       Xenium  ...          NaN               NaN
# aafeghlf-1                       Xenium  ...          NaN               NaN
# ...                                 ...  ...          ...               ...
# oijpleco-1                       Xenium  ...          NaN               NaN
# oikabfkp-1                       Xenium  ...          NaN               NaN
# oikalpjm-1                       Xenium  ...          NaN               NaN
# oikamhom-1                       Xenium  ...          NaN               NaN
# oikaoaef-1                       Xenium  ...          NaN               NaN
#
#            pct_counts_mito total_counts_ribo pct_counts_ribo Cell_ID  \
# aafdcfgh-1             NaN               NaN             NaN     NaN
# aafdjmak-1             NaN               NaN             NaN     NaN
# aafeagch-1             NaN               NaN             NaN     NaN
# aafedihe-1             NaN               NaN             NaN     NaN
# aafeghlf-1             NaN               NaN             NaN     NaN
# ...                    ...               ...             ...     ...
# oijpleco-1             NaN               NaN             NaN     NaN
# oikabfkp-1             NaN               NaN             NaN     NaN
# oikalpjm-1             NaN               NaN             NaN     NaN
# oikamhom-1             NaN               NaN             NaN     NaN
# oikaoaef-1             NaN               NaN             NaN     NaN
#
#            _scvi_batch _scvi_labels seed_labels          C_scANVI
# aafdcfgh-1           0           12     Unknown  Epithelial_cells
# aafdjmak-1           0           12     Unknown        Stem_cells
# aafeagch-1           0           12     Unknown      Goblet_cells
# aafedihe-1           0           12     Unknown        Stem_cells
# aafeghlf-1           0           12     Unknown        Stem_cells
# ...                ...          ...         ...               ...
# oijpleco-1           0           12     Unknown  Epithelial_cells
# oikabfkp-1           0           12     Unknown  Epithelial_cells
# oikalpjm-1           0           12     Unknown  Epithelial_cells
# oikamhom-1           0           12     Unknown  Epithelial_cells
# oikaoaef-1           0           12     Unknown  Epithelial_cells
#
# [99893 rows x 30 columns]

# %%
adata_xenium = adata_xenium[adata_xenium.obs['C_scANVI'] == 'Stem_cells']

# %%
adata_fetal_sc.obs['seed_labels'] = adata_fetal_sc.obs['cluster'].copy()

# %%
adata_xenium.obs['seed_labels'] = 'Unknown'

# %%
adata_xenium.obs['Donor_ID'] = 'Xenium_donor_1'

# %%
adata_xenium.obs['Library_Preparation_Protocol'] = 'Xenium'

# %%
adata_xenium.obs['Study_name'] = '10X_Xenium_gut_data'

# %% [markdown]
# + Concatenate datasets

# %%
adata = adata_fetal_sc.concatenate(adata_xenium, batch_key = 'dataset', batch_categories = ['reference', 'query'], join='inner', index_unique = None)

# %% [markdown]
# + Run scVI

# %%
adata.layers['counts'] = adata.X.copy()

# %%
adata.obs['seed_labels'] = adata.obs['seed_labels'].astype('category')

# %%
adata.obs['seed_labels'].value_counts()
# Out:
# Unknown               26674
# MTRNR2L12+ASS1+_SC     3979
# RPS10+_RPS17+_SC       3544
# FXYD3+_CKB+_SC          294
# Name: seed_labels, dtype: int64

# %%
scvi.model.SCVI.setup_anndata(adata, 
                              categorical_covariate_keys=['Donor_ID', 
                                                          'Library_Preparation_Protocol', 
                                                          'Study_name'],
                              labels_key = "seed_labels", 
                              layer = 'counts')
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
scvi_model = scvi.model.SCVI(adata,
                            n_latent = 50, 
                            n_layers = 3, 
                            dispersion = 'gene-batch', 
                            gene_likelihood = 'nb')

# %%
scvi_model.train(30, 
                 check_val_every_n_epoch = 1, 
                 enable_progress_bar = True, 
                 accelerator = "gpu",
                 devices = [0])
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Epoch 30/30: 100%|█| 30/30 [00:46<00:00,  1.52s/it, v_num=1, train_loss_step=132, train_loss_epoch=129
# `Trainer.fit` stopped: `max_epochs=30` reached.
# Epoch 30/30: 100%|█| 30/30 [00:46<00:00,  1.54s/it, v_num=1, train_loss_step=132, train_loss_epoch=129

# %%
adata.obsm['X_scvi'] = scvi_model.get_latent_representation()

# %% [markdown]
# #### Evaluate model performance using the [_Svensson_](https://www.nxn.se/valent/2023/8/10/training-scvi-posterior-predictive-distributions-over-epochs) method

# %%
history_df = (
    scvi_model.history['elbo_train'].astype(float)
    .join(scvi_model.history['elbo_validation'].astype(float))
    .reset_index()
    .melt(id_vars = ['epoch'])
)

p.options.figure_size = 12, 6

p_ = (
    p.ggplot(p.aes(x = 'epoch', y = 'value', color = 'variable'), history_df.query('epoch > 0'))
    + p.geom_line()
    + p.geom_point()
    + p.scale_color_manual({'elbo_train': 'black', 'elbo_validation': 'red'})
    + p.theme_minimal()
)

print(p_)

# %% [markdown]
# #### Label transfer with `scANVI`

# %%
scanvi_model = scvi.model.SCANVI.from_scvi_model(scvi_model, 'Unknown')

# %%
scanvi_model.train(50, 
                   check_val_every_n_epoch = 1, 
                   enable_progress_bar = True,
                   accelerator = "gpu",
                   devices = [0])
# Out:
# INFO     Training for 50 epochs.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Epoch 50/50: 100%|█| 50/50 [03:05<00:00,  3.55s/it, v_num=1, train_loss_step=125, train_loss_epoch=124
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 50/50: 100%|█| 50/50 [03:05<00:00,  3.71s/it, v_num=1, train_loss_step=125, train_loss_epoch=124

# %%
adata.obs["C_scANVI"] = scanvi_model.predict(adata)

# %% [markdown]
# ### Explore model performance using the [_Svensson_](https://www.nxn.se/valent/2023/8/10/training-scvi-posterior-predictive-distributions-over-epochs) method

# %%
history_df = (
    scanvi_model.history['elbo_train'].astype(float)
    .join(scanvi_model.history['elbo_validation'].astype(float))
    .reset_index()
    .melt(id_vars = ['epoch'])
)

p.options.figure_size = 12, 6

p_ = (
    p.ggplot(p.aes(x = 'epoch', y = 'value', color = 'variable'), history_df.query('epoch > 0'))
    + p.geom_line()
    + p.geom_point()
    + p.scale_color_manual({'elbo_train': 'black', 'elbo_validation': 'red'})
    + p.theme_minimal()
)

p_.save('fig1.png', dpi = 300)

print(p_)

# %% [markdown]
# - Extract latent representation

# %%
adata.obsm["X_scANVI"] = scanvi_model.get_latent_representation(adata)

# %% [markdown]
# + Visualize dataset

# %%
sc.pp.neighbors(adata, use_rep = "X_scANVI", n_neighbors = 50, metric = 'minkowski')
sc.tl.umap(adata, min_dist = 0.2, spread = 2, random_state = 1712)
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:23)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:16)

# %%
sc.set_figure_params(dpi = 300, figsize=(10,5))
sc.pl.umap(adata, color = ['Study_name', 'seed_labels', 'C_scANVI', 'Library_Preparation_Protocol', 'Donor_ID'], ncols = 3, frameon = False, size = 6)

# %%
adata.write('/mnt/LaCIE/annaM/gut_project/Processed_data/Gut_data/10X_Xenium_data/Stem_cells_scRNA_and_Xenium_add_on_scANVI.h5ad')

# %% [markdown]
# + Check scIB metrics

# %%
import anndata as an
import scanpy as sc
from rich import print
import scib
import scib.metrics

# %%
from scib_metrics.benchmark import Benchmarker
# Out:
# /home/amaguza/miniforge3/envs/scvi_env/lib/python3.9/site-packages/scib_metrics/_types.py:9: DeprecationWarning: jax.random.KeyArray is deprecated. Use jax.Array for annotations, and jax.dtypes.issubdtype(arr.dtype, jax.dtypes.prng_key) for runtime detection of typed prng keys (i.e. keys created with jax.random.key).
# For more information, see https://jax.readthedocs.io/en/latest/jep/9263-typed-keys.html
# /home/amaguza/miniforge3/envs/scvi_env/lib/python3.9/site-packages/scib_metrics/utils/_utils.py:40: DeprecationWarning: jax.random.KeyArray is deprecated. Use jax.Array for annotations, and jax.dtypes.issubdtype(arr.dtype, jax.dtypes.prng_key) for runtime detection of typed prng keys (i.e. keys created with jax.random.key).
# For more information, see https://jax.readthedocs.io/en/latest/jep/9263-typed-keys.html
# /home/amaguza/miniforge3/envs/scvi_env/lib/python3.9/site-packages/scib_metrics/utils/_kmeans.py:21: DeprecationWarning: jax.random.KeyArray is deprecated. Use jax.Array for annotations, and jax.dtypes.issubdtype(arr.dtype, jax.dtypes.prng_key) for runtime detection of typed prng keys (i.e. keys created with jax.random.key).
# For more information, see https://jax.readthedocs.io/en/latest/jep/9263-typed-keys.html
# /home/amaguza/miniforge3/envs/scvi_env/lib/python3.9/site-packages/scib_metrics/utils/_kmeans.py:31: DeprecationWarning: jax.random.KeyArray is deprecated. Use jax.Array for annotations, and jax.dtypes.issubdtype(arr.dtype, jax.dtypes.prng_key) for runtime detection of typed prng keys (i.e. keys created with jax.random.key).
# For more information, see https://jax.readthedocs.io/en/latest/jep/9263-typed-keys.html

# %%
bm = Benchmarker(
    adata,
    batch_key='Donor_ID',
    label_key='C_scANVI',
    embedding_obsm_keys=['X_scANVI', 'X_scVI', 'X_pca', 'X_umap'],
    n_jobs=-1
)

bm.benchmark()
# Out:
# computing PCA
#     with n_comps=50
#     finished (0:00:00)
# Computing neighbors: 100%|██████████████████████████████████████████████| 4/4 [01:39<00:00, 24.90s/it]
# Embeddings: 100%|███████████████████████████████████████████████████████| 4/4 [05:54<00:00, 88.66s/it]

# %%
bm.plot_results_table(min_max_scale=False)
