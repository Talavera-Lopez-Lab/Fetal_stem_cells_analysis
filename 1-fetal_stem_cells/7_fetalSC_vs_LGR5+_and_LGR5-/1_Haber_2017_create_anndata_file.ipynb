# %% [markdown]
# ### Create anndata object for Haber, 2017 LGR5+ stem cells
#
# - **Developed by:** Anna Maguza
# - **Affilation:** Faculty of Medicine, Würzburg University
# - **Date of creation:** 19th August 2024
# - **Last modified date:** 20th August 2024

# %% [markdown]
# + Import packages

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import anndata as ad

# %% [markdown]
# + Load datasets

# %%
AtlasFullLength_TPM = pd.read_csv('/../../../gut_project/raw_fastq_files/Haber_2017/GSE92332/GSE92332_AtlasFullLength_TPM.txt', sep='\t', index_col=0)
AtlasFullLength_TPM = AtlasFullLength_TPM.T
AtlasFullLength_TPM.head()
# Out:
#                                    0610005C13Rik  0610007N19Rik  \
# S634_Lgr5GFP_M7_GFPLow_Enterocyte         103.90          21.93
# S745_Lgr5GFP_M7_GFPLow_Stem                 0.00          70.47
# S856_Lgr5GFP_M7_GFPLow_Stem                 8.99          20.84
# S967_Lgr5GFP_M7_GFPLow_Goblet               0.00          67.15
# S1078_Lgr5GFP_M7_GFPLow_Goblet             50.94          36.25
#
#                                    0610007P14Rik  0610008F07Rik  \
# S634_Lgr5GFP_M7_GFPLow_Enterocyte         150.61            8.6
# S745_Lgr5GFP_M7_GFPLow_Stem                 0.00            0.0
# S856_Lgr5GFP_M7_GFPLow_Stem                 0.00            0.0
# S967_Lgr5GFP_M7_GFPLow_Goblet             212.32            0.0
# S1078_Lgr5GFP_M7_GFPLow_Goblet            104.89            0.0
#
#                                    0610009B14Rik  0610009B22Rik  \
# S634_Lgr5GFP_M7_GFPLow_Enterocyte            0.0          59.52
# S745_Lgr5GFP_M7_GFPLow_Stem                  0.0          10.22
# S856_Lgr5GFP_M7_GFPLow_Stem                  0.0          76.65
# S967_Lgr5GFP_M7_GFPLow_Goblet                0.0          64.97
# S1078_Lgr5GFP_M7_GFPLow_Goblet               0.0          63.68
#
#                                    0610009D07Rik  0610009L18Rik  \
# S634_Lgr5GFP_M7_GFPLow_Enterocyte          33.52            0.0
# S745_Lgr5GFP_M7_GFPLow_Stem                51.87            0.0
# S856_Lgr5GFP_M7_GFPLow_Stem               219.94            0.0
# S967_Lgr5GFP_M7_GFPLow_Goblet              45.24            0.0
# S1078_Lgr5GFP_M7_GFPLow_Goblet             93.14            0.0
#
#                                    0610009O20Rik  0610010B08Rik  ...  Zxda  \
# S634_Lgr5GFP_M7_GFPLow_Enterocyte           1.08           0.64  ...  0.00
# S745_Lgr5GFP_M7_GFPLow_Stem                54.82          45.11  ...  0.22
# S856_Lgr5GFP_M7_GFPLow_Stem                57.28           7.79  ...  0.00
# S967_Lgr5GFP_M7_GFPLow_Goblet             135.89           0.00  ...  0.00
# S1078_Lgr5GFP_M7_GFPLow_Goblet              1.05           0.00  ...  0.39
#
#                                    Zxdb  Zxdc  Zyg11a  Zyg11b    Zyx  Zzef1  \
# S634_Lgr5GFP_M7_GFPLow_Enterocyte  1.67  1.04     0.0    3.82  11.72  55.49
# S745_Lgr5GFP_M7_GFPLow_Stem        0.00  7.72     0.0   12.01   3.77   4.03
# S856_Lgr5GFP_M7_GFPLow_Stem        0.00  0.00     0.0    0.26   0.00  14.46
# S967_Lgr5GFP_M7_GFPLow_Goblet      0.00  0.00     0.0    5.01   0.00  33.99
# S1078_Lgr5GFP_M7_GFPLow_Goblet     0.00  0.00     0.0    0.47   0.00  16.56
#
#                                     Zzz3    a  l7Rn6
# S634_Lgr5GFP_M7_GFPLow_Enterocyte   0.00  0.0   5.99
# S745_Lgr5GFP_M7_GFPLow_Stem         0.00  0.0  53.27
# S856_Lgr5GFP_M7_GFPLow_Stem         0.56  0.0  57.09
# S967_Lgr5GFP_M7_GFPLow_Goblet       0.00  0.0  37.72
# S1078_Lgr5GFP_M7_GFPLow_Goblet     15.39  0.0   0.00
#
# [5 rows x 20108 columns]

# %%
AtlasFullLength_TPM['barcode'] = AtlasFullLength_TPM.index.copy()

# %%
AtlasFullLength_TPM[['barcode', 'Gene_marker', 'Donor_ID', 'GFP_intensity', 'Cell_Type']] = AtlasFullLength_TPM['barcode'].str.split('_', expand=True)

# %%
AtlasFullLength_TPM.head()
# Out:
#                                    0610005C13Rik  0610007N19Rik  \
# S634_Lgr5GFP_M7_GFPLow_Enterocyte         103.90          21.93
# S745_Lgr5GFP_M7_GFPLow_Stem                 0.00          70.47
# S856_Lgr5GFP_M7_GFPLow_Stem                 8.99          20.84
# S967_Lgr5GFP_M7_GFPLow_Goblet               0.00          67.15
# S1078_Lgr5GFP_M7_GFPLow_Goblet             50.94          36.25
#
#                                    0610007P14Rik  0610008F07Rik  \
# S634_Lgr5GFP_M7_GFPLow_Enterocyte         150.61            8.6
# S745_Lgr5GFP_M7_GFPLow_Stem                 0.00            0.0
# S856_Lgr5GFP_M7_GFPLow_Stem                 0.00            0.0
# S967_Lgr5GFP_M7_GFPLow_Goblet             212.32            0.0
# S1078_Lgr5GFP_M7_GFPLow_Goblet            104.89            0.0
#
#                                    0610009B14Rik  0610009B22Rik  \
# S634_Lgr5GFP_M7_GFPLow_Enterocyte            0.0          59.52
# S745_Lgr5GFP_M7_GFPLow_Stem                  0.0          10.22
# S856_Lgr5GFP_M7_GFPLow_Stem                  0.0          76.65
# S967_Lgr5GFP_M7_GFPLow_Goblet                0.0          64.97
# S1078_Lgr5GFP_M7_GFPLow_Goblet               0.0          63.68
#
#                                    0610009D07Rik  0610009L18Rik  \
# S634_Lgr5GFP_M7_GFPLow_Enterocyte          33.52            0.0
# S745_Lgr5GFP_M7_GFPLow_Stem                51.87            0.0
# S856_Lgr5GFP_M7_GFPLow_Stem               219.94            0.0
# S967_Lgr5GFP_M7_GFPLow_Goblet              45.24            0.0
# S1078_Lgr5GFP_M7_GFPLow_Goblet             93.14            0.0
#
#                                    0610009O20Rik  0610010B08Rik  ...    Zyx  \
# S634_Lgr5GFP_M7_GFPLow_Enterocyte           1.08           0.64  ...  11.72
# S745_Lgr5GFP_M7_GFPLow_Stem                54.82          45.11  ...   3.77
# S856_Lgr5GFP_M7_GFPLow_Stem                57.28           7.79  ...   0.00
# S967_Lgr5GFP_M7_GFPLow_Goblet             135.89           0.00  ...   0.00
# S1078_Lgr5GFP_M7_GFPLow_Goblet              1.05           0.00  ...   0.00
#
#                                    Zzef1   Zzz3    a  l7Rn6  barcode  \
# S634_Lgr5GFP_M7_GFPLow_Enterocyte  55.49   0.00  0.0   5.99     S634
# S745_Lgr5GFP_M7_GFPLow_Stem         4.03   0.00  0.0  53.27     S745
# S856_Lgr5GFP_M7_GFPLow_Stem        14.46   0.56  0.0  57.09     S856
# S967_Lgr5GFP_M7_GFPLow_Goblet      33.99   0.00  0.0  37.72     S967
# S1078_Lgr5GFP_M7_GFPLow_Goblet     16.56  15.39  0.0   0.00    S1078
#
#                                    Gene_marker  Donor_ID  GFP_intensity  \
# S634_Lgr5GFP_M7_GFPLow_Enterocyte      Lgr5GFP        M7         GFPLow
# S745_Lgr5GFP_M7_GFPLow_Stem            Lgr5GFP        M7         GFPLow
# S856_Lgr5GFP_M7_GFPLow_Stem            Lgr5GFP        M7         GFPLow
# S967_Lgr5GFP_M7_GFPLow_Goblet          Lgr5GFP        M7         GFPLow
# S1078_Lgr5GFP_M7_GFPLow_Goblet         Lgr5GFP        M7         GFPLow
#
#                                     Cell_Type
# S634_Lgr5GFP_M7_GFPLow_Enterocyte  Enterocyte
# S745_Lgr5GFP_M7_GFPLow_Stem              Stem
# S856_Lgr5GFP_M7_GFPLow_Stem              Stem
# S967_Lgr5GFP_M7_GFPLow_Goblet          Goblet
# S1078_Lgr5GFP_M7_GFPLow_Goblet         Goblet
#
# [5 rows x 20113 columns]

# %%
X = AtlasFullLength_TPM.iloc[:, 1:20108] 
var = pd.DataFrame(index=AtlasFullLength_TPM.columns[1:20108])
obs = AtlasFullLength_TPM.iloc[:, 20108:20114]

adata = ad.AnnData(X=X.values, var=var, obs=obs)

# %%
adata.write('/../../../gut_project/raw_fastq_files/Haber_2017/Haber_2017_Smartseq_LGR5_FACS_data.h5ad')

# %% [markdown]
# + Add human orthologue genes

# %%
adata_copy = adata.copy()

# %%
human_mouse_orthologues = pd.read_csv('/../../../ensembl_data/mouse_to_human_orthologues_ensembl.txt', sep='\t', index_col=0)

# %%
duplicates = human_mouse_orthologues['Gene name'].duplicated()
num_duplicates = duplicates.sum()
num_duplicates
# Out:
# 85408

# %%
human_mouse_orthologues_cleaned = human_mouse_orthologues.loc[
    human_mouse_orthologues.groupby('Gene name')['%id. target Human gene identical to query gene'].idxmax()
]
human_mouse_orthologues_cleaned = human_mouse_orthologues_cleaned.reset_index(drop=True)

# %%
human_mouse_orthologues_cleaned = human_mouse_orthologues_cleaned.drop_duplicates(subset='Gene name')

# %%
intersect = np.intersect1d(human_mouse_orthologues_cleaned['Gene name'], adata.var.index)
len(intersect)
# Out:
# 14814

# %%
human_mouse_orthologues_cleaned = human_mouse_orthologues_cleaned.loc[human_mouse_orthologues_cleaned['Gene name'].isin(intersect)]
adata = adata[:, intersect]
# Out:
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):

# %%
adata.var['original_mouse_gene_name'] = adata.var.index.copy()
# Out:
# /tmp/ipykernel_460533/2987893276.py:1: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['original_mouse_gene_name'] = adata.var.index.copy()

# %%
adata.var = adata.var.merge(human_mouse_orthologues_cleaned, left_index=True, right_on='Gene name')
# Out:
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:788: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     [0, 14, 18, 24, 30]
#
#     Inferred to be: integer
#
#   value_idx = self._prep_dim_index(value.index, attr)

# %%
adata.var = adata.var.set_index('Human gene name')

# %%
adata.var.index = adata.var.index.astype(str)

# %%
adata.write('/../../../gut_project/Processed_data/Gut_data/Haber_2017_Smartseq/Haber_2017_Smartseq_LGR5_FACS_data_human_orthologues_genes.h5ad')

# %% [markdown]
# + Create anndata object from re-mapped data

# %%
countmatrix = pd.read_csv('/../../../gut_project/raw_fastq_files/Haber_2017/counts_all.txt', 
                          sep='\t', 
                          comment='#', 
                          skiprows=1)

# %%
countmatrix.columns = countmatrix.columns.str.split('/').str[-1].str.replace('_Aligned.sortedByCoord.out.bam', '')

# %%
countmatrix = countmatrix.set_index('Geneid')

# %% [markdown]
# + Go from SRR to cell name as in FACS data

# %%
adata = sc.read_h5ad('/../../../gut_project/Processed_data/Gut_data/Haber_2017_Smartseq/Haber_2017_Smartseq_LGR5_FACS_data_human_orthologues_genes.h5ad')
adata = adata[adata.obs['Cell_Type'] == 'Stem']
adata = adata[adata.obs['Gene_marker'] == 'Lgr5GFP']
adata.obs['full_cell_description'] = adata.obs.index.copy()
# Out:
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /tmp/ipykernel_17745/294400955.py:4: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs['full_cell_description'] = adata.obs.index.copy()
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1840: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
dataframe = pd.read_csv('/../../../gut_project/raw_fastq_files/Haber_2017/sample_database.csv')
dataframe = dataframe[dataframe['Title'].str.contains('Atlas WT single cell ')]
dataframe['Sample'] = dataframe['Title'].str.split('Atlas WT single cell ').str[1]
dataframe['Sample'] = 'S' + dataframe['Sample']

# %%
dataframe = dataframe[dataframe['Sample'].isin(adata.obs['barcode'])]

# %%
countmatrix = countmatrix.T
countmatrix = countmatrix.iloc[5:]
countmatrix.head(10)
# Out:
# Geneid     ENSMUSG00000102693.2 ENSMUSG00000064842.3 ENSMUSG00000051951.6  \
# SRX2418522                    0                    0                    0
# SRX2418533                    0                    0                    0
# SRX2418544                    0                    0                    0
# SRX2418555                    0                    0                    0
# SRX2418577                    0                    0                    0
# SRX2418588                    0                    0                    0
# SRX2418599                    0                    0                    0
# SRX2418622                    0                    0                    0
# SRX2418633                    0                    0                    0
# SRX2418666                    0                    0                    0
#
# Geneid     ENSMUSG00000102851.2 ENSMUSG00000103377.2 ENSMUSG00000104017.2  \
# SRX2418522                    0                    0                    0
# SRX2418533                    0                    0                    0
# SRX2418544                    0                    0                    0
# SRX2418555                    0                    0                    0
# SRX2418577                    0                    0                    0
# SRX2418588                    0                    0                    0
# SRX2418599                    0                    0                    0
# SRX2418622                    0                    0                    0
# SRX2418633                    0                    0                    0
# SRX2418666                    0                    0                    0
#
# Geneid     ENSMUSG00000103025.2 ENSMUSG00000089699.2 ENSMUSG00000103201.2  \
# SRX2418522                    0                    0                    0
# SRX2418533                    0                    0                    0
# SRX2418544                    0                    0                    0
# SRX2418555                    0                    0                    0
# SRX2418577                    0                    0                    0
# SRX2418588                    0                    0                    0
# SRX2418599                    0                    0                    0
# SRX2418622                    0                    0                    0
# SRX2418633                    0                    0                    0
# SRX2418666                    0                    0                    0
#
# Geneid     ENSMUSG00000103147.2  ... ENSMUSG00000096550.2  \
# SRX2418522                    0  ...                    0
# SRX2418533                    0  ...                    0
# SRX2418544                    0  ...                    0
# SRX2418555                    0  ...                    0
# SRX2418577                    0  ...                    0
# SRX2418588                    0  ...                    0
# SRX2418599                    0  ...                    0
# SRX2418622                    0  ...                    0
# SRX2418633                    0  ...                    0
# SRX2418666                    0  ...                    0
#
# Geneid     ENSMUSG00000094172.2 ENSMUSG00000094887.2 ENSMUSG00000091585.3  \
# SRX2418522                    0                    0                    0
# SRX2418533                    0                    0                    0
# SRX2418544                    0                    0                    0
# SRX2418555                    0                    0                    0
# SRX2418577                    0                    0                    0
# SRX2418588                    0                    0                    0
# SRX2418599                    0                    0                    0
# SRX2418622                    0                    0                    0
# SRX2418633                    0                    0                    0
# SRX2418666                    0                    0                    0
#
# Geneid     ENSMUSG00000095763.2 ENSMUSG00000095523.2 ENSMUSG00000095475.2  \
# SRX2418522                    0                    0                    0
# SRX2418533                    0                    0                    0
# SRX2418544                    0                    0                    0
# SRX2418555                    0                    0                    0
# SRX2418577                    0                    0                    0
# SRX2418588                    0                    0                    0
# SRX2418599                    0                    0                    0
# SRX2418622                    0                    0                    0
# SRX2418633                    0                    0                    0
# SRX2418666                    0                    0                    0
#
# Geneid     ENSMUSG00000094855.2 ENSMUSG00000095019.2 ENSMUSG00000095041.8
# SRX2418522                    0                    0                  105
# SRX2418533                    0                    0                  904
# SRX2418544                    0                    0                  354
# SRX2418555                    0                    0                   43
# SRX2418577                    0                    0                  138
# SRX2418588                    0                    0                  502
# SRX2418599                    0                    0                  136
# SRX2418622                    0                    0                   18
# SRX2418633                    0                    0                  529
# SRX2418666                    0                    0                   78
#
# [10 rows x 57186 columns]

# %%
sra_accession_df = dataframe[['Sample', 'SRA Accession']]
adata.obs = adata.obs.merge(sra_accession_df, left_on='barcode', right_on='Sample', how='left')

# %%
adata.obs
# Out:
#     barcode Gene_marker Donor_ID GFP_intensity Cell_Type  \
# 0      S745     Lgr5GFP       M7        GFPLow      Stem
# 1      S856     Lgr5GFP       M7        GFPLow      Stem
# 2      S222     Lgr5GFP       M7       GFPHigh      Stem
# 3      S333     Lgr5GFP       M7        GFPLow      Stem
# 4      S589     Lgr5GFP       M7        GFPLow      Stem
# ..      ...         ...      ...           ...       ...
# 487    S423     Lgr5GFP       M5       GFPHigh      Stem
# 488    S424     Lgr5GFP       M5       GFPHigh      Stem
# 489    S425     Lgr5GFP       M5       GFPHigh      Stem
# 490    S427     Lgr5GFP       M5       GFPHigh      Stem
# 491    S429     Lgr5GFP       M5       GFPHigh      Stem
#
#             full_cell_description Sample SRA Accession
# 0     S745_Lgr5GFP_M7_GFPLow_Stem   S745    SRX2419245
# 1     S856_Lgr5GFP_M7_GFPLow_Stem   S856    SRX2419356
# 2    S222_Lgr5GFP_M7_GFPHigh_Stem   S222    SRX2418722
# 3     S333_Lgr5GFP_M7_GFPLow_Stem   S333    SRX2418833
# 4     S589_Lgr5GFP_M7_GFPLow_Stem   S589    SRX2419089
# ..                            ...    ...           ...
# 487  S423_Lgr5GFP_M5_GFPHigh_Stem   S423    SRX2418923
# 488  S424_Lgr5GFP_M5_GFPHigh_Stem   S424    SRX2418924
# 489  S425_Lgr5GFP_M5_GFPHigh_Stem   S425    SRX2418925
# 490  S427_Lgr5GFP_M5_GFPHigh_Stem   S427    SRX2418927
# 491  S429_Lgr5GFP_M5_GFPHigh_Stem   S429    SRX2418929
#
# [492 rows x 8 columns]

# %%
countmatrix_rows = set(countmatrix.index)
sra_accessions = set(adata.obs['SRA Accession'])
missing_in_countmatrix_rows = sra_accessions - countmatrix_rows
print(missing_in_countmatrix_rows)
# Out:
# {'SRX2419104', 'SRX2418850', 'SRX2419603'}

# %%
countmatrix['row_index'] = countmatrix.index
merged_df = pd.merge(adata.obs, countmatrix, left_on='SRA Accession', right_on='row_index', how='inner')
merged_df = merged_df.drop(columns=['row_index'])
merged_df.set_index('SRA Accession', inplace=True)

# %%
merged_df
# Out:
#               barcode Gene_marker Donor_ID GFP_intensity Cell_Type  \
# SRA Accession
# SRX2419245       S745     Lgr5GFP       M7        GFPLow      Stem
# SRX2419356       S856     Lgr5GFP       M7        GFPLow      Stem
# SRX2418722       S222     Lgr5GFP       M7       GFPHigh      Stem
# SRX2418833       S333     Lgr5GFP       M7        GFPLow      Stem
# SRX2419089       S589     Lgr5GFP       M7        GFPLow      Stem
# ...               ...         ...      ...           ...       ...
# SRX2418923       S423     Lgr5GFP       M5       GFPHigh      Stem
# SRX2418924       S424     Lgr5GFP       M5       GFPHigh      Stem
# SRX2418925       S425     Lgr5GFP       M5       GFPHigh      Stem
# SRX2418927       S427     Lgr5GFP       M5       GFPHigh      Stem
# SRX2418929       S429     Lgr5GFP       M5       GFPHigh      Stem
#
#                       full_cell_description Sample ENSMUSG00000102693.2  \
# SRA Accession
# SRX2419245      S745_Lgr5GFP_M7_GFPLow_Stem   S745                    0
# SRX2419356      S856_Lgr5GFP_M7_GFPLow_Stem   S856                    0
# SRX2418722     S222_Lgr5GFP_M7_GFPHigh_Stem   S222                    0
# SRX2418833      S333_Lgr5GFP_M7_GFPLow_Stem   S333                    0
# SRX2419089      S589_Lgr5GFP_M7_GFPLow_Stem   S589                    0
# ...                                     ...    ...                  ...
# SRX2418923     S423_Lgr5GFP_M5_GFPHigh_Stem   S423                    0
# SRX2418924     S424_Lgr5GFP_M5_GFPHigh_Stem   S424                    0
# SRX2418925     S425_Lgr5GFP_M5_GFPHigh_Stem   S425                    0
# SRX2418927     S427_Lgr5GFP_M5_GFPHigh_Stem   S427                    0
# SRX2418929     S429_Lgr5GFP_M5_GFPHigh_Stem   S429                    0
#
#               ENSMUSG00000064842.3 ENSMUSG00000051951.6  ...  \
# SRA Accession                                            ...
# SRX2419245                       0                    0  ...
# SRX2419356                       0                    0  ...
# SRX2418722                       0                    0  ...
# SRX2418833                       0                    0  ...
# SRX2419089                       0                    0  ...
# ...                            ...                  ...  ...
# SRX2418923                       0                    0  ...
# SRX2418924                       0                    0  ...
# SRX2418925                       0                    0  ...
# SRX2418927                       0                    0  ...
# SRX2418929                       0                    0  ...
#
#               ENSMUSG00000096550.2 ENSMUSG00000094172.2 ENSMUSG00000094887.2  \
# SRA Accession
# SRX2419245                       0                    0                    0
# SRX2419356                       0                    0                    0
# SRX2418722                       0                    0                    0
# SRX2418833                       0                    0                    0
# SRX2419089                       0                    0                    0
# ...                            ...                  ...                  ...
# SRX2418923                       0                    0                    0
# SRX2418924                       0                    0                    0
# SRX2418925                       0                    0                    0
# SRX2418927                       0                    0                    0
# SRX2418929                       0                    0                    0
#
#               ENSMUSG00000091585.3 ENSMUSG00000095763.2 ENSMUSG00000095523.2  \
# SRA Accession
# SRX2419245                       0                    0                    0
# SRX2419356                       0                    0                    0
# SRX2418722                       0                    0                    0
# SRX2418833                       0                    0                    0
# SRX2419089                       0                    0                    0
# ...                            ...                  ...                  ...
# SRX2418923                       0                    0                    0
# SRX2418924                       0                    0                    0
# SRX2418925                       0                    0                    0
# SRX2418927                       0                    0                    0
# SRX2418929                       0                    0                    0
#
#               ENSMUSG00000095475.2 ENSMUSG00000094855.2 ENSMUSG00000095019.2  \
# SRA Accession
# SRX2419245                       0                    0                    0
# SRX2419356                       0                    0                    0
# SRX2418722                       0                    0                    0
# SRX2418833                       0                    0                    0
# SRX2419089                       0                    0                    0
# ...                            ...                  ...                  ...
# SRX2418923                       0                    0                    0
# SRX2418924                       0                    0                    0
# SRX2418925                       0                    0                    0
# SRX2418927                       0                    0                    0
# SRX2418929                       0                    0                    0
#
#               ENSMUSG00000095041.8
# SRA Accession
# SRX2419245                     583
# SRX2419356                     274
# SRX2418722                      11
# SRX2418833                     153
# SRX2419089                       2
# ...                            ...
# SRX2418923                     378
# SRX2418924                     694
# SRX2418925                     391
# SRX2418927                     398
# SRX2418929                     605
#
# [489 rows x 57193 columns]

# %%
obs = merged_df.iloc[:, :7]
X = merged_df.iloc[:, 7:]
var = pd.DataFrame(index=X.columns)
new_adata = ad.AnnData(X=X.values, obs=obs, var=var)

# %%
new_adata.obs
# Out:
#               barcode Gene_marker Donor_ID GFP_intensity Cell_Type  \
# SRA Accession
# SRX2419245       S745     Lgr5GFP       M7        GFPLow      Stem
# SRX2419356       S856     Lgr5GFP       M7        GFPLow      Stem
# SRX2418722       S222     Lgr5GFP       M7       GFPHigh      Stem
# SRX2418833       S333     Lgr5GFP       M7        GFPLow      Stem
# SRX2419089       S589     Lgr5GFP       M7        GFPLow      Stem
# ...               ...         ...      ...           ...       ...
# SRX2418923       S423     Lgr5GFP       M5       GFPHigh      Stem
# SRX2418924       S424     Lgr5GFP       M5       GFPHigh      Stem
# SRX2418925       S425     Lgr5GFP       M5       GFPHigh      Stem
# SRX2418927       S427     Lgr5GFP       M5       GFPHigh      Stem
# SRX2418929       S429     Lgr5GFP       M5       GFPHigh      Stem
#
#                       full_cell_description Sample
# SRA Accession
# SRX2419245      S745_Lgr5GFP_M7_GFPLow_Stem   S745
# SRX2419356      S856_Lgr5GFP_M7_GFPLow_Stem   S856
# SRX2418722     S222_Lgr5GFP_M7_GFPHigh_Stem   S222
# SRX2418833      S333_Lgr5GFP_M7_GFPLow_Stem   S333
# SRX2419089      S589_Lgr5GFP_M7_GFPLow_Stem   S589
# ...                                     ...    ...
# SRX2418923     S423_Lgr5GFP_M5_GFPHigh_Stem   S423
# SRX2418924     S424_Lgr5GFP_M5_GFPHigh_Stem   S424
# SRX2418925     S425_Lgr5GFP_M5_GFPHigh_Stem   S425
# SRX2418927     S427_Lgr5GFP_M5_GFPHigh_Stem   S427
# SRX2418929     S429_Lgr5GFP_M5_GFPHigh_Stem   S429
#
# [489 rows x 7 columns]

# %%
new_adata.var = new_adata.var.astype(str)
new_adata.var.index = new_adata.var.index.astype(str)
new_adata.obs = new_adata.obs.astype(str)
new_adata.obs.index = new_adata.obs.index.astype(str)
new_adata.X = new_adata.X.astype(float)

# %%
new_adata.write_h5ad('/../../../gut_project/Processed_data/Gut_data/Haber_2017_Smartseq/Haber_2017_Smartseq_stem_cells_remapped.h5ad')

# %% [markdown]
# + Add human paralogues

# %%
human_mouse_orthologues = pd.read_csv('/../../../ensembl_data/mouse_to_human_orthologues_ensembl.txt', sep='\t', index_col=0)

# %%
duplicates = human_mouse_orthologues['Gene stable ID version'].duplicated()
num_duplicates = duplicates.sum()
num_duplicates
# Out:
# 85346

# %%
human_mouse_orthologues_cleaned = human_mouse_orthologues.loc[
    human_mouse_orthologues.groupby('Gene stable ID version')['%id. target Human gene identical to query gene'].idxmax()
]
human_mouse_orthologues_cleaned = human_mouse_orthologues_cleaned.reset_index(drop=True)

# %%
human_mouse_orthologues_cleaned = human_mouse_orthologues_cleaned.drop_duplicates(subset='Gene stable ID version')

# %%
intersect = np.intersect1d(human_mouse_orthologues_cleaned['Gene stable ID version'], new_adata.var.index)
len(intersect)
# Out:
# 20473

# %%
human_mouse_orthologues_cleaned = human_mouse_orthologues_cleaned.loc[human_mouse_orthologues_cleaned['Gene stable ID version'].isin(intersect)]
new_adata = new_adata[:, intersect]
# Out:
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1113: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):

# %%
new_adata.var['original_mouse_gene_id'] = new_adata.var.index.copy()
# Out:
# /tmp/ipykernel_17745/1126677715.py:1: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   new_adata.var['original_mouse_gene_id'] = new_adata.var.index.copy()

# %%
new_adata.var = new_adata.var.merge(human_mouse_orthologues_cleaned, left_index=True, right_on='Gene stable ID version')
# Out:
# /home/amaguza/miniforge3/envs/scanpy_env/lib/python3.11/site-packages/anndata/_core/anndata.py:788: UserWarning:
# AnnData expects .var.index to contain strings, but got values like:
#     [0, 1, 5, 14, 18]
#
#     Inferred to be: integer
#
#   value_idx = self._prep_dim_index(value.index, attr)

# %%
new_adata.var = new_adata.var.set_index('Human gene name')

# %%
new_adata.var.index = new_adata.var.index.astype(str)

# %%
new_adata.var
# Out:
#                 original_mouse_gene_id Gene stable ID version  \
# Human gene name
# GNAI3             ENSMUSG00000000001.5   ENSMUSG00000000001.5
# CDC45            ENSMUSG00000000028.16  ENSMUSG00000000028.16
# SCML2            ENSMUSG00000000037.18  ENSMUSG00000000037.18
# APOH             ENSMUSG00000000049.12  ENSMUSG00000000049.12
# NARF              ENSMUSG00000000056.8   ENSMUSG00000000056.8
# ...                                ...                    ...
# RNU6-977P         ENSMUSG00002076963.1   ENSMUSG00002076963.1
# SNORD100          ENSMUSG00002076971.1   ENSMUSG00002076971.1
# 5S_rRNA           ENSMUSG00002076988.1   ENSMUSG00002076988.1
# nan               ENSMUSG00002076990.1   ENSMUSG00002076990.1
# RN7SKP183         ENSMUSG00002076992.1   ENSMUSG00002076992.1
#
#                 Transcript stable ID Transcript stable ID version  \
# Human gene name
# GNAI3             ENSMUST00000000001         ENSMUST00000000001.5
# CDC45             ENSMUST00000000028        ENSMUST00000000028.14
# SCML2             ENSMUST00000238603         ENSMUST00000238603.2
# APOH              ENSMUST00000000049         ENSMUST00000000049.6
# NARF              ENSMUST00000103015         ENSMUST00000103015.4
# ...                              ...                          ...
# RNU6-977P         ENSMUST00020183153         ENSMUST00020183153.1
# SNORD100          ENSMUST00020182284         ENSMUST00020182284.1
# 5S_rRNA           ENSMUST00020182589         ENSMUST00020182589.1
# nan               ENSMUST00020183326         ENSMUST00020183326.1
# RN7SKP183         ENSMUST00020181762         ENSMUST00020181762.1
#
#                 Human gene stable ID Human homology type  \
# Human gene name
# GNAI3                ENSG00000065135    ortholog_one2one
# CDC45                ENSG00000093009    ortholog_one2one
# SCML2                ENSG00000102098    ortholog_one2one
# APOH                 ENSG00000091583    ortholog_one2one
# NARF                 ENSG00000141562    ortholog_one2one
# ...                              ...                 ...
# RNU6-977P            ENSG00000252220   ortholog_one2many
# SNORD100             ENSG00000221500    ortholog_one2one
# 5S_rRNA              ENSG00000277411   ortholog_one2many
# nan                  ENSG00000281311  ortholog_many2many
# RN7SKP183            ENSG00000252978    ortholog_one2one
#
#                  %id. target Human gene identical to query gene  \
# Human gene name
# GNAI3                                                   98.3051
# CDC45                                                   91.3428
# SCML2                                                   36.5325
# APOH                                                    76.5217
# NARF                                                    84.4156
# ...                                                         ...
# RNU6-977P                                               60.3774
# SNORD100                                                83.7838
# 5S_rRNA                                                 42.3077
# nan                                                     79.2593
# RN7SKP183                                               39.7394
#
#                  %id. query gene identical to target Human gene  \
# Human gene name
# GNAI3                                                   98.3051
# CDC45                                                   91.3428
# SCML2                                                   50.5714
# APOH                                                    76.5217
# NARF                                                    85.5263
# ...                                                         ...
# RNU6-977P                                               62.1359
# SNORD100                                                81.5789
# 5S_rRNA                                                 51.8868
# nan                                                     79.2593
# RN7SKP183                                               37.6543
#
#                  Human Gene-order conservation score  \
# Human gene name
# GNAI3                                          100.0
# CDC45                                          100.0
# SCML2                                          100.0
# APOH                                           100.0
# NARF                                           100.0
# ...                                              ...
# RNU6-977P                                        NaN
# SNORD100                                         NaN
# 5S_rRNA                                          NaN
# nan                                              NaN
# RN7SKP183                                        NaN
#
#                  Human orthology confidence [0 low, 1 high]  \
# Human gene name
# GNAI3                                                     1
# CDC45                                                     1
# SCML2                                                     0
# APOH                                                      1
# NARF                                                      1
# ...                                                     ...
# RNU6-977P                                                 0
# SNORD100                                                  1
# 5S_rRNA                                                   0
# nan                                                       1
# RN7SKP183                                                 0
#
#                 Human protein or transcript stable ID  \
# Human gene name
# GNAI3                                 ENSP00000358867
# CDC45                                 ENSP00000263201
# SCML2                                 ENSP00000251900
# APOH                                  ENSP00000205948
# NARF                                  ENSP00000309899
# ...                                               ...
# RNU6-977P                             ENST00000516411
# SNORD100                              ENST00000408573
# 5S_rRNA                               ENST00000614916
# nan                                   ENST00000628590
# RN7SKP183                             ENST00000517169
#
#                 Query protein or transcript ID   Protein stable ID  \
# Human gene name
# GNAI3                       ENSMUSP00000000001  ENSMUSP00000000001
# CDC45                       ENSMUSP00000000028  ENSMUSP00000000028
# SCML2                       ENSMUSP00000076593  ENSMUSP00000158772
# APOH                        ENSMUSP00000000049  ENSMUSP00000000049
# NARF                        ENSMUSP00000099304  ENSMUSP00000099304
# ...                                        ...                 ...
# RNU6-977P                   ENSMUST00020183153                 NaN
# SNORD100                    ENSMUST00020182284                 NaN
# 5S_rRNA                     ENSMUST00020182589                 NaN
# nan                         ENSMUST00020183326                 NaN
# RN7SKP183                   ENSMUST00020181762                 NaN
#
#                 Protein stable ID version Gene name
# Human gene name
# GNAI3                ENSMUSP00000000001.5     Gnai3
# CDC45                ENSMUSP00000000028.8     Cdc45
# SCML2                ENSMUSP00000158772.2     Scml2
# APOH                 ENSMUSP00000000049.6      Apoh
# NARF                 ENSMUSP00000099304.4      Narf
# ...                                   ...       ...
# RNU6-977P                             NaN   Gm54684
# SNORD100                              NaN  Snord100
# 5S_rRNA                               NaN   Gm56371
# nan                                   NaN   Gm22711
# RN7SKP183                             NaN   Gm54807
#
# [20473 rows x 15 columns]

# %%
new_adata.write('/../../../gut_project/Processed_data/Gut_data/Haber_2017_Smartseq/Haber_2017_Smartseq_stem_cells_remapped_human_orthologues_genes.h5ad')
