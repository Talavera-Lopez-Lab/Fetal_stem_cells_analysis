# %% [markdown]
# ### Integrating stem cells scRNA-seq datasets across human and mouse with `SATURN`
#
# - **Developed by:** Anna Maguza
# - **Affilation:** Faculty of Medicine, Würzburg University
# - **Date of creation:** 3rd September 2024
# - **Last modified date:** 4th September 2024
#
# This notebook is created to integrate human gut fetal stem cells from Elementaite, 2021 dataset and mouse gut stem cells from Haber, 2017 study using `SATURN` tool.

# %% [markdown]
# #### Import packages

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

import pickle

# %% [markdown]
# #### Make csv

# %%
df = pd.DataFrame(columns=["path", "species", "embedding_path"])
df["species"] = ["human", "mouse"]
df["path"] = ["data/FetalSC_for_SATURN.h5ad", "data/Haber_2017_Smartseq_stem_cells_remapped.h5ad"]
human_embedding_path = "database_data/ESM2_human_embedding.torch"
mouse_embedding_path = "database_data/ESM2_mouse_embedding.torch"
df["embedding_path"] = [human_embedding_path, mouse_embedding_path]
df.to_csv("data/SATURN_human_mouse.csv", index=False)

# %% [markdown]
# #### Create a cell type map

# %%
df = pd.DataFrame(columns=["human_cell_type", "mouse_cell_type"])
df["human_cell_type"] = ["MTRNR2L12", 'RPS10', 'FXYD3', "Stem cell", "Stem cell"]
df["mouse_cell_type"] = ["Stem cell", "Stem cell", "Stem cell", "LGR5+ stem cell", "LGR5- stem cell"]
df.to_csv("data/cell_type_map.csv", index=False)

# %% [markdown]
# #### Train SATURN

# %%
# !python3 /saturn/train-saturn.py --in_data=data/SATURN_human_mouse.csv \
                              --in_label_col=cell_type --ref_label_col=cell_type \
                              --num_macrogenes=2000 --hv_genes=8000 \
                              --centroids_init_path=/saturn_results/hm_centroids.pkl \
                              --ct_map_path=data/cell_type_map.csv \
                              --work_dir=/saturn_results \
                              --device_num=0
# Out:
# Using Device 0
# Set seed to 0
# After loading the anndata human View of AnnData object with n_obs × n_vars = 7817 × 15488
#     obs: 'Sample_ID', 'Cell Type', 'Study_name', 'Donor_ID', 'Diagnosis', 'Age', 'Region code', 'Fraction', 'Sex', 'Library_Preparation_Protocol', 'batch', 'Age_group', 'Location', 'Cell States', 'Cell States GCA', 'Chem', 'Layer', 'Cell States Kong', 'dataset', 'n_genes_by_counts', 'total_counts', 'total_counts_mito', 'pct_counts_mito', 'total_counts_ribo', 'pct_counts_ribo', 'Cell_ID', '_scvi_batch', '_scvi_labels', 'n_genes', 'n_counts', 'leiden', 'cluster', 'cell_type', 'species', 'species_type_label', 'truth_labels', 'ref_labels'
#     var: 'feature_types-0-0-0', 'gene_name-1-0-0', 'gene_id-0-0', 'GENE-1-0', 'n_counts', 'n_cells'
#     uns: 'Age_colors', 'Age_group_colors', 'Donor_ID_colors', 'Library_Preparation_Protocol_colors', 'Sex_colors', '_scvi_manager_uuid', '_scvi_uuid', 'hvg', 'leiden', 'leiden_colors', 'neighbors', 'rank_genes_groups', 'umap'
#     obsm: 'X_scVI', 'X_umap', '_scvi_extra_categorical_covs', '_scvi_extra_continuous_covs'
#     obsp: 'connectivities', 'distances'
# After loading the anndata mouse View of AnnData object with n_obs × n_vars = 489 × 15094
#     obs: 'barcode', 'Gene_marker', 'Donor_ID', 'GFP_intensity', 'Cell_Type', 'full_cell_description', 'cell_type', 'Sample', 'n_genes', 'n_counts', 'species', 'species_type_label', 'truth_labels', 'ref_labels'
#     var: 'ensemble_gene_id_version', 'ensemble_gene_id', 'start_position', 'end_position', 'chromosome_name', 'external_gene_name', 'n_counts', 'n_cells'
# Loaded centroids
# Pretraining...
# Epoch 200: L1 Loss 0.0 Rank Loss 4.711374759674072, Avg Loss human: 3306, Avg Lo
# Saving Pretrain AnnData
# 100%|█████████████████████████████████████████████| 9/9 [00:00<00:00, 17.52it/s]
# -----------------------------
# ***STARTING METRIC LEARNING***
# ***STARTING METRIC TRAINING***
# Epoch 1 Iteration 0: Loss = 0.10568979382514954, Number of mined triplets = 2693678
# Epoch 2 Iteration 0: Loss = 0.10270778834819794, Number of mined triplets = 2106281
# Epoch 3 Iteration 0: Loss = 0.1033712700009346, Number of mined triplets = 1997481
# Epoch 4 Iteration 0: Loss = 0.10414755344390869, Number of mined triplets = 2158794
# Epoch 5 Iteration 0: Loss = 0.10465877503156662, Number of mined triplets = 1826590
# Epoch 6 Iteration 0: Loss = 0.09994746744632721, Number of mined triplets = 1989929
# Epoch 7 Iteration 0: Loss = 0.10119111835956573, Number of mined triplets = 1730908
# Epoch 8 Iteration 0: Loss = 0.09971995651721954, Number of mined triplets = 1804496
# ^C
# Traceback (most recent call last):
#   File "/home/amaguza/tools/saturn/train-saturn.py", line 1064, in <module>
#     trainer(args)
#   File "/home/amaguza/tools/saturn/train-saturn.py", line 792, in trainer
#     train(metric_model, loss_func, mining_func, device,
#   File "/home/amaguza/tools/saturn/train-saturn.py", line 108, in train
#     key = f"{indices_mapped[0][j]},{indices_mapped[1][j]},{indices_mapped[2][j]}"
#   File "/home/amaguza/miniforge3/envs/SATURN/lib/python3.9/site-packages/torch/_tensor.py", line 986, in __format__
#     return self.item().__format__(format_spec)
# KeyboardInterrupt

# %% [markdown]
# #### Load SATURN Results

# %%
adata = sc.read("data/saturn_results/test256_data_FetalSC_for_SATURN_Haber_2017_Smartseq_stem_cells_remapped_org_saturn_seed_0.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 8306 × 256
#     obs: 'labels', 'labels2', 'ref_labels', 'species'
#     obsm: 'macrogenes'

# %%
adata.obs['labels2'] = adata.obs['labels2'].cat.add_categories(['MTRNR2L12+ASS1+_SC', 'RPS10+_RPS17+_SC', 'FXYD3+_CKB+_SC'])
adata.obs.loc[adata.obs['labels2'] == 'MTRNR2L12', 'labels2'] = 'MTRNR2L12+ASS1+_SC'
adata.obs.loc[adata.obs['labels2'] == 'RPS10', 'labels2'] = 'RPS10+_RPS17+_SC'
adata.obs.loc[adata.obs['labels2'] == 'FXYD3', 'labels2'] = 'FXYD3+_CKB+_SC'

adata.obs['labels2'] = adata.obs['labels2'].cat.remove_categories(['MTRNR2L12', 'RPS10', 'FXYD3'])

# %%
sc.pp.pca(adata)
sc.pl.pca(adata,color=["species", "labels2"])

# %%
sc.pp.neighbors(adata)
sc.tl.umap(adata)

# %%
sc.pl.umap(adata,color=["species", "labels2"])

# %%
adata.obsm['X_saturn'] = adata.X.copy()

# %%
adata.write("data/saturn_results/test256_data_FetalSC_for_SATURN_Haber_2017_Smartseq_stem_cells_remapped_org_saturn_seed_0.h5ad")

# %% [markdown]
# #### Macrogene Differential Expression

# %%
with open("data/saturn_results/test256_data_FetalSC_for_SATURN_Haber_2017_Smartseq_stem_cells_remapped_org_saturn_seed_0_genes_to_macrogenes.pkl", "rb") as f:
    macrogene_weights = pickle.load(f)

# %%
macrogene_weights
# Out:
# {'human_A1BG': array([3.5742380e-06, 6.7097193e-07, 6.2579015e-06, ..., 4.0799429e-04,
#         1.3140639e-06, 4.0296036e-06], dtype=float32),
#  'human_A1CF': array([7.4012598e-05, 8.1439708e-07, 2.9245830e-05, ..., 4.4919834e-06,
#         2.4796350e-06, 2.6589792e-06], dtype=float32),
#  'human_A2M': array([8.8247107e-06, 5.0339190e-07, 4.6930846e-04, ..., 8.8899551e-06,
#         1.9512165e-06, 8.6499284e-07], dtype=float32),
#  'human_AADAC': array([5.2929254e-06, 9.3007952e-07, 3.7237242e-04, ..., 1.7356524e-05,
#         2.3076268e-06, 1.6961293e-06], dtype=float32),
#  'human_AADAT': array([2.9910309e-06, 1.7356697e-06, 1.5399115e-05, ..., 3.9397164e-06,
#         1.4078863e-06, 2.3399061e-06], dtype=float32),
#  'human_AAGAB': array([1.5158956e-05, 6.2279690e-07, 7.6810493e-06, ..., 2.8772886e-06,
#         1.1757318e-06, 1.5917697e-06], dtype=float32),
#  'human_AAK1': array([3.4994885e-04, 4.9026801e-07, 5.0523176e-06, ..., 2.0384884e-06,
#         1.0892009e-06, 1.5664536e-06], dtype=float32),
#  'human_AARSD1': array([1.9877805e-05, 4.3967674e-07, 4.6978959e-05, ..., 2.8061206e-06,
#         1.5673936e-06, 8.5768704e-07], dtype=float32),
#  'human_AATK': array([2.8308725e-05, 5.3858503e-07, 3.3031781e-06, ..., 2.7211477e-06,
#         1.0246576e-06, 2.3500613e-06], dtype=float32),
#  'human_ABAT': array([2.4464987e-06, 7.0722622e-06, 1.7096995e-06, ..., 1.4033233e-06,
#         1.0352135e-06, 2.6461107e-06], dtype=float32),
#  'human_ABCA1': array([1.4196614e-05, 5.4688445e-07, 2.9052326e-05, ..., 4.0927248e-06,
#         2.2875493e-06, 9.8035412e-07], dtype=float32),
#  'human_ABCA2': array([2.6011630e-05, 5.3383445e-07, 2.0422429e-05, ..., 2.0085045e-06,
#         1.6457018e-06, 1.2289198e-06], dtype=float32),
#  'human_ABCA4': array([2.2494904e-05, 5.2511575e-07, 2.0837056e-04, ..., 4.1148687e-06,
#         2.5778149e-06, 9.5000610e-07], dtype=float32),
#  'human_ABCA5': array([7.6272518e-06, 7.2576279e-07, 6.3534586e-05, ..., 9.7589955e-06,
#         1.6048800e-06, 1.4269198e-06], dtype=float32),
#  'human_ABCA6': array([3.9758152e-06, 6.7629952e-07, 1.8650228e-05, ..., 1.8769882e-05,
#         1.2788535e-06, 1.0737716e-06], dtype=float32),
#  'human_ABCA7': array([5.6807876e-06, 6.4499665e-07, 5.5635792e-06, ..., 2.7548808e-06,
#         1.9557381e-06, 1.6617171e-06], dtype=float32),
#  'human_ABCA9': array([3.4554373e-06, 7.8913297e-07, 8.5506754e-06, ..., 9.1009306e-06,
#         1.4220876e-06, 1.1745730e-06], dtype=float32),
#  'human_ABCB1': array([5.7282785e-05, 5.5740492e-07, 2.7095567e-04, ..., 4.8729989e-06,
#         2.2049389e-06, 1.1433826e-06], dtype=float32),
#  'human_ABCB10': array([2.7898372e-05, 5.3285072e-07, 8.9127105e-05, ..., 4.3054661e-06,
#         2.2346392e-06, 1.3990751e-06], dtype=float32),
#  'human_ABCB4': array([1.8934768e-05, 6.1768452e-07, 3.9701868e-04, ..., 6.5490372e-06,
#         2.2870520e-06, 1.3276606e-06], dtype=float32),
#  'human_ABCB5': array([2.35180232e-05, 6.13384088e-07, 1.08082476e-03, ...,
#         1.47338305e-05, 3.35345226e-06, 1.38661301e-06], dtype=float32),
#  'human_ABCB8': array([2.1967755e-05, 4.6459053e-07, 1.2761335e-05, ..., 2.0472671e-06,
#         1.2732834e-06, 9.3592359e-07], dtype=float32),
#  'human_ABCC11': array([3.1633532e-05, 5.2371388e-07, 3.1604632e-04, ..., 5.9601516e-06,
#         2.3999230e-06, 9.5990640e-07], dtype=float32),
#  'human_ABCC2': array([1.18186035e-05, 5.58233751e-07, 1.53471628e-04, ...,
#         8.10223537e-06, 2.00853515e-06, 1.23417567e-06], dtype=float32),
#  'human_ABCC3': array([1.35230885e-05, 4.38222884e-07, 1.59639203e-05, ...,
#         1.96315477e-06, 1.44926480e-06, 8.66983214e-07], dtype=float32),
#  'human_ABCC6': array([4.6970199e-06, 7.5698983e-07, 8.0743894e-06, ..., 5.2959804e-06,
#         1.4047198e-06, 1.6983581e-06], dtype=float32),
#  'human_ABCC9': array([7.4850723e-06, 6.9622217e-07, 1.3205834e-05, ..., 4.4164244e-06,
#         1.3940407e-06, 1.2564406e-06], dtype=float32),
#  'human_ABCD3': array([1.52486637e-05, 5.38798247e-07, 1.00704456e-04, ...,
#         5.33418915e-06, 3.09107190e-06, 1.06912239e-06], dtype=float32),
#  'human_ABCF1': array([2.0592843e-04, 5.8530634e-07, 2.7468754e-05, ..., 2.8762872e-06,
#         1.4694645e-06, 1.0058984e-06], dtype=float32),
#  'human_ABCG4': array([2.9012510e-05, 5.5996395e-07, 7.6696932e-05, ..., 9.2228256e-06,
#         2.7435046e-06, 1.4149988e-06], dtype=float32),
#  'human_ABCG8': array([4.9915405e-05, 5.1579707e-07, 2.5543710e-04, ..., 7.4992477e-06,
#         2.0055797e-06, 9.7248380e-07], dtype=float32),
#  'human_ABHD11': array([3.3508245e-06, 1.4937273e-06, 4.0258624e-06, ..., 4.3937807e-06,
#         1.2756401e-06, 4.3011896e-06], dtype=float32),
#  'human_ABHD13': array([1.5882102e-05, 5.9417664e-07, 7.8618922e-04, ..., 7.0569281e-06,
#         2.5715881e-06, 1.4117584e-06], dtype=float32),
#  'human_ABHD14A': array([3.6207493e-06, 6.4122537e-07, 2.3665357e-06, ..., 2.7774990e-06,
#         8.9932081e-07, 1.2164688e-06], dtype=float32),
#  'human_ABHD14A-ACY1': array([3.8679914e-06, 6.2634695e-07, 2.9101004e-06, ..., 3.9374254e-06,
#         9.8459577e-07, 1.5372797e-06], dtype=float32),
#  'human_ABHD15': array([1.8750587e-06, 4.0276286e-06, 1.0932605e-06, ..., 1.9915669e-06,
#         1.1488652e-06, 8.8768147e-06], dtype=float32),
#  'human_ABHD16A': array([6.0499415e-06, 9.5735754e-07, 2.3179734e-06, ..., 1.2136622e-06,
#         1.0794978e-06, 1.5194380e-06], dtype=float32),
#  'human_ABHD17A': array([3.0387673e-06, 5.4105953e-06, 2.2503345e-06, ..., 1.4899201e-06,
#         1.9408940e-06, 8.2017696e-06], dtype=float32),
#  'human_ABHD17C': array([1.9489532e-06, 1.9586143e-04, 1.4701191e-06, ..., 1.4318313e-06,
#         1.6961164e-06, 1.8422312e-05], dtype=float32),
#  'human_ABHD18': array([2.6159401e-05, 4.9130239e-07, 1.7699795e-05, ..., 2.1925880e-06,
#         1.5544442e-06, 8.6367891e-07], dtype=float32),
#  'human_ABHD2': array([1.1871539e-05, 5.0345574e-07, 1.6721702e-05, ..., 3.9582342e-06,
#         1.1936822e-06, 1.3652068e-06], dtype=float32),
#  'human_ABHD3': array([1.7694504e-06, 6.7118250e-05, 2.2091567e-06, ..., 1.2825456e-06,
#         1.3460549e-06, 5.4735383e-06], dtype=float32),
#  'human_ABHD4': array([1.6830383e-05, 4.6480321e-07, 1.9782321e-05, ..., 2.2089525e-06,
#         1.2725477e-06, 9.7587667e-07], dtype=float32),
#  'human_ABHD5': array([1.7023691e-05, 4.6701777e-07, 2.8780172e-05, ..., 2.4528999e-06,
#         1.5856381e-06, 9.0660416e-07], dtype=float32),
#  'human_ABI2': array([1.4720172e-04, 5.6352917e-07, 1.4323947e-05, ..., 2.6157315e-06,
#         1.5475101e-06, 8.8751005e-07], dtype=float32),
#  'human_ABI3': array([1.8651269e-03, 5.2863800e-07, 6.6712928e-06, ..., 2.4011476e-06,
#         1.1636499e-06, 1.0761869e-06], dtype=float32),
#  'human_ABLIM1': array([3.0008596e-06, 3.9807550e-04, 1.1380586e-06, ..., 1.3398831e-06,
#         1.5116909e-06, 7.1734714e-05], dtype=float32),
#  'human_ABLIM3': array([6.6405261e-04, 6.0081953e-07, 1.1115826e-05, ..., 4.8455599e-06,
#         2.0281529e-06, 1.8573601e-05], dtype=float32),
#  'human_ABRACL': array([1.1701305e-05, 1.3145501e-06, 9.4982806e-06, ..., 1.5003203e-06,
#         1.1050837e-06, 1.1052882e-06], dtype=float32),
#  'human_ACAA2': array([1.9456449e-05, 5.4198671e-07, 2.5754020e-04, ..., 1.0914849e-05,
#         5.3385606e-06, 1.3491947e-06], dtype=float32),
#  'human_ACAD8': array([1.5233852e-05, 5.7782074e-07, 1.7384702e-05, ..., 2.3054029e-06,
#         1.7213185e-06, 1.2884830e-06], dtype=float32),
#  'human_ACAP3': array([4.8443981e-05, 5.1943169e-07, 1.2016529e-05, ..., 2.5063914e-06,
#         1.5934146e-06, 1.1356842e-06], dtype=float32),
#  'human_ACAT1': array([3.6775573e-06, 1.8121945e-06, 8.1813805e-06, ..., 2.0984867e-06,
#         2.3266418e-06, 2.0419011e-06], dtype=float32),
#  'human_ACAT2': array([1.5824227e-05, 6.1574957e-07, 3.6311444e-04, ..., 5.1872853e-06,
#         5.1868201e-06, 1.7067248e-06], dtype=float32),
#  'human_ACBD3': array([1.7211143e-05, 7.1112817e-07, 4.0244804e-06, ..., 1.8081945e-06,
#         1.3756504e-06, 2.7021865e-06], dtype=float32),
#  'human_ACBD5': array([2.1551694e-05, 6.0042260e-07, 5.4102443e-06, ..., 2.6605646e-06,
#         1.0303764e-06, 1.2310347e-06], dtype=float32),
#  'human_ACBD7': array([5.7935772e-06, 7.4440572e-07, 1.2301277e-04, ..., 6.6562438e-06,
#         1.7823813e-06, 1.2152350e-06], dtype=float32),
#  'human_ACD': array([1.3065294e-05, 4.9469361e-07, 2.1746871e-06, ..., 2.3560776e-06,
#         8.1045732e-07, 9.5355523e-07], dtype=float32),
#  'human_ACE': array([1.1387202e-05, 5.2963162e-07, 1.2323745e-03, ..., 3.2980126e-06,
#         2.1100880e-06, 9.3398700e-07], dtype=float32),
#  'human_ACE2': array([9.6714957e-06, 6.4136606e-07, 1.7309794e-02, ..., 5.8898322e-06,
#         3.2883931e-06, 1.3889529e-06], dtype=float32),
#  'human_ACER1': array([6.2275863e-06, 8.6332892e-07, 1.9709447e-05, ..., 8.4179646e-06,
#         3.0197698e-06, 1.8524680e-06], dtype=float32),
#  'human_ACER3': array([2.2042639e-06, 5.8194209e-06, 3.7491857e-06, ..., 2.0195100e-06,
#         2.3509310e-06, 2.6967493e-06], dtype=float32),
#  'human_ACHE': array([1.0801976e-05, 5.1772844e-07, 1.3688506e-04, ..., 4.4153926e-06,
#         3.0194212e-06, 1.0613741e-06], dtype=float32),
#  'human_ACKR1': array([4.3523596e-06, 5.3848845e-07, 3.5163355e-06, ..., 3.0600622e-05,
#         9.6520387e-07, 1.2072612e-06], dtype=float32),
#  'human_ACKR3': array([9.7368420e-06, 6.6653877e-07, 1.4222945e-05, ..., 3.1839966e-04,
#         1.5436497e-06, 3.3932017e-06], dtype=float32),
#  'human_ACKR4': array([2.1318492e-05, 5.0822479e-07, 4.6219575e-05, ..., 5.4719412e-06,
#         1.3329815e-06, 8.7998723e-07], dtype=float32),
#  'human_ACLY': array([3.2194323e-05, 5.5920401e-07, 4.5153720e-05, ..., 4.7572112e-06,
#         1.8293746e-06, 1.5384721e-06], dtype=float32),
#  'human_ACO1': array([1.9693136e-05, 5.8912337e-07, 6.6478351e-05, ..., 5.1491756e-06,
#         2.5114209e-06, 1.2056987e-06], dtype=float32),
#  'human_ACOT11': array([2.6965693e-06, 3.5238386e-06, 2.7987335e-06, ..., 2.1874628e-06,
#         1.6959626e-06, 4.5292441e-06], dtype=float32),
#  'human_ACOT12': array([4.1297367e-06, 1.6226073e-06, 6.7848405e-06, ..., 6.0556968e-06,
#         2.1508808e-06, 6.6685511e-06], dtype=float32),
#  'human_ACOT13': array([5.6602435e-06, 1.6278570e-06, 2.5575484e-05, ..., 7.6568485e-06,
#         2.5068146e-06, 2.6237014e-06], dtype=float32),
#  'human_ACOT2': array([7.7760396e-06, 4.8384737e-07, 1.1481670e-05, ..., 1.8419423e-06,
#         1.5896914e-06, 9.3279505e-07], dtype=float32),
#  'human_ACOT4': array([3.4621269e-06, 7.2815254e-07, 9.6343874e-06, ..., 4.7000085e-06,
#         2.3762898e-06, 1.3728340e-06], dtype=float32),
#  'human_ACOT6': array([3.6850531e-06, 7.7043165e-07, 1.3347313e-05, ..., 7.1398199e-06,
#         1.9121285e-06, 1.1695387e-06], dtype=float32),
#  'human_ACOT7': array([1.9161446e-06, 4.1069905e-04, 1.5305375e-06, ..., 1.6756735e-06,
#         1.5750295e-06, 1.3721122e-05], dtype=float32),
#  'human_ACOT8': array([2.4493397e-06, 4.3659793e-06, 2.3326004e-06, ..., 1.6331330e-06,
#         1.3379408e-06, 3.4376030e-06], dtype=float32),
#  'human_ACOX2': array([1.7881710e-05, 4.7620208e-07, 7.2505376e-05, ..., 4.5713286e-06,
#         2.0497698e-06, 8.6447574e-07], dtype=float32),
#  'human_ACP5': array([1.2753172e-05, 4.6188197e-07, 5.5155921e-05, ..., 3.9023012e-06,
#         1.8442307e-06, 9.7851307e-07], dtype=float32),
#  'human_ACP6': array([2.6290691e-06, 1.1557731e-06, 2.9044829e-06, ..., 3.7510385e-06,
#         1.2339556e-06, 1.7227491e-06], dtype=float32),
#  'human_ACP7': array([3.4477710e-06, 8.3660990e-07, 1.0519456e-05, ..., 4.5633310e-06,
#         2.3797663e-06, 3.1922389e-06], dtype=float32),
#  'human_ACSBG2': array([2.8619426e-05, 5.2478725e-07, 8.2726852e-05, ..., 7.5637831e-06,
#         1.5197162e-06, 9.9228214e-07], dtype=float32),
#  'human_ACSL3': array([1.1770832e-05, 5.3530420e-07, 2.6926713e-04, ..., 4.8882098e-06,
#         2.6401219e-06, 1.3563354e-06], dtype=float32),
#  'human_ACSL5': array([5.8478163e-06, 6.7772191e-07, 6.3373795e-05, ..., 4.2556549e-06,
#         2.2771146e-06, 1.6159747e-06], dtype=float32),
#  'human_ACSM3': array([9.3480103e-06, 5.6473272e-07, 4.6675064e-05, ..., 3.4175230e-06,
#         1.6685025e-06, 1.0711666e-06], dtype=float32),
#  'human_ACSM5': array([3.6176668e-06, 1.3137669e-06, 3.3736610e-06, ..., 1.8651516e-06,
#         1.2971095e-06, 1.5619650e-06], dtype=float32),
#  'human_ACSM6': array([9.4700254e-06, 5.1385820e-07, 3.2035245e-05, ..., 4.9563268e-06,
#         1.3933177e-06, 8.3226575e-07], dtype=float32),
#  'human_ACSS1': array([3.5608315e-05, 5.0736230e-07, 8.2285602e-05, ..., 6.4402830e-06,
#         2.5466725e-06, 1.1783663e-06], dtype=float32),
#  'human_ACSS2': array([2.4003293e-05, 4.4091965e-07, 3.3297474e-05, ..., 3.2619282e-06,
#         1.6622939e-06, 8.3063151e-07], dtype=float32),
#  'human_ACTA1': array([1.3160297e-05, 6.4624533e-07, 6.7332387e-04, ..., 6.6583329e-06,
#         1.0707820e-05, 1.9017263e-06], dtype=float32),
#  'human_ACTA2': array([9.3493572e-06, 6.6577951e-07, 1.8866858e-04, ..., 4.8404563e-06,
#         1.0309363e-05, 1.7404949e-06], dtype=float32),
#  'human_ACTB': array([1.3600652e-05, 1.0289810e-06, 5.2062399e-04, ..., 8.0666932e-06,
#         1.2905397e-05, 2.0291261e-06], dtype=float32),
#  'human_ACTC1': array([1.3793622e-05, 6.5992907e-07, 5.7274156e-04, ..., 6.0226839e-06,
#         1.1541469e-05, 1.9718120e-06], dtype=float32),
#  'human_ACTG2': array([1.2703185e-05, 5.7844647e-07, 3.6001214e-04, ..., 5.2248888e-06,
#         7.9803731e-06, 1.4678131e-06], dtype=float32),
#  'human_ACTL6A': array([3.5334378e-05, 5.6340241e-07, 1.4674800e-04, ..., 4.9020887e-06,
#         2.3256325e-06, 1.2830093e-06], dtype=float32),
#  'human_ACTL6B': array([1.4395514e-05, 5.6151316e-07, 3.6912152e-04, ..., 5.6055414e-06,
#         3.1892387e-06, 1.4561724e-06], dtype=float32),
#  'human_ACTL8': array([2.0469968e-05, 4.8032615e-07, 9.8550991e-05, ..., 3.0967887e-05,
#         2.8210447e-06, 1.4462204e-06], dtype=float32),
#  'human_ACTN1': array([5.5703113e-06, 4.0299419e-06, 8.2270253e-06, ..., 2.1048222e-06,
#         2.2568356e-06, 7.6078991e-06], dtype=float32),
#  'human_ACTN2': array([6.4707697e-06, 4.0908517e-06, 1.1244260e-05, ..., 2.1603003e-06,
#         2.0808659e-06, 7.6354181e-06], dtype=float32),
#  'human_ACTN4': array([1.6754857e-05, 2.0119419e-06, 1.9887932e-05, ..., 2.8382940e-06,
#         1.7956738e-06, 4.2501915e-06], dtype=float32),
#  'human_ACTR3C': array([3.1499374e-06, 1.0551778e-05, 3.3747967e-06, ..., 1.4550910e-06,
#         1.4639379e-06, 2.7295373e-06], dtype=float32),
#  'human_ACTRT3': array([1.3889920e-05, 5.0260093e-07, 5.7206384e-04, ..., 1.1617489e-05,
#         4.3512559e-06, 1.1371581e-06], dtype=float32),
#  'human_ACVR1B': array([7.4676500e-05, 7.9360382e-07, 1.6991260e-04, ..., 2.2406968e-05,
#         3.2715018e-06, 1.3915025e-06], dtype=float32),
#  'human_ACVR1C': array([4.8227696e-05, 5.3679901e-07, 1.1612022e-04, ..., 2.8909435e-05,
#         3.1459745e-06, 1.4517091e-06], dtype=float32),
#  'human_ACVR2A': array([4.3125792e-06, 4.3605651e-06, 3.3443278e-06, ..., 3.9123729e-06,
#         1.6793177e-06, 1.3715050e-05], dtype=float32),
#  'human_ACVR2B': array([5.6025378e-06, 1.2816470e-06, 3.9650272e-06, ..., 4.5055281e-06,
#         1.9649829e-06, 7.1773138e-06], dtype=float32),
#  'human_ACVRL1': array([4.1687948e-05, 5.3588701e-07, 3.7434285e-05, ..., 1.6419386e-05,
#         3.1496158e-06, 1.3550012e-06], dtype=float32),
#  'human_ACY1': array([7.2787657e-06, 6.8277882e-07, 9.4253182e-06, ..., 1.9403387e-06,
#         1.1390346e-06, 1.3522464e-06], dtype=float32),
#  'human_ACY3': array([3.1774200e-06, 7.6836170e-07, 2.8607351e-06, ..., 3.5389330e-06,
#         1.3119214e-06, 1.5360164e-06], dtype=float32),
#  'human_ACYP1': array([7.5453036e-06, 9.2190925e-07, 1.0347590e-05, ..., 1.9410438e-06,
#         1.0813143e-06, 1.1711793e-06], dtype=float32),
#  'human_ACYP2': array([7.2048210e-06, 7.6288632e-07, 2.0791847e-05, ..., 1.8729785e-06,
#         1.5496206e-06, 1.4128993e-06], dtype=float32),
#  'human_ADA': array([5.7112893e-06, 1.1483897e-06, 1.0200445e-05, ..., 4.8962252e-06,
#         1.6797422e-06, 2.3893404e-06], dtype=float32),
#  'human_ADA2': array([1.1004033e-05, 4.8090601e-07, 2.6360463e-04, ..., 4.3365494e-06,
#         2.5834804e-06, 9.0894855e-07], dtype=float32),
#  'human_ADAL': array([2.53118810e-06, 1.21052335e-05, 3.55661450e-06, ...,
#         2.57045053e-06, 1.12184512e-06, 3.04890978e-06], dtype=float32),
#  'human_ADAM10': array([1.5693822e-05, 4.2611148e-07, 3.1890791e-05, ..., 2.6067269e-06,
#         2.1994281e-06, 7.5511667e-07], dtype=float32),
#  'human_ADAM12': array([9.2423015e-06, 6.3549186e-07, 2.1808931e-04, ..., 1.9244231e-05,
#         9.8934206e-06, 1.8001473e-06], dtype=float32),
#  'human_ADAM17': array([1.8725990e-05, 4.2727081e-07, 2.7002096e-05, ..., 2.3757618e-06,
#         1.5905572e-06, 7.4080805e-07], dtype=float32),
#  'human_ADAM20': array([4.9754453e-06, 6.4165113e-07, 3.8937287e-04, ..., 9.2623981e-05,
#         6.1052765e-06, 1.1158901e-06], dtype=float32),
#  'human_ADAM21': array([3.1999839e-06, 8.6185645e-07, 3.8098453e-05, ..., 7.7008932e-05,
#         5.2961473e-06, 1.8231325e-06], dtype=float32),
#  'human_ADAM23': array([6.9972712e-06, 9.1929911e-07, 1.0391478e-05, ..., 8.7487169e-06,
#         3.2446869e-06, 4.3729710e-06], dtype=float32),
#  'human_ADAM28': array([1.4563134e-05, 6.0866176e-07, 1.5374264e-04, ..., 9.8825905e-05,
#         2.2281870e-06, 1.4536458e-06], dtype=float32),
#  'human_ADAM33': array([1.7347298e-06, 2.8728959e-06, 2.0259956e-06, ..., 4.0725836e-06,
#         2.3975667e-06, 1.1104118e-05], dtype=float32),
#  'human_ADAM9': array([5.4221450e-06, 8.5220961e-07, 2.6434109e-05, ..., 8.4789235e-06,
#         3.8030698e-06, 3.2822832e-06], dtype=float32),
#  'human_ADAMDEC1': array([1.4362110e-05, 5.0026915e-07, 1.9480057e-04, ..., 1.7830573e-05,
#         2.0012865e-06, 1.0359631e-06], dtype=float32),
#  'human_ADAMTS1': array([1.1239661e-05, 7.5502015e-07, 4.9702689e-04, ..., 3.3959292e-05,
#         3.5385197e-05, 1.9608869e-06], dtype=float32),
#  'human_ADAMTS12': array([8.1120243e-06, 5.8710032e-07, 9.1101145e-05, ..., 1.7669683e-04,
#         5.6685517e-06, 1.7641883e-06], dtype=float32),
#  'human_ADAMTS14': array([6.9175044e-06, 8.1373952e-07, 1.2133481e-05, ..., 4.6444700e-05,
#         6.8388827e-06, 5.6642339e-06], dtype=float32),
#  'human_ADAMTS16': array([5.9408749e-06, 8.7359967e-07, 4.0377337e-05, ..., 1.1534954e-05,
#         1.1536560e-05, 2.9816977e-06], dtype=float32),
#  'human_ADAMTS17': array([1.4262648e-05, 4.8001436e-07, 3.8856622e-05, ..., 9.9112312e-06,
#         3.0883905e-06, 1.0137134e-06], dtype=float32),
#  'human_ADAMTS19': array([1.8012472e-05, 4.5517501e-07, 1.3544055e-04, ..., 7.6714086e-06,
#         2.8847148e-06, 9.0910805e-07], dtype=float32),
#  'human_ADAMTS5': array([4.3155169e-06, 1.2550214e-06, 1.2366281e-05, ..., 6.9168254e-06,
#         9.9592698e-06, 1.1104965e-05], dtype=float32),
#  'human_ADAMTS6': array([1.9623958e-05, 6.1213467e-07, 2.2557558e-02, ..., 5.9410642e-05,
#         2.9577508e-05, 1.3027477e-06], dtype=float32),
#  'human_ADAMTS7': array([5.8514756e-06, 6.5187749e-07, 5.9268092e-05, ..., 3.9894636e-05,
#         1.2587535e-05, 2.4872400e-06], dtype=float32),
#  'human_ADAMTS8': array([4.1960870e-06, 1.0061633e-06, 7.0876426e-06, ..., 1.1532303e-05,
#         6.4028773e-06, 8.5273032e-06], dtype=float32),
#  'human_ADAMTS9': array([1.1538651e-05, 6.8831309e-07, 6.2573679e-05, ..., 1.0414912e-05,
#         7.6304823e-06, 2.1138706e-06], dtype=float32),
#  'human_ADAMTSL1': array([1.7073247e-05, 5.7147628e-07, 1.2327924e-04, ..., 3.3352186e-04,
#         8.5014653e-06, 1.5091858e-06], dtype=float32),
#  'human_ADAMTSL3': array([2.4626403e-05, 5.8195900e-07, 1.6503352e-04, ..., 1.5477441e-03,
#         1.0507064e-05, 1.6820585e-06], dtype=float32),
#  'human_ADAMTSL4': array([7.7455979e-06, 5.9733105e-07, 3.2044029e-06, ..., 1.2730133e-05,
#         2.1386293e-06, 2.8042480e-06], dtype=float32),
#  'human_ADAMTSL5': array([3.7753712e-06, 5.5958066e-07, 3.9810434e-06, ..., 6.9924345e-06,
#         2.7082183e-06, 1.4720495e-06], dtype=float32),
#  'human_ADAP2': array([5.1698102e-05, 5.4251109e-07, 1.4388755e-04, ..., 1.3955924e-05,
#         3.0365104e-06, 1.3650388e-06], dtype=float32),
#  'human_ADAT1': array([1.7482229e-05, 4.6865202e-07, 1.1292005e-05, ..., 1.9809836e-06,
#         1.2373789e-06, 7.7797068e-07], dtype=float32),
#  'human_ADAT2': array([1.7435351e-06, 1.6282687e-04, 1.6801828e-06, ..., 1.9006927e-06,
#         1.5211270e-06, 1.1432872e-05], dtype=float32),
#  'human_ADCK2': array([2.1429880e-06, 2.4194080e-06, 1.6270345e-06, ..., 2.7901363e-06,
#         1.2165953e-06, 4.5037796e-06], dtype=float32),
#  'human_ADCY7': array([2.2039540e-05, 4.7046788e-07, 2.2767468e-05, ..., 2.6806902e-06,
#         1.7222892e-06, 8.6357676e-07], dtype=float32),
#  'human_ADCYAP1R1': array([5.6607942e-06, 7.9081684e-07, 1.2724391e-05, ..., 2.6867468e-05,
#         1.6015454e-06, 4.0372315e-06], dtype=float32),
#  'human_ADD2': array([7.2232792e-06, 1.7798826e-06, 1.4933540e-06, ..., 1.3991779e-06,
#         9.4965645e-07, 5.5205464e-06], dtype=float32),
#  'human_ADGRA2': array([9.6046824e-06, 5.5439318e-07, 8.3993682e-06, ..., 2.7694150e-05,
#         2.2504673e-06, 1.5475307e-06], dtype=float32),
#  'human_ADGRA3': array([3.1934935e-06, 3.7696757e-06, 3.2526341e-06, ..., 5.4027423e-06,
#         1.8531271e-06, 6.8116169e-06], dtype=float32),
#  'human_ADGRB3': array([2.3220157e-06, 4.2608834e-05, 2.2507422e-06, ..., 3.2930438e-06,
#         1.7035392e-06, 1.9648658e-05], dtype=float32),
#  'human_ADGRD1': array([4.0715622e-06, 1.0875090e-06, 6.5356103e-06, ..., 8.2932274e-06,
#         1.5441607e-06, 4.9984687e-06], dtype=float32),
#  'human_ADGRE2': array([3.82028566e-06, 6.02796774e-07, 1.49267125e-05, ...,
#         1.41751923e-04, 2.03475724e-06, 1.40268639e-06], dtype=float32),
#  'human_ADGRF5': array([1.9115807e-05, 5.3249005e-07, 3.8233379e-04, ..., 7.2142649e-03,
#         2.2393433e-06, 9.3994879e-07], dtype=float32),
#  'human_ADGRG4': array([1.19261995e-05, 4.84476686e-07, 1.99715778e-05, ...,
#         1.16565752e-05, 1.14306533e-06, 6.72769886e-07], dtype=float32),
#  'human_ADGRG6': array([3.0137251e-06, 1.6765447e-06, 8.6790769e-06, ..., 1.5791151e-05,
#         1.5977346e-06, 4.7740182e-06], dtype=float32),
#  'human_ADGRG7': array([2.6573289e-06, 2.5104678e-06, 6.9662833e-06, ..., 1.6311338e-05,
#         1.2572664e-06, 2.8120733e-06], dtype=float32),
#  'human_ADGRL1': array([5.49649412e-05, 4.75198561e-07, 1.38297655e-05, ...,
#         3.35130062e-06, 1.93521237e-06, 9.91485649e-07], dtype=float32),
#  'human_ADGRL2': array([3.1610401e-05, 7.9331858e-07, 7.2677340e-03, ..., 3.5356963e-05,
#         7.7707164e-06, 1.2378215e-06], dtype=float32),
#  'human_ADGRL4': array([1.6155271e-05, 5.4491085e-07, 1.1388642e-03, ..., 3.0073372e-04,
#         2.7364965e-06, 1.4343024e-06], dtype=float32),
#  'human_ADGRV1': array([2.0285061e-05, 5.0792926e-07, 7.3414395e-04, ..., 1.2935574e-05,
#         1.6067437e-06, 1.0215909e-06], dtype=float32),
#  'human_ADH1A': array([8.3746290e-06, 7.9611902e-07, 6.2493942e-05, ..., 1.4341046e-05,
#         3.5439311e-06, 2.4394606e-06], dtype=float32),
#  'human_ADH4': array([1.3054745e-05, 5.3247885e-07, 2.1641317e-04, ..., 5.5496794e-06,
#         2.2958216e-06, 1.0134437e-06], dtype=float32),
#  'human_ADH6': array([9.02922875e-06, 6.11765870e-07, 1.12582471e-04, ...,
#         1.18141525e-05, 2.56640624e-06, 1.18457808e-06], dtype=float32),
#  'human_ADI1': array([1.1314728e-05, 8.1335463e-07, 1.5420408e-05, ..., 2.5496470e-06,
#         1.7367378e-06, 1.4794058e-06], dtype=float32),
#  'human_ADIPOR2': array([3.7414837e-05, 5.0768324e-07, 3.4215947e-04, ..., 6.0443654e-06,
#         2.7132207e-06, 1.3442065e-06], dtype=float32),
#  'human_ADIRF': array([5.6091776e-06, 7.1578148e-07, 2.6379546e-06, ..., 2.4944065e-06,
#         8.6413866e-07, 1.7327225e-06], dtype=float32),
#  'human_ADM': array([2.0829466e-06, 1.9624827e-06, 1.6461020e-06, ..., 3.0998749e-06,
#         1.8997974e-06, 4.0362879e-06], dtype=float32),
#  'human_ADNP2': array([1.3355843e-05, 5.0719785e-07, 5.5826545e-06, ..., 2.5449463e-06,
#         9.6496831e-07, 1.1450369e-06], dtype=float32),
#  'human_ADORA2A': array([1.9858970e-05, 6.0014270e-07, 4.1423213e-05, ..., 1.0243484e-05,
#         1.8692544e-06, 1.4278360e-06], dtype=float32),
#  'human_ADORA2B': array([1.6672308e-05, 5.8764533e-07, 3.5469930e-05, ..., 2.8709008e-05,
#         2.2447080e-06, 1.4097363e-06], dtype=float32),
#  'human_ADPRM': array([3.4248346e-06, 1.3236177e-06, 4.7494505e-06, ..., 3.8367484e-06,
#         1.4103683e-06, 1.9020291e-06], dtype=float32),
#  'human_ADRA1B': array([3.7264988e-05, 4.9475074e-07, 1.6173553e-05, ..., 2.4131148e-06,
#         1.2341073e-06, 8.7414890e-07], dtype=float32),
#  'human_ADRA2A': array([1.5944742e-04, 5.0820250e-07, 7.9009696e-05, ..., 7.1440154e-06,
#         2.4605872e-06, 1.3798971e-06], dtype=float32),
#  'human_ADRA2C': array([1.0660233e-04, 5.1702540e-07, 3.4596927e-05, ..., 4.7634217e-06,
#         2.5859033e-06, 1.2978037e-06], dtype=float32),
#  'human_ADRB1': array([1.4431191e-04, 5.2902686e-07, 4.3364362e-05, ..., 5.8597961e-06,
#         2.5606123e-06, 1.2895598e-06], dtype=float32),
#  'human_ADRB2': array([5.5108652e-05, 5.4501112e-07, 3.8000647e-04, ..., 1.2670131e-05,
#         2.8614090e-06, 1.1417089e-06], dtype=float32),
#  'human_ADRM1': array([2.2926249e-06, 2.0974784e-04, 1.2003294e-06, ..., 1.3422887e-06,
#         1.1741631e-06, 1.7470813e-05], dtype=float32),
#  'human_ADSL': array([1.9169013e-06, 1.5916847e-04, 1.6212896e-06, ..., 1.2137942e-06,
#         1.4894456e-06, 4.7478657e-06], dtype=float32),
#  'human_ADTRP': array([1.33315516e-05, 4.79555354e-07, 1.16251416e-04, ...,
#         4.26084853e-06, 1.84042005e-06, 8.37582263e-07], dtype=float32),
#  'human_AEBP1': array([3.5965575e-05, 5.0468014e-07, 2.6901955e-05, ..., 3.7196442e-06,
#         1.5871494e-06, 8.8029526e-07], dtype=float32),
#  'human_AEBP2': array([2.4461069e-06, 2.0250221e-04, 1.3830828e-06, ..., 1.7612715e-06,
#         1.3818843e-06, 3.9955441e-05], dtype=float32),
#  'human_AFAP1': array([1.7407547e-05, 1.5035416e-06, 1.6012659e-06, ..., 2.5956333e-06,
#         9.0727713e-07, 5.6716717e-06], dtype=float32),
#  'human_AFAP1L2': array([8.5175699e-05, 5.3679338e-07, 4.7112321e-06, ..., 6.2352524e-06,
#         1.0072577e-06, 9.3500205e-07], dtype=float32),
#  'human_AFF1': array([8.0410928e-06, 9.6282656e-07, 1.6581741e-06, ..., 1.7358286e-06,
#         7.7843379e-07, 5.5838259e-06], dtype=float32),
#  'human_AFF3': array([6.5982813e-06, 1.2206571e-06, 1.6688605e-06, ..., 1.2450731e-06,
#         8.5267703e-07, 5.1328984e-06], dtype=float32),
#  'human_AFG1L': array([3.8133769e-06, 1.6019884e-06, 1.0801049e-05, ..., 2.9610487e-06,
#         1.9778199e-06, 6.6193256e-06], dtype=float32),
#  'human_AFM': array([4.0920809e-06, 6.7138728e-07, 3.2052820e-05, ..., 1.2176783e-04,
#         1.9925531e-06, 1.4860773e-06], dtype=float32),
#  'human_AFMID': array([1.9776060e-05, 4.6185994e-07, 2.9280018e-05, ..., 2.5161460e-06,
#         1.3105071e-06, 7.9088090e-07], dtype=float32),
#  'human_AFP': array([3.03131992e-06, 1.47841990e-06, 1.04852015e-05, ...,
#         2.01771309e-05, 2.19269486e-06, 2.18224932e-06], dtype=float32),
#  'human_AFTPH': array([2.4801977e-06, 3.9230849e-06, 1.4704709e-06, ..., 3.7730276e-06,
#         8.0394403e-07, 8.1027611e-06], dtype=float32),
#  'human_AGA': array([1.4486768e-05, 4.9908164e-07, 1.5563297e-04, ..., 6.8322270e-06,
#         1.0018072e-05, 1.0124130e-06], dtype=float32),
#  'human_AGAP1': array([3.3227290e-04, 4.9368316e-07, 2.8274970e-05, ..., 3.3080551e-06,
#         1.7427521e-06, 1.0623321e-06], dtype=float32),
#  'human_AGAP2': array([1.14184560e-03, 5.18584841e-07, 1.08506365e-05, ...,
#         2.40000304e-06, 1.49874563e-06, 1.15526950e-06], dtype=float32),
#  'human_AGAP4': array([2.5429667e-04, 4.8947288e-07, 2.0572774e-05, ..., 2.9682074e-06,
#         1.5543864e-06, 1.0143614e-06], dtype=float32),
#  'human_AGBL4': array([1.7585005e-06, 3.5723316e-04, 1.5530306e-06, ..., 1.3362780e-06,
#         1.4651071e-06, 1.3907403e-05], dtype=float32),
#  'human_AGFG1': array([1.5835989e-03, 4.6477706e-07, 1.0634649e-05, ..., 2.4576157e-06,
#         1.2056320e-06, 2.1000142e-06], dtype=float32),
#  'human_AGGF1': array([1.4188398e-05, 7.0745386e-07, 5.2706068e-06, ..., 1.9638233e-06,
#         9.0431502e-07, 1.0809122e-06], dtype=float32),
#  'human_AGL': array([3.2993780e-06, 2.7468584e-06, 4.5026286e-06, ..., 1.8085429e-06,
#         1.3347903e-06, 2.0107257e-06], dtype=float32),
#  'human_AGMAT': array([3.5438283e-05, 4.7224441e-07, 1.3329752e-04, ..., 5.6068943e-06,
#         2.7494661e-06, 1.1716576e-06], dtype=float32),
#  'human_AGMO': array([1.31481165e-05, 5.14108194e-07, 1.54656955e-05, ...,
#         2.02571141e-06, 1.32919354e-06, 7.69814676e-07], dtype=float32),
#  'human_AGO1': array([3.0136262e-05, 5.8923183e-07, 7.1066388e-05, ..., 3.6184849e-06,
#         2.3711737e-06, 1.3214734e-06], dtype=float32),
#  'human_AGO2': array([3.1259624e-05, 4.6288739e-07, 4.5382312e-05, ..., 2.8967982e-06,
#         1.7755476e-06, 9.3535698e-07], dtype=float32),
#  'human_AGPAT2': array([2.5742847e-06, 2.2966976e-06, 4.2867796e-06, ..., 4.8470711e-06,
#         1.6439354e-06, 8.1572507e-06], dtype=float32),
#  'human_AGPAT4': array([2.1996505e-06, 6.6871089e-06, 3.0339199e-06, ..., 1.4646250e-06,
#         1.1951220e-06, 2.9204762e-06], dtype=float32),
#  'human_AGR2': array([4.1175637e-05, 7.1522055e-07, 9.5764938e-04, ..., 1.7123504e-05,
#         2.5203440e-06, 1.3253759e-06], dtype=float32),
#  'human_AGR3': array([2.7724433e-05, 6.6419727e-07, 1.2224495e-03, ..., 1.7444107e-05,
#         2.9160230e-06, 1.1929105e-06], dtype=float32),
#  'human_AGRN': array([1.2825108e-05, 5.8308115e-07, 1.6845830e-05, ..., 1.6444192e-05,
#         4.8951183e-06, 1.9703139e-06], dtype=float32),
#  'human_AGT': array([1.9866709e-06, 8.3773966e-07, 3.8260609e-06, ..., 1.4206298e-05,
#         1.2462527e-06, 2.4502417e-06], dtype=float32),
#  'human_AGTPBP1': array([4.6117793e-06, 5.5337396e-06, 2.2222068e-06, ..., 1.8273155e-06,
#         1.2737752e-06, 7.9894735e-06], dtype=float32),
#  'human_AGTR1': array([2.1727667e-05, 6.4449068e-07, 1.3699751e-04, ..., 2.5664383e-04,
#         3.1633729e-06, 3.2415230e-06], dtype=float32),
#  'human_AGTRAP': array([1.3793517e-05, 7.4257002e-07, 8.4254261e-06, ..., 1.7417535e-06,
#         1.0528062e-06, 7.4832906e-07], dtype=float32),
#  'human_AGXT2': array([2.5743768e-05, 5.1661476e-07, 5.0087861e-04, ..., 6.6737998e-06,
#         2.8547936e-06, 1.1320195e-06], dtype=float32),
#  'human_AHCTF1': array([8.1810986e-06, 8.0860286e-07, 3.5580802e-06, ..., 1.6021198e-06,
#         9.8791497e-07, 1.0720955e-06], dtype=float32),
#  'human_AHDC1': array([9.7305583e-06, 5.7648651e-07, 9.8380076e-07, ..., 1.2417172e-06,
#         9.1542518e-07, 5.8231012e-06], dtype=float32),
#  'human_AHI1': array([8.2624043e-05, 7.1575829e-07, 2.7196053e-05, ..., 3.8515118e-06,
#         1.3736997e-06, 8.5568047e-07], dtype=float32),
#  'human_AHNAK': array([6.82441605e-05, 5.12019881e-07, 1.26395735e-05, ...,
#         7.18568253e-06, 1.32258924e-06, 1.12262114e-06], dtype=float32),
#  'human_AHR': array([1.3503403e-04, 4.9171587e-07, 1.5516531e-05, ..., 2.4704743e-06,
#         1.3486737e-06, 1.3480025e-06], dtype=float32),
#  'human_AHSP': array([1.8929333e-05, 4.6190002e-07, 1.0587250e-05, ..., 1.7487606e-06,
#         1.2395001e-06, 7.2617058e-07], dtype=float32),
#  'human_AIDA': array([6.4456814e-05, 5.0463780e-07, 1.8524601e-05, ..., 3.7596840e-06,
#         1.5062296e-06, 8.6322433e-07], dtype=float32),
#  'human_AIF1': array([1.1965104e-05, 8.4422720e-07, 7.7229824e-06, ..., 4.1725593e-06,
#         1.5560298e-06, 3.3429533e-06], dtype=float32),
#  'human_AIF1L': array([3.3242250e-06, 1.2346849e-05, 1.8435960e-06, ..., 1.5493694e-06,
#         1.0046531e-06, 6.8014706e-06], dtype=float32),
#  'human_AIMP2': array([5.2147170e-05, 4.4742978e-07, 2.0804166e-05, ..., 3.3903357e-06,
#         1.1988512e-06, 9.4009937e-07], dtype=float32),
#  'human_AIPL1': array([1.9581446e-05, 5.2867279e-07, 4.1634747e-05, ..., 5.8285964e-06,
#         1.5297130e-06, 1.0886951e-06], dtype=float32),
#  'human_AJAP1': array([2.0609759e-06, 3.5378564e-06, 1.1015252e-06, ..., 3.1000643e-06,
#         9.5049364e-07, 9.4988063e-06], dtype=float32),
#  'human_AJM1': array([4.7459330e-06, 2.0020482e-06, 1.2169132e-06, ..., 1.4888362e-06,
#         9.9798672e-07, 2.4014376e-05], dtype=float32),
#  'human_AJUBA': array([1.4880912e-04, 5.2169349e-07, 3.6203128e-05, ..., 5.2679334e-06,
#         1.7371650e-06, 3.9563583e-06], dtype=float32),
#  'human_AK4': array([2.2271990e-06, 5.3801319e-05, 3.4007305e-06, ..., 2.1790531e-06,
#         1.3771796e-06, 7.8978455e-06], dtype=float32),
#  'human_AK5': array([9.8209239e-06, 8.8881194e-07, 1.1993379e-05, ..., 3.7483278e-06,
#         1.5840255e-06, 2.8919208e-06], dtype=float32),
#  'human_AK7': array([6.9428902e-06, 7.9244444e-07, 3.7609464e-06, ..., 1.3135401e-06,
#         9.4032180e-07, 1.2192226e-06], dtype=float32),
#  'human_AK8': array([8.1409626e-06, 6.7962350e-07, 1.8949004e-05, ..., 1.3062193e-05,
#         1.9622339e-06, 1.5934404e-06], dtype=float32),
#  'human_AK9': array([2.0499820e-05, 5.4200484e-07, 2.7834565e-05, ..., 6.6463863e-06,
#         1.3325697e-06, 1.0647267e-06], dtype=float32),
#  'human_AKAP10': array([2.3362194e-05, 5.0565575e-07, 3.9306160e-06, ..., 1.3315446e-06,
#         8.8404329e-07, 9.9303475e-07], dtype=float32),
#  'human_AKAP12': array([9.0555732e-06, 6.1741775e-07, 1.8445475e-06, ..., 4.4259828e-06,
#         1.0905759e-06, 1.1566745e-05], dtype=float32),
#  'human_AKAP13': array([1.7998615e-05, 8.4492547e-07, 4.7338772e-06, ..., 2.2336164e-06,
#         9.5943790e-07, 1.4490298e-06], dtype=float32),
#  'human_AKAP3': array([2.5576508e-05, 5.0375786e-07, 5.2984456e-06, ..., 2.6971838e-06,
#         1.0451631e-06, 8.5159866e-07], dtype=float32),
#  'human_AKAP4': array([1.8353694e-05, 5.1768552e-07, 3.1986294e-06, ..., 3.2165797e-06,
#         9.1203543e-07, 1.1631951e-06], dtype=float32),
#  'human_AKAP7': array([3.7608726e-05, 6.8482905e-07, 3.2112912e-05, ..., 2.7214173e-06,
#         1.4178490e-06, 9.0769333e-07], dtype=float32),
#  'human_AKIRIN1': array([2.0493653e-06, 1.3051670e-05, 1.1800915e-06, ..., 1.5029811e-06,
#         9.5366158e-07, 2.6103105e-05], dtype=float32),
#  'human_AKIRIN2': array([2.0325213e-06, 7.6002441e-05, 1.4418493e-06, ..., 1.3685726e-06,
#         1.2748593e-06, 7.2921022e-05], dtype=float32),
#  'human_AKNA': array([1.3791137e-05, 4.9180352e-07, 1.6989997e-06, ..., 3.2839803e-06,
#         8.7682986e-07, 1.1327452e-06], dtype=float32),
#  'human_AKR1B1': array([8.5017737e-06, 8.3596791e-07, 2.3762535e-04, ..., 5.4200409e-06,
#         3.0732681e-06, 1.8313873e-06], dtype=float32),
#  'human_AKR1B10': array([1.0113665e-05, 7.8639238e-07, 8.1755692e-04, ..., 5.7779012e-06,
#         3.3808240e-06, 2.4608664e-06], dtype=float32),
#  'human_AKR1C1': array([2.4908791e-06, 4.9324485e-06, 6.5595691e-06, ..., 2.4744663e-06,
#         1.5798269e-06, 2.6835626e-06], dtype=float32),
#  'human_AKR1C2': array([2.3493512e-06, 4.9669684e-06, 6.0953807e-06, ..., 2.8045315e-06,
#         1.4778152e-06, 2.4796350e-06], dtype=float32),
#  'human_AKR1C3': array([2.2067647e-06, 7.1809764e-06, 5.2067385e-06, ..., 2.7051155e-06,
#         1.5349124e-06, 2.5738750e-06], dtype=float32),
#  'human_AKR1C4': array([2.1064789e-06, 6.8285922e-06, 4.9588421e-06, ..., 2.6338046e-06,
#         1.4972700e-06, 2.4470985e-06], dtype=float32),
#  'human_AKR1D1': array([6.8395416e-06, 6.8028493e-07, 2.7462692e-04, ..., 5.8525584e-06,
#         2.3337552e-06, 1.4350125e-06], dtype=float32),
#  'human_AKR7A2': array([2.2111676e-06, 5.2154801e-06, 3.7768582e-06, ..., 2.3070766e-06,
#         1.3514342e-06, 2.5320910e-06], dtype=float32),
#  'human_AKR7A3': array([1.5606904e-06, 6.5810709e-05, 1.5198742e-06, ..., 1.9729860e-06,
#         1.2044575e-06, 5.5010905e-06], dtype=float32),
#  'human_AKT1': array([6.6075881e-06, 6.0925327e-06, 4.0233754e-06, ..., 3.7341847e-06,
#         1.8335334e-06, 1.8766045e-04], dtype=float32),
#  'human_AKT3': array([2.0134285e-05, 1.0888156e-06, 1.6096448e-05, ..., 6.2718823e-06,
#         1.8486613e-06, 9.3200060e-06], dtype=float32),
#  'human_ALAD': array([2.6665683e-05, 4.3707800e-07, 1.6136655e-05, ..., 2.9120076e-06,
#         1.2825101e-06, 8.4570746e-07], dtype=float32),
#  'human_ALAS1': array([3.9940358e-05, 5.1040615e-07, 9.6463809e-05, ..., 3.4625793e-06,
#         2.1892515e-06, 1.2144403e-06], dtype=float32),
#  'human_ALCAM': array([3.1238540e-06, 9.1502761e-06, 2.7471781e-06, ..., 2.0341278e-05,
#         1.2230960e-06, 8.0247601e-06], dtype=float32),
#  'human_ALDH16A1': array([6.5516301e-06, 5.7375235e-07, 3.1387524e-06, ..., 3.4135230e-06,
#         1.1500699e-06, 2.2523225e-06], dtype=float32),
#  'human_ALDH1A1': array([2.0617417e-05, 1.0281864e-06, 9.4247656e-03, ..., 1.2708250e-05,
#         4.9238902e-06, 1.9088509e-06], dtype=float32),
#  'human_ALDH1A2': array([2.3833629e-05, 5.1457272e-07, 3.2332030e-04, ..., 3.6251406e-06,
#         2.3407165e-06, 1.0566092e-06], dtype=float32),
#  'human_ALDH1A3': array([4.8234735e-05, 5.0734104e-07, 5.0274882e-04, ..., 4.1551466e-06,
#         2.5560621e-06, 1.1703844e-06], dtype=float32),
#  'human_ALDH1B1': array([3.0252162e-05, 8.5582656e-07, 6.7497133e-03, ..., 6.9987659e-06,
#         5.6341987e-06, 1.7362972e-06], dtype=float32),
#  'human_ALDH1L1': array([1.6574619e-05, 6.1970189e-07, 8.6213018e-05, ..., 4.1835401e-06,
#         1.7923138e-06, 1.5867333e-06], dtype=float32),
#  'human_ALDH1L2': array([1.6846650e-05, 6.5276527e-07, 4.7073793e-04, ..., 5.3566296e-06,
#         2.5143638e-06, 1.5201033e-06], dtype=float32),
#  'human_ALDH5A1': array([3.1960786e-05, 5.3043783e-07, 5.7903409e-04, ..., 7.7104505e-06,
#         3.2908367e-06, 1.6137078e-06], dtype=float32),
#  'human_ALDH6A1': array([1.4803266e-05, 6.1089077e-07, 3.8059670e-04, ..., 5.3377566e-06,
#         5.5171727e-06, 2.2060221e-06], dtype=float32),
#  'human_ALDH8A1': array([4.9142263e-06, 9.7239388e-07, 1.2575152e-05, ..., 2.9973271e-06,
#         1.4432222e-06, 1.9624827e-06], dtype=float32),
#  'human_ALDOA': array([1.0036969e-05, 1.1510442e-06, 2.5070813e-05, ..., 3.0546141e-06,
#         2.3470534e-06, 1.5282942e-06], dtype=float32),
#  'human_ALDOB': array([1.5524494e-05, 5.4517540e-07, 2.9519713e-05, ..., 2.8454192e-06,
#         1.7447427e-06, 9.8269152e-07], dtype=float32),
#  'human_ALDOC': array([1.24559265e-05, 5.88583134e-07, 2.76479404e-05, ...,
#         3.40457609e-06, 2.35743755e-06, 1.27554154e-06], dtype=float32),
#  'human_ALG1': array([2.0264961e-06, 3.5160201e-06, 2.6758091e-06, ..., 1.9998920e-06,
#         1.7426972e-06, 6.5890499e-06], dtype=float32),
#  'human_ALG10B': array([2.0341733e-06, 9.5706912e-07, 9.8303981e-06, ..., 3.0500526e-06,
#         1.7045354e-06, 1.6166191e-06], dtype=float32),
#  'human_ALG12': array([4.6535210e-06, 6.6394898e-07, 1.4751574e-05, ..., 2.2738097e-06,
#         2.2801657e-06, 1.2152628e-06], dtype=float32),
#  'human_ALG2': array([9.7691918e-06, 6.2042329e-07, 3.6776080e-05, ..., 4.7830781e-06,
#         1.6604783e-06, 1.3837873e-06], dtype=float32),
#  'human_ALG5': array([1.2297376e-05, 5.9513962e-07, 7.7584577e-05, ..., 4.1065537e-06,
#         1.9980885e-06, 1.4303382e-06], dtype=float32),
#  'human_ALG6': array([3.7262944e-06, 8.3748643e-07, 2.1978021e-05, ..., 2.3327273e-06,
#         1.4416390e-06, 1.3085988e-06], dtype=float32),
#  'human_ALG8': array([5.9912850e-06, 6.6008454e-07, 4.4079101e-05, ..., 4.0415539e-06,
#         1.6016996e-06, 1.2921967e-06], dtype=float32),
#  'human_ALK': array([3.6793253e-06, 3.3564725e-06, 1.9682425e-06, ..., 2.9463276e-06,
#         1.1472853e-06, 1.0531501e-05], dtype=float32),
#  'human_ALKAL2': array([1.4646739e-06, 7.2460309e-05, 1.2963193e-06, ..., 1.9610384e-06,
#         3.7150321e-06, 8.2947545e-06], dtype=float32),
#  'human_ALKBH3': array([4.6721379e-05, 4.3340913e-07, 1.7193244e-05, ..., 2.5546974e-06,
#         1.3969526e-06, 8.7662170e-07], dtype=float32),
#  'human_ALKBH5': array([1.6248350e-05, 6.3816412e-07, 1.8944567e-06, ..., 1.1451984e-06,
#         1.1095484e-06, 1.3185593e-06], dtype=float32),
#  'human_ALMS1': array([2.1317821e-05, 4.9531394e-07, 4.6857185e-06, ..., 2.2400375e-06,
#         9.0745448e-07, 7.5671772e-07], dtype=float32),
#  'human_ALOX15': array([3.0963060e-06, 1.1284646e-06, 3.2976543e-06, ..., 1.9519089e-06,
#         1.3162073e-06, 1.7898113e-06], dtype=float32),
#  'human_ALOX15B': array([3.1991419e-06, 7.2402065e-07, 5.0431763e-06, ..., 4.2153110e-06,
#         2.0572234e-06, 1.3791919e-06], dtype=float32),
#  'human_ALOX5': array([4.5774054e-06, 1.2176005e-06, 1.2661832e-05, ..., 3.1537338e-06,
#         2.5161532e-06, 2.3017253e-06], dtype=float32),
#  'human_ALOX5AP': array([1.8872814e-06, 3.8264061e-05, 1.3876515e-06, ..., 1.7568244e-06,
#         1.0264847e-06, 3.7837945e-06], dtype=float32),
#  'human_ALOXE3': array([3.7695968e-06, 8.3658517e-07, 6.0622669e-06, ..., 5.3149543e-06,
#         2.6440246e-06, 3.8525845e-06], dtype=float32),
#  'human_ALPI': array([4.4159819e-06, 5.4253752e-07, 3.9690794e-06, ..., 2.2628790e-06,
#         1.2416237e-06, 1.0338698e-06], dtype=float32),
#  'human_ALPK3': array([1.9627663e-05, 4.9684684e-07, 1.6119205e-06, ..., 2.1598573e-06,
#         7.7962471e-07, 1.0517224e-06], dtype=float32),
#  'human_ALS2CL': array([2.6403509e-06, 7.7546184e-07, 1.9942202e-06, ..., 6.8422883e-06,
#         1.1779001e-06, 3.0215356e-06], dtype=float32),
#  'human_ALX1': array([4.9813825e-05, 5.0874314e-07, 1.0280116e-05, ..., 2.5913469e-06,
#         1.3829443e-06, 1.4776144e-05], dtype=float32),
#  'human_ALYREF': array([2.0925474e-06, 1.3898223e-04, 1.1491884e-06, ..., 1.5134998e-06,
#         1.6425407e-06, 1.5218837e-05], dtype=float32),
#  'human_AMACR': array([4.7693629e-06, 7.1330373e-07, 1.4408357e-05, ..., 2.4946494e-06,
#         1.7616999e-06, 1.9190284e-06], dtype=float32),
#  'human_AMBP': array([9.6813519e-06, 5.7721269e-07, 2.3916292e-04, ..., 2.0269658e-04,
#         3.6716071e-06, 1.5588131e-06], dtype=float32),
#  'human_AMBRA1': array([3.3818415e-05, 5.4129043e-07, 3.4432758e-06, ..., 1.7749602e-06,
#         1.0829252e-06, 1.3927704e-06], dtype=float32),
#  'human_AMD1': array([2.7864639e-06, 7.7065728e-05, 3.8045571e-06, ..., 1.4272778e-06,
#         1.2315126e-06, 4.7971803e-06], dtype=float32),
#  'human_AMDHD2': array([4.4495941e-06, 7.4328346e-07, 4.1107382e-06, ..., 2.6232760e-06,
#         1.5957291e-06, 2.1438855e-06], dtype=float32),
#  'human_AMFR': array([1.3110765e-05, 5.6548720e-07, 7.8917546e-06, ..., 3.3433807e-06,
#         1.4071171e-06, 1.3150379e-06], dtype=float32),
#  'human_AMHR2': array([1.7988457e-05, 7.4942324e-07, 1.7995630e-05, ..., 1.5387679e-05,
#         1.6784306e-06, 1.3116161e-06], dtype=float32),
#  'human_AMIGO2': array([9.8659457e-06, 6.5833814e-07, 9.7004722e-06, ..., 1.5906393e-04,
#         2.0457837e-06, 2.4504732e-06], dtype=float32),
#  'human_AMMECR1': array([4.0038080e-06, 1.4003400e-05, 1.7056868e-06, ..., 1.1096088e-06,
#         1.6107035e-06, 8.5630218e-06], dtype=float32),
#  'human_AMMECR1L': array([3.2893715e-06, 1.1204782e-05, 1.4932515e-06, ..., 1.3047967e-06,
#         1.2552968e-06, 1.1261087e-05], dtype=float32),
#  'human_AMN1': array([1.2802854e-05, 6.1590288e-07, 1.6285674e-05, ..., 5.7497796e-06,
#         1.5690672e-06, 1.0808729e-06], dtype=float32),
#  'human_AMOT': array([1.1416594e-05, 2.0145626e-06, 1.5727211e-06, ..., 1.6352823e-06,
#         1.0641076e-06, 3.4872864e-05], dtype=float32),
#  'human_AMOTL2': array([1.0929620e-05, 5.4353131e-07, 1.8077756e-06, ..., 1.7576422e-06,
#         9.0603891e-07, 3.5695950e-06], dtype=float32),
#  'human_AMPH': array([5.8476098e-06, 1.9821762e-06, 1.2803947e-06, ..., 1.2910843e-06,
#         7.7318964e-07, 6.1993687e-06], dtype=float32),
#  'human_AMT': array([3.7705818e-06, 7.9575614e-07, 4.7487624e-06, ..., 1.7672580e-06,
#         1.5246577e-06, 1.7598679e-06], dtype=float32),
#  'human_AMZ1': array([1.8322764e-06, 2.1375504e-06, 1.2910117e-06, ..., 1.8350360e-06,
#         9.5313425e-07, 4.2150377e-06], dtype=float32),
#  'human_ANAPC1': array([9.7932489e-06, 1.4437262e-06, 4.3615305e-06, ..., 1.7586113e-06,
#         9.6126041e-07, 2.0442587e-06], dtype=float32),
#  'human_ANAPC15': array([2.2333695e-06, 8.3933744e-05, 1.1352531e-06, ..., 1.0598962e-06,
#         9.2606837e-07, 7.4054842e-06], dtype=float32),
#  'human_ANG': array([2.3491114e-06, 1.0766149e-06, 5.0287972e-06, ..., 1.1878062e-05,
#         2.3555016e-05, 1.0590081e-06], dtype=float32),
#  'human_ANGPT1': array([1.1507760e-05, 5.5304503e-07, 3.5969006e-05, ..., 1.1725524e-05,
#         2.3057987e-06, 1.5273019e-06], dtype=float32),
#  'human_ANGPT2': array([1.5672867e-05, 5.0920238e-07, 7.8562261e-05, ..., 4.3729819e-05,
#         2.4505127e-06, 1.0627658e-06], dtype=float32),
#  'human_ANGPTL4': array([4.9788819e-06, 5.2227745e-07, 3.6813926e-06, ..., 8.5428255e-06,
#         2.2626327e-06, 1.3328670e-06], dtype=float32),
#  'human_ANGPTL6': array([2.9728180e-05, 4.6473008e-07, 2.1669457e-05, ..., 2.9896305e-06,
#         5.0767280e-06, 9.0571319e-07], dtype=float32),
#  'human_ANK2': array([1.0350655e-04, 5.0033503e-07, 5.0021528e-05, ..., 4.1733033e-06,
#         2.5697373e-06, 9.3623254e-07], dtype=float32),
#  'human_ANK3': array([7.7628101e-05, 4.5735933e-07, 1.3254499e-05, ..., 2.7126180e-06,
#         1.4442302e-06, 9.4249981e-07], dtype=float32),
#  'human_ANKAR': array([2.2115359e-05, 6.4151897e-07, 1.0260096e-05, ..., 1.3364725e-05,
#         1.4774939e-06, 2.2682934e-06], dtype=float32),
#  'human_ANKEF1': array([4.2034844e-06, 1.2191418e-05, 2.0509235e-06, ..., 2.4842743e-06,
#         1.2392270e-06, 2.5662230e-06], dtype=float32),
#  'human_ANKH': array([1.0220738e-05, 6.0984416e-07, 5.9437589e-06, ..., 1.3882484e-06,
#         9.5927408e-07, 8.5556707e-07], dtype=float32),
#  'human_ANKHD1': array([1.1618403e-04, 5.2354204e-07, 4.0135565e-06, ..., 2.0558111e-06,
#         1.1396322e-06, 1.9095264e-06], dtype=float32),
#  'human_ANKIB1': array([5.0306990e-05, 4.5723459e-07, 2.6425992e-05, ..., 3.4835052e-06,
#         1.3668898e-06, 1.1024290e-06], dtype=float32),
#  'human_ANKK1': array([3.5122655e-05, 6.0699227e-07, 6.4828550e-05, ..., 2.8575627e-05,
#         2.0770055e-06, 1.2974435e-06], dtype=float32),
#  'human_ANKMY2': array([2.5412877e-05, 5.0647958e-07, 8.0873133e-06, ..., 1.9045739e-06,
#         1.2603865e-06, 9.7952807e-07], dtype=float32),
#  'human_ANKRA2': array([5.9378246e-05, 7.5914642e-07, 4.1536887e-06, ..., 2.6129992e-06,
#         1.1628666e-06, 3.4185009e-06], dtype=float32),
#  'human_ANKRD13A': array([2.4730687e-05, 5.0328202e-07, 3.8317336e-05, ..., 2.9061039e-06,
#         1.5626830e-06, 8.2450401e-07], dtype=float32),
#  'human_ANKRD18A': array([1.3091837e-05, 5.3027600e-07, 4.8021143e-06, ..., 7.4687005e-06,
#         8.2041350e-07, 7.9525546e-07], dtype=float32),
#  'human_ANKRD22': array([5.5072110e-06, 1.0791766e-06, 4.9293685e-06, ..., 1.4779103e-05,
#         1.4409078e-06, 2.1658659e-06], dtype=float32),
#  'human_ANKRD26': array([6.7415007e-05, 6.7903846e-07, 9.5390305e-06, ..., 5.9768240e-06,
#         1.0573058e-06, 8.6778061e-07], dtype=float32),
#  'human_ANKRD30A': array([3.9929466e-05, 5.9337708e-07, 5.6841586e-06, ..., 7.1993536e-06,
#         9.0668544e-07, 1.2076009e-06], dtype=float32),
#  'human_ANKRD30BL': array([6.0891321e-05, 5.5987425e-07, 1.7086360e-05, ..., 3.0218311e-05,
#         1.4749822e-06, 9.3639591e-07], dtype=float32),
#  'human_ANKRD35': array([1.7464899e-05, 5.2097806e-07, 2.2686352e-06, ..., 4.7823755e-06,
#         9.9406373e-07, 1.5839817e-06], dtype=float32),
#  'human_ANKRD36': array([4.8586116e-05, 5.3102951e-07, 8.9437499e-06, ..., 7.7198756e-06,
#         1.0538106e-06, 9.2031661e-07], dtype=float32),
#  'human_ANKRD36C': array([4.05414394e-05, 5.17537444e-07, 1.34332795e-05, ...,
#         4.31971284e-06, 1.19566812e-06, 7.97327118e-07], dtype=float32),
#  'human_ANKRD37': array([3.0337144e-06, 1.3367190e-06, 2.6955486e-06, ..., 3.5736857e-06,
#         9.1119995e-07, 1.4720550e-06], dtype=float32),
#  'human_ANKRD40': array([2.2641601e-05, 6.0639695e-07, 1.3991579e-06, ..., 1.4267307e-06,
#         8.3862210e-07, 4.3221439e-06], dtype=float32),
#  'human_ANKRD49': array([1.9465228e-05, 5.0244705e-07, 6.9319935e-06, ..., 1.7710390e-06,
#         1.0875484e-06, 8.1721970e-07], dtype=float32),
#  'human_ANKRD53': array([4.0788203e-05, 5.2465771e-07, 3.7258110e-06, ..., 4.5818992e-06,
#         9.9246756e-07, 8.3792418e-07], dtype=float32),
#  'human_ANKRD61': array([3.3051336e-05, 5.4889665e-07, 2.6491725e-05, ..., 3.7775877e-05,
#         1.7978501e-06, 9.6714075e-07], dtype=float32),
# ...
#  'human_C9orf50': array([9.6103258e-06, 4.7812011e-07, 3.3751057e-06, ..., 2.1503047e-06,
#         7.8126067e-07, 8.0238908e-07], dtype=float32),
#  'human_C9orf64': array([5.9956915e-06, 7.1516052e-07, 1.2284985e-05, ..., 2.1218302e-06,
#         1.4240243e-06, 1.1391106e-06], dtype=float32),
#  'human_C9orf72': array([4.9935802e-06, 2.9473620e-06, 2.1072524e-06, ..., 3.1209565e-06,
#         1.1191000e-06, 1.0133070e-05], dtype=float32),
#  'human_CA1': array([1.3189032e-05, 7.2495828e-07, 3.8513244e-04, ..., 5.4694210e-06,
#         3.9851157e-06, 2.2365900e-06], dtype=float32),
#  'human_CA12': array([1.1979193e-05, 6.4870102e-07, 2.7021340e-03, ..., 1.2682668e-05,
#         4.0703276e-06, 1.2188586e-06], dtype=float32),
#  'human_CA13': array([7.2169719e-06, 8.3298914e-07, 8.0044942e-05, ..., 4.9372916e-06,
#         4.2072102e-06, 1.8904447e-06], dtype=float32),
#  'human_CA14': array([3.1503489e-06, 1.5645247e-06, 4.9002660e-06, ..., 2.0869134e-06,
#         1.3874583e-06, 2.4913898e-06], dtype=float32),
#  'human_CA2': array([1.1002994e-05, 7.9734843e-07, 5.6712586e-04, ..., 4.2099919e-06,
#         6.9237358e-06, 1.5888774e-06], dtype=float32),
#  'human_CA4': array([9.9149838e-06, 5.6775025e-07, 2.2012119e-04, ..., 1.6229951e-05,
#         4.8391134e-06, 1.2971540e-06], dtype=float32),
#  'human_CA5B': array([2.3184509e-06, 6.8680529e-06, 2.7023359e-06, ..., 1.5203917e-06,
#         1.5803815e-06, 2.8089694e-06], dtype=float32),
#  'human_CA7': array([1.7542270e-05, 5.7488279e-07, 1.6203545e-04, ..., 2.7574515e-06,
#         2.5851366e-06, 1.4099165e-06], dtype=float32),
#  'human_CA8': array([2.9638779e-05, 5.3662143e-07, 7.1603211e-04, ..., 7.1901936e-06,
#         5.5152686e-06, 1.1254210e-06], dtype=float32),
#  'human_CAAP1': array([3.7889895e-05, 6.8210517e-07, 3.9027886e-06, ..., 1.5629097e-06,
#         1.0320640e-06, 1.2253433e-06], dtype=float32),
#  'human_CAB39': array([2.0168482e-06, 1.0040469e-03, 1.6783475e-06, ..., 1.3153515e-06,
#         1.8571111e-06, 1.7720993e-05], dtype=float32),
#  'human_CABIN1': array([3.7515788e-06, 5.0885892e-06, 1.3259713e-06, ..., 1.7043793e-06,
#         9.8656869e-07, 8.1544122e-06], dtype=float32),
#  'human_CABP7': array([7.0967330e-06, 7.0523492e-07, 5.6494578e-06, ..., 5.3502276e-06,
#         1.1332651e-06, 2.2431286e-06], dtype=float32),
#  'human_CACNA1A': array([7.8799523e-05, 4.8963204e-07, 5.9083326e-05, ..., 2.8956215e-06,
#         1.8984482e-06, 9.4249441e-07], dtype=float32),
#  'human_CACNA1D': array([4.0328465e-05, 5.3606595e-07, 6.2178692e-04, ..., 6.1639848e-06,
#         2.4639544e-06, 1.1859933e-06], dtype=float32),
#  'human_CACNA1E': array([1.14787195e-04, 4.98928841e-07, 9.45594220e-05, ...,
#         3.79590983e-06, 2.11382826e-06, 1.01799924e-06], dtype=float32),
#  'human_CACNA1F': array([4.3969270e-05, 4.9570809e-07, 8.1530714e-05, ..., 3.2544708e-06,
#         1.6488233e-06, 1.0069331e-06], dtype=float32),
#  'human_CACNA1G': array([1.2259513e-04, 5.0284586e-07, 8.7863897e-05, ..., 3.7807501e-06,
#         1.7057648e-06, 1.1191448e-06], dtype=float32),
#  'human_CACNA1H': array([7.6569115e-05, 4.9540654e-07, 3.4460139e-05, ..., 2.9519133e-06,
#         1.6220612e-06, 9.7367081e-07], dtype=float32),
#  'human_CACNA1I': array([1.1930222e-04, 5.1707320e-07, 7.3562303e-05, ..., 3.6394265e-06,
#         1.6908126e-06, 1.1290180e-06], dtype=float32),
#  'human_CACNA2D1': array([2.1940064e-06, 4.3727443e-05, 3.5970259e-06, ..., 2.4195440e-06,
#         2.0883806e-06, 1.3222747e-05], dtype=float32),
#  'human_CACNB2': array([2.7535673e-06, 1.6733244e-04, 1.3729400e-06, ..., 1.3627339e-06,
#         1.6327921e-06, 5.0319464e-05], dtype=float32),
#  'human_CACNB3': array([4.3513387e-06, 6.4110341e-06, 2.4547298e-06, ..., 1.4512245e-06,
#         1.7031169e-06, 2.7029508e-05], dtype=float32),
#  'human_CACNG4': array([3.7690215e-06, 6.9734087e-06, 1.9500389e-06, ..., 2.5437209e-06,
#         2.4169772e-06, 3.9709703e-05], dtype=float32),
#  'human_CACNG8': array([2.5390941e-06, 7.9046025e-05, 1.2094162e-06, ..., 1.5348992e-06,
#         1.8037321e-06, 9.9681107e-05], dtype=float32),
#  'human_CACYBP': array([2.6121395e-06, 3.0881798e-05, 3.8967855e-06, ..., 2.1775365e-06,
#         1.2740595e-06, 4.8140500e-06], dtype=float32),
#  'human_CAD': array([4.0040886e-05, 4.5764338e-07, 5.7497498e-05, ..., 4.2710399e-06,
#         1.9898205e-06, 1.1311897e-06], dtype=float32),
#  'human_CADM1': array([7.3323781e-06, 1.0736242e-06, 7.7788800e-06, ..., 2.9817278e-05,
#         1.6934043e-06, 3.2227513e-06], dtype=float32),
#  'human_CADM2': array([1.4032062e-05, 6.5948052e-07, 9.2026399e-05, ..., 2.0037961e-04,
#         2.3817120e-06, 1.8454430e-06], dtype=float32),
#  'human_CALB1': array([5.9693211e-06, 1.2135592e-06, 1.5003767e-05, ..., 4.8622851e-06,
#         1.4693719e-06, 3.2149571e-06], dtype=float32),
#  'human_CALB2': array([2.5287970e-06, 9.9572033e-05, 2.0678431e-06, ..., 1.6928810e-06,
#         1.2226866e-06, 1.0503477e-05], dtype=float32),
#  'human_CALCB': array([1.3372036e-06, 4.2280735e-06, 1.3290769e-06, ..., 2.4449034e-06,
#         1.8396636e-06, 2.0605789e-06], dtype=float32),
#  'human_CALCOCO1': array([4.6508280e-06, 8.8606987e-07, 2.3487796e-06, ..., 4.4155991e-06,
#         1.2069527e-06, 2.1167745e-05], dtype=float32),
#  'human_CALCRL': array([1.9330424e-05, 5.2133890e-07, 7.4001022e-05, ..., 7.7798968e-06,
#         1.8947710e-06, 9.2500744e-07], dtype=float32),
#  'human_CALD1': array([4.2915428e-05, 5.9603821e-07, 4.1298749e-06, ..., 2.7834071e-06,
#         1.2474252e-06, 1.4040060e-06], dtype=float32),
#  'human_CALHM6': array([2.2080574e-06, 2.3648279e-06, 1.6912965e-06, ..., 3.6908984e-06,
#         1.7571946e-06, 2.3019952e-06], dtype=float32),
#  'human_CALML3': array([5.76689999e-05, 6.74877583e-07, 1.34346439e-04, ...,
#         1.09906605e-05, 4.59996818e-06, 2.85340548e-06], dtype=float32),
#  'human_CALML4': array([6.0879615e-06, 2.0140092e-06, 1.1090349e-05, ..., 5.9063468e-06,
#         1.8652299e-06, 4.6264136e-06], dtype=float32),
#  'human_CALR': array([6.9101930e-06, 1.3889252e-06, 2.1574066e-05, ..., 3.6665192e-06,
#         2.0271609e-06, 1.7384743e-06], dtype=float32),
#  'human_CAMK1': array([9.5452691e-05, 5.2035591e-07, 6.7000452e-05, ..., 4.3789973e-06,
#         1.4886602e-06, 1.4061379e-06], dtype=float32),
#  'human_CAMK1D': array([2.0256980e-04, 7.7042796e-07, 2.9462197e-05, ..., 8.0853852e-06,
#         1.9417973e-06, 5.5084033e-06], dtype=float32),
#  'human_CAMK1G': array([1.3182142e-03, 5.6909141e-07, 5.4416774e-05, ..., 9.2327600e-06,
#         1.5258374e-06, 1.5311068e-06], dtype=float32),
#  'human_CAMK2A': array([1.3705787e-04, 5.5715623e-07, 1.7070732e-04, ..., 9.9706640e-06,
#         2.2843992e-06, 1.2116673e-06], dtype=float32),
#  'human_CAMK2N1': array([1.6262939e-05, 5.5754100e-07, 1.4115100e-05, ..., 1.8633772e-06,
#         1.2277554e-06, 8.0524381e-07], dtype=float32),
#  'human_CAMK4': array([3.0089496e-03, 6.0758475e-07, 1.7697348e-05, ..., 5.8311089e-06,
#         1.5432553e-06, 3.0875867e-06], dtype=float32),
#  'human_CAMKK1': array([2.1644715e-02, 5.6027596e-07, 2.0435600e-05, ..., 3.3801855e-06,
#         1.7586851e-06, 2.0608206e-06], dtype=float32),
#  'human_CAMKK2': array([8.9831284e-04, 4.9924398e-07, 1.2244749e-05, ..., 2.4345100e-06,
#         1.2308610e-06, 1.2115563e-06], dtype=float32),
#  'human_CAMKMT': array([3.6605693e-06, 1.0154386e-06, 1.7041471e-06, ..., 2.0775703e-06,
#         7.8652965e-07, 2.0831274e-06], dtype=float32),
#  'human_CAMKV': array([1.9379829e-04, 6.7641048e-07, 7.6084430e-06, ..., 5.1666480e-06,
#         1.1576462e-06, 2.2930624e-06], dtype=float32),
#  'human_CAMSAP1': array([6.6104280e-05, 5.1166256e-07, 2.1843566e-06, ..., 1.7152277e-06,
#         9.0068289e-07, 1.1330500e-06], dtype=float32),
#  'human_CANT1': array([1.6581909e-05, 4.8808749e-07, 1.0306541e-05, ..., 1.4697882e-06,
#         1.2167751e-06, 8.2805155e-07], dtype=float32),
#  'human_CAP2': array([4.6463309e-05, 5.2698948e-07, 3.1594969e-05, ..., 3.3834237e-06,
#         1.6258602e-06, 9.8248438e-07], dtype=float32),
#  'human_CAPG': array([1.1563911e-05, 9.0557586e-07, 4.2046177e-05, ..., 2.1688580e-05,
#         2.7439758e-06, 2.1699720e-06], dtype=float32),
#  'human_CAPN1': array([1.5817468e-05, 7.4529078e-07, 7.4277326e-05, ..., 4.7455164e-06,
#         2.9024727e-06, 1.2166405e-06], dtype=float32),
#  'human_CAPN12': array([8.8500792e-06, 7.1400069e-07, 2.3295228e-05, ..., 2.8257243e-06,
#         1.6505207e-06, 9.4515514e-07], dtype=float32),
#  'human_CAPN2': array([7.0428559e-06, 8.9948287e-07, 7.0175978e-05, ..., 4.2392458e-06,
#         4.2146157e-06, 1.5662461e-06], dtype=float32),
#  'human_CAPN5': array([1.9442759e-05, 6.1577072e-07, 6.2097381e-05, ..., 7.4094901e-06,
#         3.9932493e-06, 1.6548678e-06], dtype=float32),
#  'human_CAPN6': array([1.8700790e-05, 5.9490753e-07, 1.8975668e-04, ..., 8.4167204e-06,
#         3.4021416e-06, 1.0684670e-06], dtype=float32),
#  'human_CAPN8': array([8.9259493e-06, 6.1223335e-07, 2.9804030e-05, ..., 2.9371874e-06,
#         1.6859354e-06, 1.1622315e-06], dtype=float32),
#  'human_CAPN9': array([1.4605946e-05, 6.6764250e-07, 8.4989973e-05, ..., 4.8688039e-06,
#         3.9406150e-06, 1.4983813e-06], dtype=float32),
#  'human_CAPS': array([2.4972533e-06, 2.4405124e-06, 1.7351335e-06, ..., 1.7114206e-06,
#         1.6479493e-06, 5.6484987e-06], dtype=float32),
#  'human_CAPZA1': array([1.8665378e-06, 7.9128088e-04, 1.4176976e-06, ..., 1.2817936e-06,
#         1.6270516e-06, 1.3438918e-05], dtype=float32),
#  'human_CARD10': array([3.0098317e-05, 4.9159911e-07, 2.5326972e-06, ..., 2.3464536e-06,
#         9.8734608e-07, 1.2550131e-06], dtype=float32),
#  'human_CARD16': array([2.0366501e-06, 2.6982466e-06, 5.1284701e-06, ..., 2.4822755e-06,
#         1.1253995e-06, 2.2539793e-06], dtype=float32),
#  'human_CARF': array([1.1177236e-05, 6.1049064e-07, 2.7090966e-06, ..., 1.5014067e-06,
#         8.4872607e-07, 2.3443981e-06], dtype=float32),
#  'human_CARHSP1': array([1.9519796e-04, 7.7730471e-07, 2.4793739e-05, ..., 2.7647084e-06,
#         1.5697108e-06, 9.5361793e-07], dtype=float32),
#  'human_CARMIL1': array([6.0057241e-06, 3.5442897e-06, 2.3728701e-06, ..., 1.6889932e-06,
#         1.1931154e-06, 1.0221470e-05], dtype=float32),
#  'human_CARMIL2': array([1.1646097e-05, 5.4809061e-07, 2.5378595e-06, ..., 2.0184184e-06,
#         1.0367854e-06, 2.0167809e-06], dtype=float32),
#  'human_CARNMT1': array([4.7385611e-06, 2.9810806e-06, 2.3988268e-06, ..., 1.7265237e-06,
#         1.5531699e-06, 3.7724737e-06], dtype=float32),
#  'human_CARNS1': array([2.8647373e-06, 9.9427609e-07, 1.7232913e-06, ..., 3.0538336e-06,
#         1.2614676e-06, 4.3452474e-06], dtype=float32),
#  'human_CARS2': array([7.3968031e-06, 5.8070549e-07, 1.6176209e-05, ..., 4.6647274e-06,
#         1.6186600e-06, 1.2841219e-06], dtype=float32),
#  'human_CASP1': array([2.1689107e-06, 3.3343360e-05, 5.1280640e-06, ..., 2.8807920e-06,
#         1.3811097e-06, 5.6529502e-06], dtype=float32),
#  'human_CASP10': array([3.68784072e-06, 8.45454281e-07, 5.72057252e-06, ...,
#         1.11782065e-05, 1.16517799e-06, 1.79667597e-06], dtype=float32),
#  'human_CASP2': array([3.9713395e-06, 9.2221171e-07, 2.6872042e-06, ..., 6.5493123e-06,
#         1.1269536e-06, 3.7793807e-06], dtype=float32),
#  'human_CASP3': array([1.86246757e-06, 1.20892946e-04, 2.38382995e-06, ...,
#         1.95551411e-06, 1.51073107e-06, 1.33921176e-05], dtype=float32),
#  'human_CASP4': array([2.6718058e-06, 2.4020776e-06, 1.2266383e-05, ..., 4.2858023e-06,
#         1.2097057e-06, 1.4552437e-06], dtype=float32),
#  'human_CASP8': array([3.3341403e-06, 1.7401298e-06, 6.2768909e-06, ..., 3.6437327e-06,
#         1.3520697e-06, 3.5725818e-06], dtype=float32),
#  'human_CASQ1': array([6.5474946e-06, 8.1373798e-07, 1.2535962e-05, ..., 5.5597552e-06,
#         1.2431794e-06, 1.6796381e-06], dtype=float32),
#  'human_CASR': array([2.5563193e-05, 6.0096795e-07, 1.6873238e-03, ..., 2.5283523e-05,
#         7.0277333e-06, 1.7371170e-06], dtype=float32),
#  'human_CASS4': array([4.0869974e-05, 5.7252470e-07, 2.5458323e-06, ..., 6.5009667e-06,
#         9.5096425e-07, 1.4500002e-06], dtype=float32),
#  'human_CAT': array([2.0324136e-05, 4.7097336e-07, 2.9687524e-05, ..., 2.4356711e-06,
#         1.3761988e-06, 8.7191677e-07], dtype=float32),
#  'human_CATIP': array([2.2710597e-06, 2.0860259e-06, 1.6397141e-06, ..., 2.2081838e-06,
#         9.2400234e-07, 1.2656030e-06], dtype=float32),
#  'human_CATSPER2': array([1.8416638e-05, 4.8457650e-07, 8.7217504e-06, ..., 2.5529926e-06,
#         9.5019459e-07, 8.7883069e-07], dtype=float32),
#  'human_CATSPER4': array([2.6649566e-05, 5.0078421e-07, 2.9766590e-05, ..., 5.9401100e-06,
#         1.2285027e-06, 8.0707207e-07], dtype=float32),
#  'human_CATSPERD': array([2.7438107e-06, 9.5301516e-07, 3.9374968e-06, ..., 7.5360340e-06,
#         1.2145410e-06, 1.2469410e-06], dtype=float32),
#  'human_CATSPERZ': array([1.9217363e-05, 6.2593551e-07, 1.8205229e-06, ..., 2.5318568e-06,
#         8.5524562e-07, 1.6517821e-06], dtype=float32),
#  'human_CAV1': array([3.8038822e-06, 8.0653308e-06, 2.5440506e-06, ..., 1.2865700e-06,
#         1.5197510e-06, 2.9360449e-06], dtype=float32),
#  'human_CAV2': array([8.2748593e-06, 7.3477952e-07, 9.9233930e-06, ..., 1.5981354e-06,
#         1.3961962e-06, 1.2502609e-06], dtype=float32),
#  'human_CAVIN1': array([5.3824233e-06, 1.1034462e-06, 1.5703006e-06, ..., 1.9417400e-06,
#         1.4430310e-06, 4.4427023e-05], dtype=float32),
#  'human_CAVIN2': array([7.2774542e-06, 8.7420563e-07, 1.8513130e-06, ..., 1.8978906e-06,
#         1.0213649e-06, 4.8081542e-06], dtype=float32),
#  'human_CAVIN3': array([3.1024865e-06, 7.1313303e-07, 1.0790449e-06, ..., 1.7040186e-06,
#         9.9656017e-07, 7.7143632e-06], dtype=float32),
#  'human_CBARP': array([2.0059097e-05, 5.3832315e-07, 1.8407781e-06, ..., 2.2903673e-06,
#         8.7026694e-07, 2.6202506e-06], dtype=float32),
#  'human_CBFA2T2': array([9.4890365e-06, 1.3340077e-06, 2.9310622e-06, ..., 1.4987086e-06,
#         1.7599838e-06, 1.4118852e-04], dtype=float32),
#  'human_CBL': array([3.3122819e-06, 9.9953933e-05, 1.0806998e-06, ..., 1.5560015e-06,
#         9.9667136e-07, 3.4542267e-05], dtype=float32),
#  'human_CBLN2': array([2.6769808e-06, 2.5721720e-06, 3.5871801e-06, ..., 4.3490113e-06,
#         2.5834386e-06, 1.1951168e-05], dtype=float32),
#  'human_CBLN4': array([5.5627779e-06, 7.0674309e-07, 1.1966519e-05, ..., 2.8945906e-05,
#         3.0423078e-06, 2.6072044e-06], dtype=float32),
#  'human_CBR1': array([1.7331257e-06, 2.2962191e-05, 1.7645028e-06, ..., 1.6767972e-06,
#         1.1524480e-06, 6.4020160e-06], dtype=float32),
#  'human_CBS': array([1.3790636e-05, 6.7468324e-07, 9.6650228e-06, ..., 2.5307875e-06,
#         1.8390725e-06, 1.2952021e-06], dtype=float32),
#  'human_CBWD1': array([1.9923013e-05, 4.2965220e-07, 5.0020670e-05, ..., 3.0850435e-06,
#         1.4233060e-06, 9.2433112e-07], dtype=float32),
#  'human_CBWD2': array([2.6964937e-05, 4.3680382e-07, 3.9248756e-05, ..., 3.0953049e-06,
#         1.3535689e-06, 1.1044389e-06], dtype=float32),
#  'human_CBWD5': array([2.7200929e-05, 4.3384625e-07, 4.7462207e-05, ..., 3.3310193e-06,
#         1.3399980e-06, 1.0484716e-06], dtype=float32),
#  'human_CBX1': array([5.4224242e-06, 4.8900843e-06, 2.8036382e-06, ..., 4.1411663e-06,
#         1.3807975e-06, 1.8062599e-05], dtype=float32),
#  'human_CBX2': array([2.0421787e-05, 5.1379698e-07, 2.7704991e-06, ..., 1.8311358e-06,
#         9.8568091e-07, 1.2651965e-06], dtype=float32),
#  'human_CBX4': array([2.6328767e-05, 6.3569314e-07, 4.2848255e-06, ..., 2.5815791e-06,
#         1.1714910e-06, 2.0689517e-06], dtype=float32),
#  'human_CBX5': array([6.58963108e-05, 7.50776678e-07, 1.08830594e-04, ...,
#         7.55867813e-06, 2.36035089e-06, 1.41036696e-06], dtype=float32),
#  'human_CBX6': array([6.4553518e-05, 5.3371838e-07, 3.6207905e-06, ..., 1.9486299e-06,
#         1.1493549e-06, 1.2306062e-06], dtype=float32),
#  'human_CBY3': array([5.8842852e-06, 5.2676188e-07, 1.2126198e-06, ..., 2.1156918e-06,
#         7.8484970e-07, 8.6434471e-07], dtype=float32),
#  'human_CC2D2A': array([1.2697044e-05, 5.8750976e-07, 2.3135080e-06, ..., 1.5145639e-06,
#         8.8332860e-07, 8.8086966e-07], dtype=float32),
#  ...}

# %%
macrogene_adata = sc.AnnData(adata.obsm["macrogenes"])
macrogene_adata.obs = adata.obs

# %%
sc.tl.rank_genes_groups(macrogene_adata, groupby="labels2", method="wilcoxon")

# %%
sc.pl.rank_genes_groups_dotplot(macrogene_adata)
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_labels2). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# /home/amaguza/miniforge3/envs/SATURN/lib/python3.9/site-packages/scanpy/tools/_utils.py:41: UserWarning: You’re trying to run this on 2000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
#   warnings.warn(

# %% [markdown]
# * Investigate these macrogenes by their top ranked genes

# %%
def get_top_gene_for_species(macrogene, species, macrogene_weights):
    scores = {}
    for gene, score in macrogene_weights.items():
        if gene.startswith(species):
            scores[gene] = score[int(macrogene)]
    
    if scores:
        return max(scores, key=scores.get)
    return None

# %%
def compile_macrogene_top_genes(macrogenes, macrogene_weights):
    results = []
    for macrogene in macrogenes:
        top_human_gene = get_top_gene_for_species(macrogene, 'human', macrogene_weights)
        top_mouse_gene = get_top_gene_for_species(macrogene, 'mouse', macrogene_weights)
        
        if top_human_gene:
            top_human_gene = top_human_gene.split('_', 1)[1] 
        if top_mouse_gene:
            top_mouse_gene = top_mouse_gene.split('_', 1)[1]
        
        results.append({
            'Macrogene': macrogene,
            'Top Human Gene': top_human_gene,
            'Top Mouse Gene': top_mouse_gene
        })
    
    return pd.DataFrame(results)

# %%
macrogenes = list(range(2000))

# %%
df = compile_macrogene_top_genes(macrogenes, macrogene_weights)

# %%
print(df.head())
# Out:
#    Macrogene Top Human Gene Top Mouse Gene
# 0          0           PAK6           Pak4
# 1          1           RBL1           Rbl1
# 2          2          ANPEP          Erap1
# 3          3          CASP2          Ifih1
# 4          4           PCP4        Nup62cl

# %%
df.to_csv('data/saturn_results/macrogenes_derived_human_mouse_orthologues.csv', index=False)
