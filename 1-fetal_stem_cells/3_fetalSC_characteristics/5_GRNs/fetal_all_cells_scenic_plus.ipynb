# %% [markdown]
# ### Notebook for analysis of gene regulatory netwoorks in fetal data with `scenic+`
#
# - **Developed by:** Anna Maguza
# - **Affilation:** Faculty of Medicine, Würzburg University
# - **Created date:** 29th August 2024
# - **Last modified date:** 29th August 2024

# %% [markdown]
# #### Import packages

# %%
import os
import numpy as np
import pandas as pd
import scanpy as sc
import loompy as lp

# %% [markdown]
# #### Load anndata object

# %%
adata = sc.read_h5ad('/mnt/LaCIE/annaM/gut_project/Processed_data/Gut_data/Fetal_stem_cells/Fetal_cells_filtered_raw.h5ad')

# %%
adata.raw = adata

# %% [markdown]
# #### Set up working environment

# %%
sc.settings.verbosity = 3 # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.set_figure_params(dpi=150, fontsize=10, dpi_save=600)
# Out:
# -----
# anndata     0.10.9
# scanpy      1.10.2
# -----
# PIL                         10.4.0
# anyio                       NA
# arrow                       1.3.0
# asttokens                   NA
# attr                        24.2.0
# attrs                       24.2.0
# babel                       2.16.0
# backcall                    0.2.0
# certifi                     2024.07.04
# cffi                        1.17.0
# charset_normalizer          3.3.2
# cloudpickle                 3.0.0
# colorama                    0.4.6
# comm                        0.2.2
# cycler                      0.12.1
# cython_runtime              NA
# cytoolz                     0.12.3
# dask                        2024.8.0
# dateutil                    2.9.0
# debugpy                     1.8.5
# decorator                   5.1.1
# defusedxml                  0.7.1
# exceptiongroup              1.2.2
# executing                   2.0.1
# fastjsonschema              NA
# fqdn                        NA
# ...

# %%
output_dir = '/mnt/LaCIE/annaM/gut_project/Processed_data/Gut_data/Fetal_stem_cells/FetalSC_and_other_fetal_cells/scenic/'

# %%
f_loom_path_scenic = f"{output_dir}fetal_scenic.loom"

# %%
f_anndata_path = f"{output_dir}fetal_scenic.h5ad"

# %%
f_pyscenic_output = f"{output_dir}fetal_pyscenic_output.loom"

# %%
f_final_loom = f"{output_dir}fetal_scenic_integrated-output.loom"

# %%
sc.settings.njobs = 20

# %% [markdown]
# ### STEP 1: Gene regulatory network inference, and generation of co-expression modules

# %% [markdown]
# * Phase Ia: GRN inference using the GRNBoost2 algorithm

# %%
f_tfs = f"{output_dir}/allTFs_hg38.txt"

# %%
# !pyscenic grn {adata_path} {f_tfs} -o adj.csv --num_workers 20
# Out:
# 2024-08-29 13:32:45,781 - pyscenic.cli.pyscenic - INFO - Loading expression matrix.
# /home/amaguza/miniforge3/envs/pyscenic/lib/python3.9/site-packages/anndata/_core/sparse_dataset.py:419: FutureWarning: The .value attribute is deprecated and will be removed in the anndata 0.11.0. Please use .to_memory() instead.
#   warnings.warn(
#
# 2024-08-29 13:32:59,796 - pyscenic.cli.pyscenic - INFO - Inferring regulatory networks.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# Numba: Attempted to fork from a non-main thread, the TBB library may be in an invalid state in the child process.
# ...

# %%
adjacencies = pd.read_csv("adj.csv", index_col=False, sep='\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 adjacencies = pd.read_csv("adj.csv", index_col=False, sep='\t')
#
# File ~/miniforge3/envs/pyscenic/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
