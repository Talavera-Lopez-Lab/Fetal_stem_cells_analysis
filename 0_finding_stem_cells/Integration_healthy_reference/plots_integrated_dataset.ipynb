# %% [markdown]
# ## Notebook for Integrated healthy reference dataset plots creation
#
# + Developed by: Anna Maguza
# + Institute of Computational Biology - Computational Health Centre - Hemlholtz Munich
# + Date created: 22nd May 2024
# + Last modified: 22nd May 2024

# %% [markdown]
# #### Import required packages

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as an
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# ### Data Upload

# %%
input_dir = '/mnt/LaCIE/annaM/gut_project/Processed_data/Gut_data/Healthy_reference/Integrated/'

# %%
adata = sc.read(input_dir + 'Integrated_4_datasets_05042024')

# %% [markdown]
# ### UMAP

# %%
adata

# %%
new_palette = ['#43766C', '#759EB8', '#824670', '#FF76CE', '#E9A8F2', '#94FFD8',
               '#A3D8FF', '#FFA27F', '#97BE5A']  # Hex codes for pink and light blue

# Assign the new color palette to your categories
adata.uns['Cell_Type_colors'] = new_palette

fig_dir = '/mnt/LaCIE/annaM/gut_project/Processed_data/Gut_data/Plots/Finding_stem_cells'

with plt.rc_context():
    sc.set_figure_params(dpi=300, figsize=(15, 15))
    sc.pl.umap(adata, frameon=False, color='Cell_Type', size=10, legend_fontsize=5, ncols=3, show=False)
    plt.savefig(f"{fig_dir}/Integrated_reference_umap.png", bbox_inches="tight")

# %% [markdown]
# + Umap with stem scores

# %%
adata_log = adata.copy()
sc.pp.normalize_total(adata_log, target_sum = 1e6, exclude_highly_expressed = True)
sc.pp.log1p(adata_log)

# %%
stem_cells_markers = ['AXIN2', 'ASCL2', 'ATOH1', 'BMI1', 'CA12', 'CLU', 'GPX2', 'HMGCS2', 'LEFTY1', 'LGR5', 'LRIG1', 'MYC', 'OLFM4', 'SMOC2', 'TERT']

# %%
sc.tl.score_genes(adata_log, stem_cells_markers, score_name = 'Stem_cells_markers_score')

# %%
with plt.rc_context():
    sc.set_figure_params(dpi=300, figsize=(15, 15))
    sc.pl.umap(adata_log, color= ['Stem_cells_markers_score'], color_map = "magma_r", frameon=False, size = 10, show=False)
    plt.savefig(f"{fig_dir}/Integrated_reference_stem_markers.png", bbox_inches="tight")

# %% [markdown]
# + umap with stem cells

# %%
stem_cells = ['Stem cells OLFM4', 'Stem cells OLFM4 GSTA1', 'Stem cells OLFM4 LGR5', 'Stem cells OLFM4 PCNA', 'Stem_Cells_GCA', 'Stem_Cells_ext']

# %%
# create a column stem_cells in adata.obs with True if the cell is a stem cell and False otherwise
adata.obs['stem_cells'] = adata.obs['Cell States'].isin(stem_cells)

# %%
adata.obs['stem_cells'] = adata.obs['stem_cells'].astype(str)

# %%
new_palette = ['#759EB8', '#824670']  # Hex codes for pink and light blue

# Assign the new color palette to your categories
adata.uns['stem_cells_colors'] = new_palette

with plt.rc_context():
    sc.set_figure_params(dpi=300, figsize=(15, 15))
    sc.pl.umap(adata, frameon=False, color='stem_cells', size=10, legend_fontsize=5, ncols=3, show=False)
    plt.savefig(f"{fig_dir}/Integrated_reference_stem_umap.png", bbox_inches="tight")

# %% [markdown]
# + Dot plot

# %%
df = adata_log.obs['Cell States'].value_counts()

# %%
adata_log.obs['states_for_figure'] = adata_log.obs['Cell_Type'].copy()

# %%
adata_log.obs['states_for_figure'].value_counts()
# Out:
# states_for_figure
# Epithelial         210075
# Mesenchymal        172657
# T cells             47043
# Plasma cells        46681
# Myeloid             25587
# Neuronal            19307
# B cells             17772
# Endothelial         16631
# Red blood cells      1346
# Name: count, dtype: int64

# %%
adata_log.obs['states_for_figure'] = adata_log.obs['Cell_Type'].copy()
adata_log.obs['states_for_figure'] = adata_log.obs['states_for_figure'].cat.set_categories(['Epithelial',
                                                                                            'Mesenchymal', 'T cells', 'Plasma cells', 'Myeloid',
                                                                                            'Neuronal', 'B cells', 'Endothelial', 'Red blood cells', 
                                                                                            'Colonocyte', 'Goblet cells', 'Enterocyte', 'Paneth cells', 
                                                                                            'Stem cells', 'TA',
                                                                                            'Tuft cells'])


adata_log.obs.loc[adata_log.obs['Cell States'] == 'Goblet cell', 'states_for_figure'] = 'Goblet cells'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'BEST2+ Goblet cell', 'states_for_figure'] = 'Goblet cells'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Goblet cells MUC2 TFF1', 'states_for_figure'] = 'Goblet cells'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Goblet cells SPINK4', 'states_for_figure'] = 'Goblet cells'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Paneth', 'states_for_figure'] = 'Paneth cells'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Paneth cells', 'states_for_figure'] = 'Paneth cells'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'TA', 'states_for_figure'] = 'TA'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Tuft', 'states_for_figure'] = 'Tuft cells'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Tuft cells', 'states_for_figure'] = 'Tuft cells'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Enterocyte', 'states_for_figure'] = 'Enterocyte'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Enterocytes BEST4', 'states_for_figure'] = 'Enterocyte'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Enterocytes TMIGD1 MEP1A GSTA1', 'states_for_figure'] = 'Enterocyte'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Enterocytes TMIGD1 MEP1A', 'states_for_figure'] = 'Enterocyte'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Stem cells OLFM4', 'states_for_figure'] = 'Stem cells'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Stem cells OLFM4 GSTA1', 'states_for_figure'] = 'Stem cells'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Stem cells OLFM4 LGR5', 'states_for_figure'] = 'Stem cells'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Stem cells OLFM4 PCNA', 'states_for_figure'] = 'Stem cells'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Stem_Cells_GCA', 'states_for_figure'] = 'Stem cells'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Stem_Cells_ext', 'states_for_figure'] = 'Stem cells'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Enterocytes CA1 CA2 CA4-', 'states_for_figure'] = 'Enterocyte'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Colonocyte', 'states_for_figure'] = 'Colonocyte'
adata_log.obs.loc[adata_log.obs['Cell States'] == 'Goblet cells MUC2 TFF1-', 'states_for_figure'] = 'Goblet cells'

# %%
with plt.rc_context():
    sc.set_figure_params(dpi=300, figsize=(15, 15))
    sc.pl.dotplot(adata_log, stem_cells_markers, groupby='states_for_figure', cmap = 'magma_r', show=False) 
    plt.savefig(f"{fig_dir}/Integrated_stem_markers_dotplot.png", bbox_inches="tight")

# %%
adata_log.obs['states_for_figure'].value_counts()
# Out:
# states_for_figure
# Mesenchymal        172164
# Enterocyte          75420
# T cells             47043
# Plasma cells        46681
# TA                  39556
# Stem cells          35828
# Myeloid             25587
# Epithelial          24703
# Neuronal            19307
# B cells             17772
# Endothelial         16631
# Goblet cells        16375
# Colonocyte          13614
# Paneth cells         3743
# Red blood cells      1346
# Tuft cells           1329
# Name: count, dtype: int64

# %%
adata_log.obs
# Out:
#                                      Sample_ID     Cell_Type  Study_name  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell     Ileum-1    Epithelial  Wang, 2020
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell     Ileum-1    Epithelial  Wang, 2020
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell     Ileum-1    Epithelial  Wang, 2020
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell     Ileum-1    Epithelial  Wang, 2020
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell     Ileum-1    Epithelial  Wang, 2020
# ...                                        ...           ...         ...
# H180844_N4-GATCGATCATATACGC         H180844_N4  Plasma cells  Kong, 2023
# H180844_N4-ACTGCTCAGAAACCTA         H180844_N4       Myeloid  Kong, 2023
# H180844_N4-CATCAGACACGGCCAT         H180844_N4       Myeloid  Kong, 2023
# H180844_N4-TATGCCCCAATGACCT         H180844_N4       Myeloid  Kong, 2023
# H180844_N4-ATTATCCCAGCTTAAC         H180844_N4       Myeloid  Kong, 2023
#
#                                         Donor_ID      Diagnosis  Age  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell  Wang_Donor_1  Healthy adult  nan
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell  Wang_Donor_1  Healthy adult  nan
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell  Wang_Donor_1  Healthy adult  nan
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell  Wang_Donor_1  Healthy adult  nan
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell  Wang_Donor_1  Healthy adult  nan
# ...                                          ...            ...  ...
# H180844_N4-GATCGATCATATACGC               180844  Healthy adult  NaN
# H180844_N4-ACTGCTCAGAAACCTA               180844  Healthy adult  NaN
# H180844_N4-CATCAGACACGGCCAT               180844  Healthy adult  NaN
# H180844_N4-TATGCCCCAATGACCT               180844  Healthy adult  NaN
# H180844_N4-ATTATCCCAGCTTAAC               180844  Healthy adult  NaN
#
#                                    Region code Fraction   Sex  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell         nan      nan  Male
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell         nan      nan  Male
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell         nan      nan  Male
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell         nan      nan  Male
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell         nan      nan  Male
# ...                                        ...      ...   ...
# H180844_N4-GATCGATCATATACGC                NaN      NaN  Male
# H180844_N4-ACTGCTCAGAAACCTA                NaN      NaN  Male
# H180844_N4-CATCAGACACGGCCAT                NaN      NaN  Male
# H180844_N4-TATGCCCCAATGACCT                NaN      NaN  Male
# H180844_N4-ATTATCCCAGCTTAAC                NaN      NaN  Male
#
#                                    Library_Preparation_Protocol  ...  \
# cell_id                                                          ...
# AACACGTTCTTGCATT_Ileum-1_Stem Cell                    10x 3' v1  ...
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell                    10x 3' v1  ...
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell                    10x 3' v1  ...
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell                    10x 3' v1  ...
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell                    10x 3' v1  ...
# ...                                                         ...  ...
# H180844_N4-GATCGATCATATACGC                           10x 3' v2  ...
# H180844_N4-ACTGCTCAGAAACCTA                           10x 3' v2  ...
# H180844_N4-CATCAGACACGGCCAT                           10x 3' v2  ...
# H180844_N4-TATGCCCCAATGACCT                           10x 3' v2  ...
# H180844_N4-ATTATCCCAGCTTAAC                           10x 3' v2  ...
#
#                                    total_counts total_counts_mito  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell      15733.0            2722.0
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell      13928.0            2136.0
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell       6978.0             702.0
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell      19378.0            2263.0
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell      21237.0            4083.0
# ...                                         ...               ...
# H180844_N4-GATCGATCATATACGC               228.0              22.0
# H180844_N4-ACTGCTCAGAAACCTA               310.0               8.0
# H180844_N4-CATCAGACACGGCCAT               305.0              14.0
# H180844_N4-TATGCCCCAATGACCT               232.0               8.0
# H180844_N4-ATTATCCCAGCTTAAC               168.0              26.0
#
#                                    pct_counts_mito total_counts_ribo  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell       17.301214            5100.0
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell       15.336015            5261.0
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell       10.060189            2716.0
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell       11.678192            7129.0
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell       19.225880            7718.0
# ...                                            ...               ...
# H180844_N4-GATCGATCATATACGC               9.649122              29.0
# H180844_N4-ACTGCTCAGAAACCTA               2.580645              88.0
# H180844_N4-CATCAGACACGGCCAT               4.590164              66.0
# H180844_N4-TATGCCCCAATGACCT               3.448276              17.0
# H180844_N4-ATTATCCCAGCTTAAC              15.476191              12.0
#
#                                    pct_counts_ribo  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell       32.415943
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell       37.772831
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell       38.922329
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell       36.789143
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell       36.342232
# ...                                            ...
# H180844_N4-GATCGATCATATACGC              12.719299
# H180844_N4-ACTGCTCAGAAACCTA              28.387096
# H180844_N4-CATCAGACACGGCCAT              21.639343
# H180844_N4-TATGCCCCAATGACCT               7.327586
# H180844_N4-ATTATCCCAGCTTAAC               7.142858
#
#                                                                Cell_ID  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell  AACACGTTCTTGCATT_Ileum-1_Stem Cell
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell  AACCGCGCATGAAGTA_Ileum-1_Stem Cell
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell  AACTCAGAGCGATCCC_Ileum-1_Stem Cell
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell  AACTCCCTCTCAACTT_Ileum-1_Stem Cell
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell  AACTCTTAGCTTCGCG_Ileum-1_Stem Cell
# ...                                                                ...
# H180844_N4-GATCGATCATATACGC                H180844_N4-GATCGATCATATACGC
# H180844_N4-ACTGCTCAGAAACCTA                H180844_N4-ACTGCTCAGAAACCTA
# H180844_N4-CATCAGACACGGCCAT                H180844_N4-CATCAGACACGGCCAT
# H180844_N4-TATGCCCCAATGACCT                H180844_N4-TATGCCCCAATGACCT
# H180844_N4-ATTATCCCAGCTTAAC                H180844_N4-ATTATCCCAGCTTAAC
#
#                                    _scvi_batch _scvi_labels      C_scANVI  \
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell           0            8     Stem Cell
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell           0            8     Stem Cell
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell           0            8     Stem Cell
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell           0            8     Stem Cell
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell           0            8     Stem Cell
# ...                                        ...          ...           ...
# H180844_N4-GATCGATCATATACGC                  0            6  Plasma cells
# H180844_N4-ACTGCTCAGAAACCTA                  0            4       Myeloid
# H180844_N4-CATCAGACACGGCCAT                  0            4       Myeloid
# H180844_N4-TATGCCCCAATGACCT                  0            4       Myeloid
# H180844_N4-ATTATCCCAGCTTAAC                  0            4       Myeloid
#
#                                     states_for_figure
# cell_id
# AACACGTTCTTGCATT_Ileum-1_Stem Cell         Stem cells
# AACCGCGCATGAAGTA_Ileum-1_Stem Cell         Stem cells
# AACTCAGAGCGATCCC_Ileum-1_Stem Cell         Stem cells
# AACTCCCTCTCAACTT_Ileum-1_Stem Cell         Stem cells
# AACTCTTAGCTTCGCG_Ileum-1_Stem Cell         Stem cells
# ...                                               ...
# H180844_N4-GATCGATCATATACGC              Plasma cells
# H180844_N4-ACTGCTCAGAAACCTA                   Myeloid
# H180844_N4-CATCAGACACGGCCAT                   Myeloid
# H180844_N4-TATGCCCCAATGACCT                   Myeloid
# H180844_N4-ATTATCCCAGCTTAAC                   Myeloid
#
# [557099 rows x 30 columns]
